# %% [markdown]
# # Accesing and querying JanusGraph database

# %% [markdown]
# This notebook demonstrates how to create a connection to the graph database, how to query the graph database and how to visualize graph query results.
#
#
# Let's start with imports and connection to JanusGraph database:

# %%
from thoth.lab import obtain_location
from thoth.storages import GraphDatabase

# Let's obtain location of our JanusGraph instance.
JANUSGRAPH_LOCATION = obtain_location(
    "thoth-test-core-janusgraph",  # name of JanusGraph instance
    verify=False,            # do not verify TLS on internal network
    only_netloc=True         # do not use http schema, use netloc instead
)

# Instantiate and connect the JanusGraph database
adapter = GraphDatabase.create(JANUSGRAPH_LOCATION, port=80)
adapter.connect()

adapter.is_connected()
# Out:
# True

# %% [markdown]
# Next, let's try to perform some generic queries. We will use `GraphQueryResult` wrapper that wraps our graph queries and exposes some useful methods for us:

# %%
from thoth.lab import GraphQueryResult as gqr

query = adapter.g.V().has('__label__', 'python_package_version').groupCount().by('package_name').next()
query_result = gqr(query)

# %% [markdown]
# If we would like to access raw response, we can do so by acessing the result attribute:

# %%
query_result.result
# Out:
# {'asn1crypto': 2,
#  'attrs': 1,
#  'babel': 1,
#  'backcall': 1,
#  'backports.shutil-get-terminal-size': 1,
#  'backports.ssl-match-hostname': 1,
#  'bleach': 1,
#  'certifi': 32,
#  'cffi': 2,
#  'chardet': 2,
#  'click': 24,
#  'complex-dist': 1,
#  'configparser': 1,
#  'cryptography': 2,
#  'cycler': 1,
#  'cython': 1,
#  'decorator': 22,
#  'docopt': 11,
#  'docutils': 10,
#  'flask': 12,
#  'flask-socketio': 1,
#  'funcsigs': 1,
#  'gevent': 45,
#  'gevent-websocket': 1,
#  'gitdb2': 1,
#  'gitpython': 1,
#  'glob2': 3,
#  'greenlet': 4,
#  'gyp': 1,
#  'headers.dist': 1,
#  'idna': 1,
#  'iniparse': 1,
#  'ipykernel': 23,
#  'ipython': 86,
#  'ipython-genutils': 2,
#  'itsdangerous': 4,
#  'jasmine-core': 1,
#  'javapackages': 1,
#  'jedi': 12,
#  'jinja2': 25,
#  'jsonschema': 1,
#  'jupyter': 1,
#  'jupyter-client': 16,
#  'jupyter-console': 1,
#  'jupyter-core': 14,
#  'jupyterlab': 2,
#  'jupyterlab-launcher': 1,
#  'keras': 1,
#  'kitchen': 1,
#  'lxml': 1,
#  'markupsafe': 18,
#  'matplotlib': 2,
#  'mistune': 2,
#  'mock': 1,
#  'more-itertools': 3,
#  'nbconvert': 2,
#  'nbformat': 1,
#  'nltk': 1,
#  'nose': 2,
#  'notebook': 2,
#  'numpy': 62,
#  'ordereddict': 1,
#  'packaging': 1,
#  'pandas': 54,
#  'parso': 3,
#  'path.py': 57,
#  'pathlib2': 1,
#  'patsy': 7,
#  'pbr': 1,
#  'pexpect': 16,
#  'pickleshare': 11,
#  'pip': 4,
#  'pluggy': 7,
#  'prometheus-client-model': 1,
#  'prompt-toolkit': 70,
#  'psycopg2': 1,
#  'ptyprocess': 3,
#  'py': 3,
#  'py4j': 2,
#  'pycparser': 1,
#  'pygments': 32,
#  'pyliblzma': 1,
#  'pyopenssl': 2,
#  'pyparsing': 1,
#  'pysocks': 1,
#  'pyspark': 3,
#  'pytest': 71,
#  'python-dateutil': 17,
#  'python-engineio': 31,
#  'python-socketio': 20,
#  'pytz': 95,
#  'pyxattr': 1,
#  'pyyaml': 1,
#  'pyzmq': 31,
#  'requests': 2,
#  'ruamel-yaml': 1,
#  'scikit-learn': 2,
#  'scipy': 38,
#  'seaborn': 1,
#  'setuptools': 303,
#  'simple.dist': 1,
#  'simplegeneric': 1,
#  'singledispatch': 1,
#  'six': 23,
#  'smmap2': 1,
#  'sphinx': 1,
#  'sqlalchemy': 1,
#  'statsmodels': 2,
#  'testpath': 1,
#  'tornado': 20,
#  'traitlets': 15,
#  'urllib3': 1,
#  'virtualenv': 2,
#  'wcwidth': 9,
#  'werkzeug': 41,
#  'wheel': 1,
#  'widgetsnbextension': 2}

# %% [markdown]
# We can get results as Pandas dataframe:

# %%
import pandas as pd

r=query_result.result
df = pd.DataFrame(list(r.items()), columns=['Package Name', '# Versions'])
df
# Out:
#                      Package Name  # Versions
# 0                        greenlet           4
# 1                        testpath           1
# 2                    scikit-learn           2
# 3                          cython           1
# 4                     pickleshare          11
# 5         prometheus-client-model           1
# 6                        psycopg2           1
# 7                              py           3
# 8                       pycparser           1
# 9                      markupsafe          18
# 10                          patsy           7
# 11               ipython-genutils           2
# 12   backports.ssl-match-hostname           1
# 13                         bleach           1
# 14                           lxml           1
# 15                       docutils          10
# 16                         gevent          45
# 17                 flask-socketio           1
# 18                      gitpython           1
# 19                     jsonschema           1
# 20                       werkzeug          41
# 21                python-engineio          31
# 22                 jupyter-client          16
# 23                        pexpect          16
# 24                          click          24
# 25                      ipykernel          23
# 26                      nbconvert           2
# 27                     sqlalchemy           1
# 28                          attrs           1
# 29                         pyyaml           1
# ..                            ...         ...
# 87                   configparser           1
# 88                     virtualenv           2
# 89                           mock           1
# 90                            gyp           1
# 91                         smmap2           1
# 92                            pbr           1
# 93                   jupyter-core          14
# 94                     ptyprocess           3
# 95                 more-itertools           3
# 96                       funcsigs           1
# 97                        wcwidth           9
# 98                        pyspark           3
# 99                  simplegeneric           1
# 100                   simple.dist           1
# 101                       urllib3           1
# 102                    jupyterlab           2
# 103                          nose           2
# 104                           six          23
# 105                        pytest          71
# 106                    asn1crypto           2
# 107                         parso           3
# 108                         wheel           1
# 109                      nbformat           1
# 110                       ipython          86
# 111                     packaging           1
# 112                       chardet           2
# 113                        sphinx           1
# 114           jupyterlab-launcher           1
# 115                  complex-dist           1
# 116                       pyxattr           1
#
# [117 rows x 2 columns]

# %% [markdown]
# If we get result as a dictionary of values, we can easily plot some graphs:

# %%
query = adapter.g.V().has('__label__', 'python_package_version').groupCount().by('package_name').next()
query_result = gqr(query)

# %%
query_result.plot_bar()
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>
# <div id="8a5c2b0b-b054-47e2-b66d-67ea4beb43ad" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("8a5c2b0b-b054-47e2-b66d-67ea4beb43ad", [{"type": "bar", "x": ["greenlet", "testpath", "scikit-learn", "cython", "pickleshare", "prometheus-client-model", "psycopg2", "py", "pycparser", "markupsafe", "patsy", "ipython-genutils", "backports.ssl-match-hostname", "bleach", "lxml", "docutils", "gevent", "flask-socketio", "gitpython", "jsonschema", "werkzeug", "python-engineio", "jupyter-client", "pexpect", "click", "ipykernel", "nbconvert", "sqlalchemy", "attrs", "pyyaml", "jedi", "matplotlib", "pyliblzma", "flask", "idna", "decorator", "pluggy", "headers.dist", "cffi", "backports.shutil-get-terminal-size", "numpy", "requests", "py4j", "pyopenssl", "gevent-websocket", "seaborn", "jupyter", "prompt-toolkit", "itsdangerous", "kitchen", "pygments", "scipy", "tornado", "glob2", "pathlib2", "singledispatch", "pandas", "mistune", "jupyter-console", "ruamel-yaml", "babel", "statsmodels", "pysocks", "pytz", "traitlets", "iniparse", "nltk", "python-dateutil", "setuptools", "cycler", "docopt", "pyzmq", "pip", "certifi", "keras", "pyparsing", "jasmine-core", "notebook", "path.py", "ordereddict", "gitdb2", "cryptography", "jinja2", "python-socketio", "javapackages", "backcall", "widgetsnbextension", "configparser", "virtualenv", "mock", "gyp", "smmap2", "pbr", "jupyter-core", "ptyprocess", "more-itertools", "funcsigs", "wcwidth", "pyspark", "simplegeneric", "simple.dist", "urllib3", "jupyterlab", "nose", "six", "pytest", "asn1crypto", "parso", "wheel", "nbformat", "ipython", "packaging", "chardet", "sphinx", "jupyterlab-launcher", "complex-dist", "pyxattr"], "y": [4, 1, 2, 1, 11, 1, 1, 3, 1, 18, 7, 2, 1, 1, 1, 10, 45, 1, 1, 1, 41, 31, 16, 16, 24, 23, 2, 1, 1, 1, 12, 2, 1, 12, 1, 22, 7, 1, 2, 1, 62, 2, 2, 2, 1, 1, 1, 70, 4, 1, 32, 38, 20, 3, 1, 1, 54, 2, 1, 1, 1, 2, 1, 95, 15, 1, 1, 17, 303, 1, 11, 31, 4, 32, 1, 1, 1, 2, 57, 1, 1, 2, 25, 20, 1, 1, 2, 1, 2, 1, 1, 1, 1, 14, 3, 3, 1, 9, 3, 1, 1, 1, 2, 2, 23, 71, 2, 3, 1, 1, 86, 1, 2, 1, 1, 1, 1]}], {}, {"showLink": true, "linkText": "Export to plot.ly"})});</script>

# %%
# Or a pie chart

query_result.plot_pie()
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>
# <div id="8765987b-efe4-4a14-a471-65299fb6b3d5" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("8765987b-efe4-4a14-a471-65299fb6b3d5", [{"type": "pie", "labels": ["greenlet", "testpath", "scikit-learn", "cython", "pickleshare", "prometheus-client-model", "psycopg2", "py", "pycparser", "markupsafe", "patsy", "ipython-genutils", "backports.ssl-match-hostname", "bleach", "lxml", "docutils", "gevent", "flask-socketio", "gitpython", "jsonschema", "werkzeug", "python-engineio", "jupyter-client", "pexpect", "click", "ipykernel", "nbconvert", "sqlalchemy", "attrs", "pyyaml", "jedi", "matplotlib", "pyliblzma", "flask", "idna", "decorator", "pluggy", "headers.dist", "cffi", "backports.shutil-get-terminal-size", "numpy", "requests", "py4j", "pyopenssl", "gevent-websocket", "seaborn", "jupyter", "prompt-toolkit", "itsdangerous", "kitchen", "pygments", "scipy", "tornado", "glob2", "pathlib2", "singledispatch", "pandas", "mistune", "jupyter-console", "ruamel-yaml", "babel", "statsmodels", "pysocks", "pytz", "traitlets", "iniparse", "nltk", "python-dateutil", "setuptools", "cycler", "docopt", "pyzmq", "pip", "certifi", "keras", "pyparsing", "jasmine-core", "notebook", "path.py", "ordereddict", "gitdb2", "cryptography", "jinja2", "python-socketio", "javapackages", "backcall", "widgetsnbextension", "configparser", "virtualenv", "mock", "gyp", "smmap2", "pbr", "jupyter-core", "ptyprocess", "more-itertools", "funcsigs", "wcwidth", "pyspark", "simplegeneric", "simple.dist", "urllib3", "jupyterlab", "nose", "six", "pytest", "asn1crypto", "parso", "wheel", "nbformat", "ipython", "packaging", "chardet", "sphinx", "jupyterlab-launcher", "complex-dist", "pyxattr"], "values": [4, 1, 2, 1, 11, 1, 1, 3, 1, 18, 7, 2, 1, 1, 1, 10, 45, 1, 1, 1, 41, 31, 16, 16, 24, 23, 2, 1, 1, 1, 12, 2, 1, 12, 1, 22, 7, 1, 2, 1, 62, 2, 2, 2, 1, 1, 1, 70, 4, 1, 32, 38, 20, 3, 1, 1, 54, 2, 1, 1, 1, 2, 1, 95, 15, 1, 1, 17, 303, 1, 11, 31, 4, 32, 1, 1, 1, 2, 57, 1, 1, 2, 25, 20, 1, 1, 2, 1, 2, 1, 1, 1, 1, 14, 3, 3, 1, 9, 3, 1, 1, 1, 2, 2, 23, 71, 2, 3, 1, 1, 86, 1, 2, 1, 1, 1, 1]}], {}, {"showLink": true, "linkText": "Export to plot.ly"})});</script>

# %% [markdown]
# To get more options on how to visualize and interact with data retrieved from graph database, use the `help` function to access up-to-date `GraphQueryResult` documentation:

# %%
help(gqr)
# Out:
# Help on class GraphQueryResult in module thoth.lab.graph:
#
# class GraphQueryResult(builtins.object)
#  |  Methods defined here:
#  |
#  |  __init__(self, result)
#  |      Initialization.
#  |
#  |      :param result: the result to be used as a query result, can be directly coroutine that is fired.
#  |
#  |  plot_bar(self)
#  |      Plot histogram of results obtained.
#  |
#  |  plot_pie(self)
#  |      Plot a pie of results into Jupyter notebook.
#  |
#  |  serialize(self)
#  |      Serialize the output of graph query.
#  |
#  |  to_dataframe(self)
#  |      Construct a panda's dataframe on results.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)

# %% [markdown]
# For more info on how to construct queries to the graph database, see [Practical Gremlin: An Apache TinkerPop Tutorial](http://kelvinlawrence.net/book/Gremlin-Graph-Guide.html). Also see [pandas.DataFrame](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.html#pandas.DataFrame) documentation on how to use dataframes and [plotly documentation](https://plot.ly/api/) for creating interactive figures. To visualize data available in the graph, use the [graph explorer](https://url.corp.redhat.com/thoth-sbu-graphexp).
