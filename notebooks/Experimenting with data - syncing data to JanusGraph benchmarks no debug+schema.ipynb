# %% [markdown]
# # Experimenting with data - syncing data to JanusGraph benchmarks - no debug

# %% [markdown]
# This notebook is a setup for experiments with JanusGraph.
#
#  * [Graphexp](https://url.corp.redhat.com/thoth-sbu-graphexp-test1) - visualization of data available in JanusGraph
#  * [Online documentation of Thoth](https://fridex.github.io/thoth/)
#  * [Gremlin graph guide](http://kelvinlawrence.net/book/Gremlin-Graph-Guide.html)

# %%
from thoth.storages.graph import GraphDatabase
from thoth.storages import SolverResultsStore
from thoth.storages import AnalysisResultsStore

from thoth.lab import obtain_location
from thoth.lab import GraphQueryResult as gqr

#graph_db = GraphDatabase.create(obtain_location('thoth-sbu-janusgraph-test1', verify=False, only_netloc=True), port=80)
graph_db = GraphDatabase.create('localhost', port=8182)
solver_results = SolverResultsStore('thoth-sbu', host=obtain_location('thoth-upshift-ceph', verify=False))
analysis_results = AnalysisResultsStore('thoth-sbu', host=obtain_location('thoth-upshift-ceph', verify=False))

graph_db.connect()
solver_results.connect()
analysis_results.connect()

# %% [markdown]
# ## Place for experiments:

# %% [markdown]
# These are benchmarks when running JanusGraph on a local machine. **Note** the debug mode of JanusGraph was turned **off**.

# %%
from thoth.common import init_logging

# Let's keep info about enabling/disabling caches.
init_logging({'thoth.storages.graph.utils': 'DEBUG'})

# %% [markdown]
# ## Syncing image analysis results - without adapter cache

# %%
from thoth.lab import GraphQueryResult as gqr

# Erase content of the graph database:
gqr(graph_db.g.V().drop().next()).result
assert gqr(graph_db.g.V().count().next()).result == 0

# %%
#list(analysis_results.get_document_listing())
analysis_document = analysis_results.retrieve_document('fridex-thoth-package-extract-dash-4f47l')

# %%
# %%time
# %env THOTH_STORAGES_DISABLE_CACHE=1

graph_db.sync_analysis_result(analysis_document)
# Out:
# DEBUG:thoth.storages.graph.utils:Disabling edge graph cache
# DEBUG:thoth.storages.graph.utils:Disabling vertex graph cache
# env: THOTH_STORAGES_DISABLE_CACHE=1
# ERROR:thoth.storages.graph.janusgraph:Failed to sync Python package, error is not fatal: {'digests': {'manifest': '3a040220698576d1854e38dc4b3dba5cbae5ad37'}, 'ecosystem': 'Python', 'path': '/opt/app-root/lib/python3.6/site-packages/numpy/compat/setup.py', 'result': {'error': 'no calls to setup found for: /tmp/tmp25bugu_h/rootfs/opt/app-root/lib/python3.6/site-packages/numpy/compat/setup.py'}}
# Traceback (most recent call last):
#   File "/home/fpokorny/.virtualenvs/thoth-notebooks-7XLP4Rya/lib/python3.6/site-packages/thoth/storages/graph/janusgraph.py", line 212, in sync_analysis_result
#     python_package_version = PythonPackageVersion.construct(python_package_info)
#   File "/home/fpokorny/.virtualenvs/thoth-notebooks-7XLP4Rya/lib/python3.6/site-packages/thoth/storages/graph/models.py", line 68, in construct
#     name=package_info['result']['name'],
# KeyError: 'name'
# ERROR:thoth.storages.graph.janusgraph:Failed to sync Python package, error is not fatal: {'digests': {'manifest': '9776279006a6f04e9598f7d49f08a03ecfbc25e9'}, 'ecosystem': 'Python', 'path': '/opt/app-root/lib/python3.6/site-packages/numpy/core/setup.py'}
# Traceback (most recent call last):
#   File "/home/fpokorny/.virtualenvs/thoth-notebooks-7XLP4Rya/lib/python3.6/site-packages/thoth/storages/graph/janusgraph.py", line 212, in sync_analysis_result
#     python_package_version = PythonPackageVersion.construct(python_package_info)
#   File "/home/fpokorny/.virtualenvs/thoth-notebooks-7XLP4Rya/lib/python3.6/site-packages/thoth/storages/graph/models.py", line 68, in construct
#     name=package_info['result']['name'],
# KeyError: 'result'
# ERROR:thoth.storages.graph.janusgraph:Failed to sync Python package, error is not fatal: {'digests': {'manifest': '366fdd5e9f97f920e292f8310ded16d5157a41ff'}, 'ecosystem': 'Python', 'path': '/opt/app-root/lib/python3.6/site-packages/numpy/distutils/setup.py', 'result': {'error': 'no calls to setup found for: /tmp/tmp25bugu_h/rootfs/opt/app-root/lib/python3.6/site-packages/numpy/distutils/setup.py'}}
# Traceback (most recent call last):
#   File "/home/fpokorny/.virtualenvs/thoth-notebooks-7XLP4Rya/lib/python3.6/site-packages/thoth/storages/graph/janusgraph.py", line 212, in sync_analysis_result
#     python_package_version = PythonPackageVersion.construct(python_package_info)
#   File "/home/fpokorny/.virtualenvs/thoth-notebooks-7XLP4Rya/lib/python3.6/site-packages/thoth/storages/graph/models.py", line 68, in construct
#     name=package_info['result']['name'],
# KeyError: 'name'
# ERROR:thoth.storages.graph.janusgraph:Failed to sync Python package, error is not fatal: {'digests': {'manifest': '4687921b80b3754d404c5f5d21ef7d41f309cab8'}, 'ecosystem': 'Python', 'path': '/opt/app-root/lib/python3.6/site-packages/numpy/f2py/setup.py', 'result': {'error': 'no calls to setup found for: /tmp/tmp25bugu_h/rootfs/opt/app-root/lib/python3.6/site-packages/numpy/f2py/setup.py'}}
# Traceback (most recent call last):
#   File "/home/fpokorny/.virtualenvs/thoth-notebooks-7XLP4Rya/lib/python3.6/site-packages/thoth/storages/graph/janusgraph.py", line 212, in sync_analysis_result
#     python_package_version = PythonPackageVersion.construct(python_package_info)
#   File "/home/fpokorny/.virtualenvs/thoth-notebooks-7XLP4Rya/lib/python3.6/site-packages/thoth/storages/graph/models.py", line 68, in construct
#     name=package_info['result']['name'],
# KeyError: 'name'
# ERROR:thoth.storages.graph.janusgraph:Failed to sync Python package, error is not fatal: {'digests': {'manifest': 'bc13e5086c8278209634f14c1747d70611827b15'}, 'ecosystem': 'Python', 'path': '/opt/app-root/lib/python3.6/site-packages/numpy/fft/setup.py', 'result': {'error': 'no calls to setup found for: /tmp/tmp25bugu_h/rootfs/opt/app-root/lib/python3.6/site-packages/numpy/fft/setup.py'}}
# Traceback (most recent call last):
#   File "/home/fpokorny/.virtualenvs/thoth-notebooks-7XLP4Rya/lib/python3.6/site-packages/thoth/storages/graph/janusgraph.py", line 212, in sync_analysis_result
#     python_package_version = PythonPackageVersion.construct(python_package_info)
#   File "/home/fpokorny/.virtualenvs/thoth-notebooks-7XLP4Rya/lib/python3.6/site-packages/thoth/storages/graph/models.py", line 68, in construct
#     name=package_info['result']['name'],
# KeyError: 'name'
# ERROR:thoth.storages.graph.janusgraph:Failed to sync Python package, error is not fatal: {'digests': {'manifest': '02119470e9cd3bf50e6cb76021619342ec985031'}, 'ecosystem': 'Python', 'path': '/opt/app-root/lib/python3.6/site-packages/numpy/lib/setup.py', 'result': {'error': 'no calls to setup found for: /tmp/tmp25bugu_h/rootfs/opt/app-root/lib/python3.6/site-packages/numpy/lib/setup.py'}}
# Traceback (most recent call last):
#   File "/home/fpokorny/.virtualenvs/thoth-notebooks-7XLP4Rya/lib/python3.6/site-packages/thoth/storages/graph/janusgraph.py", line 212, in sync_analysis_result
#     python_package_version = PythonPackageVersion.construct(python_package_info)
#   File "/home/fpokorny/.virtualenvs/thoth-notebooks-7XLP4Rya/lib/python3.6/site-packages/thoth/storages/graph/models.py", line 68, in construct
#     name=package_info['result']['name'],
# KeyError: 'name'
# ERROR:thoth.storages.graph.janusgraph:Failed to sync Python package, error is not fatal: {'digests': {'manifest': '9225a83ce85be4ebcb68db14afdf32c46079d4e0'}, 'ecosystem': 'Python', 'path': '/opt/app-root/lib/python3.6/site-packages/numpy/linalg/setup.py', 'result': {'error': 'no calls to setup found for: /tmp/tmp25bugu_h/rootfs/opt/app-root/lib/python3.6/site-packages/numpy/linalg/setup.py'}}
# Traceback (most recent call last):
#   File "/home/fpokorny/.virtualenvs/thoth-notebooks-7XLP4Rya/lib/python3.6/site-packages/thoth/storages/graph/janusgraph.py", line 212, in sync_analysis_result
#     python_package_version = PythonPackageVersion.construct(python_package_info)
#   File "/home/fpokorny/.virtualenvs/thoth-notebooks-7XLP4Rya/lib/python3.6/site-packages/thoth/storages/graph/models.py", line 68, in construct
#     name=package_info['result']['name'],
# KeyError: 'name'
# ERROR:thoth.storages.graph.janusgraph:Failed to sync Python package, error is not fatal: {'digests': {'manifest': 'e4562b8b302e1998529dd582767363dd961c7987'}, 'ecosystem': 'Python', 'path': '/opt/app-root/lib/python3.6/site-packages/numpy/ma/setup.py', 'result': {'error': 'no calls to setup found for: /tmp/tmp25bugu_h/rootfs/opt/app-root/lib/python3.6/site-packages/numpy/ma/setup.py'}}
# Traceback (most recent call last):
#   File "/home/fpokorny/.virtualenvs/thoth-notebooks-7XLP4Rya/lib/python3.6/site-packages/thoth/storages/graph/janusgraph.py", line 212, in sync_analysis_result
#     python_package_version = PythonPackageVersion.construct(python_package_info)
#   File "/home/fpokorny/.virtualenvs/thoth-notebooks-7XLP4Rya/lib/python3.6/site-packages/thoth/storages/graph/models.py", line 68, in construct
#     name=package_info['result']['name'],
# KeyError: 'name'
# ERROR:thoth.storages.graph.janusgraph:Failed to sync Python package, error is not fatal: {'digests': {'manifest': '182848d986caf013be63a6d1e546f3dd6a117fe3'}, 'ecosystem': 'Python', 'path': '/opt/app-root/lib/python3.6/site-packages/numpy/matrixlib/setup.py', 'result': {'error': 'no calls to setup found for: /tmp/tmp25bugu_h/rootfs/opt/app-root/lib/python3.6/site-packages/numpy/matrixlib/setup.py'}}
# Traceback (most recent call last):
#   File "/home/fpokorny/.virtualenvs/thoth-notebooks-7XLP4Rya/lib/python3.6/site-packages/thoth/storages/graph/janusgraph.py", line 212, in sync_analysis_result
#     python_package_version = PythonPackageVersion.construct(python_package_info)
#   File "/home/fpokorny/.virtualenvs/thoth-notebooks-7XLP4Rya/lib/python3.6/site-packages/thoth/storages/graph/models.py", line 68, in construct
#     name=package_info['result']['name'],
# KeyError: 'name'
# ERROR:thoth.storages.graph.janusgraph:Failed to sync Python package, error is not fatal: {'digests': {'manifest': '80e1bb9ec02b2665a22381a3ad2608214c9dd923'}, 'ecosystem': 'Python', 'path': '/opt/app-root/lib/python3.6/site-packages/numpy/polynomial/setup.py', 'result': {'error': 'no calls to setup found for: /tmp/tmp25bugu_h/rootfs/opt/app-root/lib/python3.6/site-packages/numpy/polynomial/setup.py'}}
# Traceback (most recent call last):
#   File "/home/fpokorny/.virtualenvs/thoth-notebooks-7XLP4Rya/lib/python3.6/site-packages/thoth/storages/graph/janusgraph.py", line 212, in sync_analysis_result
#     python_package_version = PythonPackageVersion.construct(python_package_info)
#   File "/home/fpokorny/.virtualenvs/thoth-notebooks-7XLP4Rya/lib/python3.6/site-packages/thoth/storages/graph/models.py", line 68, in construct
#     name=package_info['result']['name'],
# KeyError: 'name'
# ERROR:thoth.storages.graph.janusgraph:Failed to sync Python package, error is not fatal: {'digests': {'manifest': 'ae1f99cb8e4db2637f3e7a6f005fc1e4d26938f4'}, 'ecosystem': 'Python', 'path': '/opt/app-root/lib/python3.6/site-packages/numpy/random/setup.py', 'result': {'error': 'no calls to setup found for: /tmp/tmp25bugu_h/rootfs/opt/app-root/lib/python3.6/site-packages/numpy/random/setup.py'}}
# Traceback (most recent call last):
#   File "/home/fpokorny/.virtualenvs/thoth-notebooks-7XLP4Rya/lib/python3.6/site-packages/thoth/storages/graph/janusgraph.py", line 212, in sync_analysis_result
#     python_package_version = PythonPackageVersion.construct(python_package_info)
#   File "/home/fpokorny/.virtualenvs/thoth-notebooks-7XLP4Rya/lib/python3.6/site-packages/thoth/storages/graph/models.py", line 68, in construct
#     name=package_info['result']['name'],
# KeyError: 'name'
# ERROR:thoth.storages.graph.janusgraph:Failed to sync Python package, error is not fatal: {'digests': {'manifest': 'd8c348d3295b598533beaee4c02708bd997cc8ae'}, 'ecosystem': 'Python', 'path': '/opt/app-root/lib/python3.6/site-packages/numpy/setup.py', 'result': {'error': 'no calls to setup found for: /tmp/tmp25bugu_h/rootfs/opt/app-root/lib/python3.6/site-packages/numpy/setup.py'}}
# Traceback (most recent call last):
#   File "/home/fpokorny/.virtualenvs/thoth-notebooks-7XLP4Rya/lib/python3.6/site-packages/thoth/storages/graph/janusgraph.py", line 212, in sync_analysis_result
#     python_package_version = PythonPackageVersion.construct(python_package_info)
#   File "/home/fpokorny/.virtualenvs/thoth-notebooks-7XLP4Rya/lib/python3.6/site-packages/thoth/storages/graph/models.py", line 68, in construct
#     name=package_info['result']['name'],
# KeyError: 'name'
# ERROR:thoth.storages.graph.janusgraph:Failed to sync Python package, error is not fatal: {'digests': {'manifest': '5eacb723093dc6b1167569ed3d0c1e07d80068d9'}, 'ecosystem': 'Python', 'path': '/opt/app-root/lib/python3.6/site-packages/numpy/testing/setup.py', 'result': {'error': 'no calls to setup found for: /tmp/tmp25bugu_h/rootfs/opt/app-root/lib/python3.6/site-packages/numpy/testing/setup.py'}}
# Traceback (most recent call last):
#   File "/home/fpokorny/.virtualenvs/thoth-notebooks-7XLP4Rya/lib/python3.6/site-packages/thoth/storages/graph/janusgraph.py", line 212, in sync_analysis_result
#     python_package_version = PythonPackageVersion.construct(python_package_info)
#   File "/home/fpokorny/.virtualenvs/thoth-notebooks-7XLP4Rya/lib/python3.6/site-packages/thoth/storages/graph/models.py", line 68, in construct
#     name=package_info['result']['name'],
# KeyError: 'name'
# ERROR:thoth.storages.graph.janusgraph:Failed to sync Python package, error is not fatal: {'digests': {'manifest': '04ec62f06a556ebb1002efabddf91e1afb23a667'}, 'ecosystem': 'Python', 'path': '/opt/app-root/lib/python3.6/site-packages/scipy/_lib/setup.py'}
# Traceback (most recent call last):
#   File "/home/fpokorny/.virtualenvs/thoth-notebooks-7XLP4Rya/lib/python3.6/site-packages/thoth/storages/graph/janusgraph.py", line 212, in sync_analysis_result
#     python_package_version = PythonPackageVersion.construct(python_package_info)
#   File "/home/fpokorny/.virtualenvs/thoth-notebooks-7XLP4Rya/lib/python3.6/site-packages/thoth/storages/graph/models.py", line 68, in construct
#     name=package_info['result']['name'],
# KeyError: 'result'
# ERROR:thoth.storages.graph.janusgraph:Failed to sync Python package, error is not fatal: {'digests': {'manifest': 'ce918a00590fb744bff6748548a976ed385beeec'}, 'ecosystem': 'Python', 'path': '/opt/app-root/lib/python3.6/site-packages/scipy/cluster/setup.py', 'result': {'error': 'no calls to setup found for: /tmp/tmp25bugu_h/rootfs/opt/app-root/lib/python3.6/site-packages/scipy/cluster/setup.py'}}
# Traceback (most recent call last):
#   File "/home/fpokorny/.virtualenvs/thoth-notebooks-7XLP4Rya/lib/python3.6/site-packages/thoth/storages/graph/janusgraph.py", line 212, in sync_analysis_result
#     python_package_version = PythonPackageVersion.construct(python_package_info)
#   File "/home/fpokorny/.virtualenvs/thoth-notebooks-7XLP4Rya/lib/python3.6/site-packages/thoth/storages/graph/models.py", line 68, in construct
#     name=package_info['result']['name'],
# KeyError: 'name'
# ERROR:thoth.storages.graph.janusgraph:Failed to sync Python package, error is not fatal: {'digests': {'manifest': 'a9cdb32174db46e06cbf026e12053ec0fd603636'}, 'ecosystem': 'Python', 'path': '/opt/app-root/lib/python3.6/site-packages/scipy/constants/setup.py', 'result': {'error': 'no calls to setup found for: /tmp/tmp25bugu_h/rootfs/opt/app-root/lib/python3.6/site-packages/scipy/constants/setup.py'}}
# Traceback (most recent call last):
#   File "/home/fpokorny/.virtualenvs/thoth-notebooks-7XLP4Rya/lib/python3.6/site-packages/thoth/storages/graph/janusgraph.py", line 212, in sync_analysis_result
#     python_package_version = PythonPackageVersion.construct(python_package_info)
#   File "/home/fpokorny/.virtualenvs/thoth-notebooks-7XLP4Rya/lib/python3.6/site-packages/thoth/storages/graph/models.py", line 68, in construct
#     name=package_info['result']['name'],
# KeyError: 'name'
# ERROR:thoth.storages.graph.janusgraph:Failed to sync Python package, error is not fatal: {'digests': {'manifest': '827862f2272a8a45b0cf7cce2bcb3982e39c0262'}, 'ecosystem': 'Python', 'path': '/opt/app-root/lib/python3.6/site-packages/scipy
}, 'ecosystem': 'Python', 'path': '/opt/app-root/lib/python3.6/site-packages/sklearn/metrics/cluster/setup.py', 'result': {'error': 'no calls to setup found for: /tmp/tmp25bugu_h/rootfs/opt/app-root/lib/python3.6/site-packages/sklearn/metrics/cluster/setup.py'}}
# Traceback (most recent call last):
#   File "/home/fpokorny/.virtualenvs/thoth-notebooks-7XLP4Rya/lib/python3.6/site-packages/thoth/storages/graph/janusgraph.py", line 212, in sync_analysis_result
#     python_package_version = PythonPackageVersion.construct(python_package_info)
#   File "/home/fpokorny/.virtualenvs/thoth-notebooks-7XLP4Rya/lib/python3.6/site-packages/thoth/storages/graph/models.py", line 68, in construct
#     name=package_info['result']['name'],
# KeyError: 'name'
# ERROR:thoth.storages.graph.janusgraph:Failed to sync Python package, error is not fatal: {'digests': {'manifest': '59fe8fc3db33afac29ba1c5ea1ebd268fdb53dca'}, 'ecosystem': 'Python', 'path': '/opt/app-root/lib/python3.6/site-packages/sklearn/metrics/setup.py', 'result': {'error': 'no calls to setup found for: /tmp/tmp25bugu_h/rootfs/opt/app-root/lib/python3.6/site-packages/sklearn/metrics/setup.py'}}
# Traceback (most recent call last):
#   File "/home/fpokorny/.virtualenvs/thoth-notebooks-7XLP4Rya/lib/python3.6/site-packages/thoth/storages/graph/janusgraph.py", line 212, in sync_analysis_result
#     python_package_version = PythonPackageVersion.construct(python_package_info)
#   File "/home/fpokorny/.virtualenvs/thoth-notebooks-7XLP4Rya/lib/python3.6/site-packages/thoth/storages/graph/models.py", line 68, in construct
#     name=package_info['result']['name'],
# KeyError: 'name'
# ERROR:thoth.storages.graph.janusgraph:Failed to sync Python package, error is not fatal: {'digests': {'manifest': 'b6fe0f9ba3ff2189590c4828628e6486baef65e9'}, 'ecosystem': 'Python', 'path': '/opt/app-root/lib/python3.6/site-packages/sklearn/neighbors/setup.py', 'result': {'error': 'no calls to setup found for: /tmp/tmp25bugu_h/rootfs/opt/app-root/lib/python3.6/site-packages/sklearn/neighbors/setup.py'}}
# Traceback (most recent call last):
#   File "/home/fpokorny/.virtualenvs/thoth-notebooks-7XLP4Rya/lib/python3.6/site-packages/thoth/storages/graph/janusgraph.py", line 212, in sync_analysis_result
#     python_package_version = PythonPackageVersion.construct(python_package_info)
#   File "/home/fpokorny/.virtualenvs/thoth-notebooks-7XLP4Rya/lib/python3.6/site-packages/thoth/storages/graph/models.py", line 68, in construct
#     name=package_info['result']['name'],
# KeyError: 'name'
# ERROR:thoth.storages.graph.janusgraph:Failed to sync Python package, error is not fatal: {'digests': {'manifest': 'b2183d87a0f616fb13a0c50c5806cc51e2929d61'}, 'ecosystem': 'Python', 'path': '/opt/app-root/lib/python3.6/site-packages/sklearn/setup.py', 'result': {'error': 'no calls to setup found for: /tmp/tmp25bugu_h/rootfs/opt/app-root/lib/python3.6/site-packages/sklearn/setup.py'}}
# Traceback (most recent call last):
#   File "/home/fpokorny/.virtualenvs/thoth-notebooks-7XLP4Rya/lib/python3.6/site-packages/thoth/storages/graph/janusgraph.py", line 212, in sync_analysis_result
#     python_package_version = PythonPackageVersion.construct(python_package_info)
#   File "/home/fpokorny/.virtualenvs/thoth-notebooks-7XLP4Rya/lib/python3.6/site-packages/thoth/storages/graph/models.py", line 68, in construct
#     name=package_info['result']['name'],
# KeyError: 'name'
# ERROR:thoth.storages.graph.janusgraph:Failed to sync Python package, error is not fatal: {'digests': {'manifest': '7ca0e496eb01411d2048e5ce73137dcb20e24324'}, 'ecosystem': 'Python', 'path': '/opt/app-root/lib/python3.6/site-packages/sklearn/svm/setup.py', 'result': {'error': 'no calls to setup found for: /tmp/tmp25bugu_h/rootfs/opt/app-root/lib/python3.6/site-packages/sklearn/svm/setup.py'}}
# Traceback (most recent call last):
#   File "/home/fpokorny/.virtualenvs/thoth-notebooks-7XLP4Rya/lib/python3.6/site-packages/thoth/storages/graph/janusgraph.py", line 212, in sync_analysis_result
#     python_package_version = PythonPackageVersion.construct(python_package_info)
#   File "/home/fpokorny/.virtualenvs/thoth-notebooks-7XLP4Rya/lib/python3.6/site-packages/thoth/storages/graph/models.py", line 68, in construct
#     name=package_info['result']['name'],
# KeyError: 'name'
# ERROR:thoth.storages.graph.janusgraph:Failed to sync Python package, error is not fatal: {'digests': {'manifest': '5f8d9458e44f097b60e09456292f2bbd896a75f6'}, 'ecosystem': 'Python', 'path': '/opt/app-root/lib/python3.6/site-packages/sklearn/tree/setup.py', 'result': {'error': 'no calls to setup found for: /tmp/tmp25bugu_h/rootfs/opt/app-root/lib/python3.6/site-packages/sklearn/tree/setup.py'}}
# Traceback (most recent call last):
#   File "/home/fpokorny/.virtualenvs/thoth-notebooks-7XLP4Rya/lib/python3.6/site-packages/thoth/storages/graph/janusgraph.py", line 212, in sync_analysis_result
#     python_package_version = PythonPackageVersion.construct(python_package_info)
#   File "/home/fpokorny/.virtualenvs/thoth-notebooks-7XLP4Rya/lib/python3.6/site-packages/thoth/storages/graph/models.py", line 68, in construct
#     name=package_info['result']['name'],
# KeyError: 'name'
# ERROR:thoth.storages.graph.janusgraph:Failed to sync Python package, error is not fatal: {'digests': {'manifest': 'e47b1d5e9b1d2a2cd0554e848bce6441d2209360'}, 'ecosystem': 'Python', 'path': '/opt/app-root/lib/python3.6/site-packages/sklearn/utils/setup.py', 'result': {'error': 'no calls to setup found for: /tmp/tmp25bugu_h/rootfs/opt/app-root/lib/python3.6/site-packages/sklearn/utils/setup.py'}}
# Traceback (most recent call last):
#   File "/home/fpokorny/.virtualenvs/thoth-notebooks-7XLP4Rya/lib/python3.6/site-packages/thoth/storages/graph/janusgraph.py", line 212, in sync_analysis_result
#     python_package_version = PythonPackageVersion.construct(python_package_info)
#   File "/home/fpokorny/.virtualenvs/thoth-notebooks-7XLP4Rya/lib/python3.6/site-packages/thoth/storages/graph/models.py", line 68, in construct
#     name=package_info['result']['name'],
# KeyError: 'name'
# ERROR:thoth.storages.graph.janusgraph:Failed to sync Python package, error is not fatal: {'digests': {'manifest': '1855857cc844a266cf9d8092d7fe038dad254b5b'}, 'ecosystem': 'Python', 'path': '/opt/app-root/lib/python3.6/site-packages/sklearn/utils/sparsetools/setup.py', 'result': {'error': 'no calls to setup found for: /tmp/tmp25bugu_h/rootfs/opt/app-root/lib/python3.6/site-packages/sklearn/utils/sparsetools/setup.py'}}
# Traceback (most recent call last):
#   File "/home/fpokorny/.virtualenvs/thoth-notebooks-7XLP4Rya/lib/python3.6/site-packages/thoth/storages/graph/janusgraph.py", line 212, in sync_analysis_result
#     python_package_version = PythonPackageVersion.construct(python_package_info)
#   File "/home/fpokorny/.virtualenvs/thoth-notebooks-7XLP4Rya/lib/python3.6/site-packages/thoth/storages/graph/models.py", line 68, in construct
#     name=package_info['result']['name'],
# KeyError: 'name'
# ERROR:thoth.storages.graph.janusgraph:Failed to sync Python package, error is not fatal: {'digests': {'manifest': 'a2aae58dbc144ace99c9ca9306619ceb07e0fe11'}, 'ecosystem': 'Python-RequirementsTXT', 'path': '/opt/app-root/share/doc/networkx-2.1/requirements.txt', 'result': {'dependencies': ['-r requirements/default.txt', '-r requirements/test.txt']}}
# Traceback (most recent call last):
#   File "/home/fpokorny/.virtualenvs/thoth-notebooks-7XLP4Rya/lib/python3.6/site-packages/thoth/storages/graph/janusgraph.py", line 212, in sync_analysis_result
#     python_package_version = PythonPackageVersion.construct(python_package_info)
#   File "/home/fpokorny/.virtualenvs/thoth-notebooks-7XLP4Rya/lib/python3.6/site-packages/thoth/storages/graph/models.py", line 68, in construct
#     name=package_info['result']['name'],
# KeyError: 'name'
# CPU times: user 23.4 s, sys: 1.19 s, total: 24.6 s
# Wall time: 6min

# %%
print(f"Number of vertexes present in graph: {gqr(graph_db.g.V().count().next()).result:d}")
# Out:
# Number of vertexes present in graph: 2827

# %%
print(f"Number of edges present in graph: {gqr(graph_db.g.E().count().next()).result:d}")
# Out:
# Number of edges present in graph: 9515

# %% [markdown]
# ## Syncing image analysis results - with adapter cache

# %%
gqr(graph_db.g.V().drop().next())
assert gqr(graph_db.g.V().count().next()).result == 0

# %%
# %%time
# %env THOTH_STORAGES_DISABLE_CACHE=0

graph_db.sync_analysis_result(analysis_document)
# Out:
# DEBUG:thoth.storages.graph.utils:Enabling edge graph cache
# DEBUG:thoth.storages.graph.utils:Enabling vertex graph cache
# env: THOTH_STORAGES_DISABLE_CACHE=0
# ERROR:thoth.storages.graph.janusgraph:Failed to sync Python package, error is not fatal: {'digests': {'manifest': '3a040220698576d1854e38dc4b3dba5cbae5ad37'}, 'ecosystem': 'Python', 'path': '/opt/app-root/lib/python3.6/site-packages/numpy/compat/setup.py', 'result': {'error': 'no calls to setup found for: /tmp/tmp25bugu_h/rootfs/opt/app-root/lib/python3.6/site-packages/numpy/compat/setup.py'}}
# Traceback (most recent call last):
#   File "/home/fpokorny/.virtualenvs/thoth-notebooks-7XLP4Rya/lib/python3.6/site-packages/thoth/storages/graph/janusgraph.py", line 212, in sync_analysis_result
#     python_package_version = PythonPackageVersion.construct(python_package_info)
#   File "/home/fpokorny/.virtualenvs/thoth-notebooks-7XLP4Rya/lib/python3.6/site-packages/thoth/storages/graph/models.py", line 68, in construct
#     name=package_info['result']['name'],
# KeyError: 'name'
# ERROR:thoth.storages.graph.janusgraph:Failed to sync Python package, error is not fatal: {'digests': {'manifest': '9776279006a6f04e9598f7d49f08a03ecfbc25e9'}, 'ecosystem': 'Python', 'path': '/opt/app-root/lib/python3.6/site-packages/numpy/core/setup.py'}
# Traceback (most recent call last):
#   File "/home/fpokorny/.virtualenvs/thoth-notebooks-7XLP4Rya/lib/python3.6/site-packages/thoth/storages/graph/janusgraph.py", line 212, in sync_analysis_result
#     python_package_version = PythonPackageVersion.construct(python_package_info)
#   File "/home/fpokorny/.virtualenvs/thoth-notebooks-7XLP4Rya/lib/python3.6/site-packages/thoth/storages/graph/models.py", line 68, in construct
#     name=package_info['result']['name'],
# KeyError: 'result'
# ERROR:thoth.storages.graph.janusgraph:Failed to sync Python package, error is not fatal: {'digests': {'manifest': '366fdd5e9f97f920e292f8310ded16d5157a41ff'}, 'ecosystem': 'Python', 'path': '/opt/app-root/lib/python3.6/site-packages/numpy/distutils/setup.py', 'result': {'error': 'no calls to setup found for: /tmp/tmp25bugu_h/rootfs/opt/app-root/lib/python3.6/site-packages/numpy/distutils/setup.py'}}
# Traceback (most recent call last):
#   File "/home/fpokorny/.virtualenvs/thoth-notebooks-7XLP4Rya/lib/python3.6/site-packages/thoth/storages/graph/janusgraph.py", line 212, in sync_analysis_result
#     python_package_version = PythonPackageVersion.construct(python_package_info)
#   File "/home/fpokorny/.virtualenvs/thoth-notebooks-7XLP4Rya/lib/python3.6/site-packages/thoth/storages/graph/models.py", line 68, in construct
#     name=package_info['result']['name'],
# KeyError: 'name'
# ERROR:thoth.storages.graph.janusgraph:Failed to sync Python package, error is not fatal: {'digests': {'manifest': '4687921b80b3754d404c5f5d21ef7d41f309cab8'}, 'ecosystem': 'Python', 'path': '/opt/app-root/lib/python3.6/site-packages/numpy/f2py/setup.py', 'result': {'error': 'no calls to setup found for: /tmp/tmp25bugu_h/rootfs/opt/app-root/lib/python3.6/site-packages/numpy/f2py/setup.py'}}
# Traceback (most recent call last):
#   File "/home/fpokorny/.virtualenvs/thoth-notebooks-7XLP4Rya/lib/python3.6/site-packages/thoth/storages/graph/janusgraph.py", line 212, in sync_analysis_result
#     python_package_version = PythonPackageVersion.construct(python_package_info)
#   File "/home/fpokorny/.virtualenvs/thoth-notebooks-7XLP4Rya/lib/python3.6/site-packages/thoth/storages/graph/models.py", line 68, in construct
#     name=package_info['result']['name'],
# KeyError: 'name'
# ERROR:thoth.storages.graph.janusgraph:Failed to sync Python package, error is not fatal: {'digests': {'manifest': 'bc13e5086c8278209634f14c1747d70611827b15'}, 'ecosystem': 'Python', 'path': '/opt/app-root/lib/python3.6/site-packages/numpy/fft/setup.py', 'result': {'error': 'no calls to setup found for: /tmp/tmp25bugu_h/rootfs/opt/app-root/lib/python3.6/site-packages/numpy/fft/setup.py'}}
# Traceback (most recent call last):
#   File "/home/fpokorny/.virtualenvs/thoth-notebooks-7XLP4Rya/lib/python3.6/site-packages/thoth/storages/graph/janusgraph.py", line 212, in sync_analysis_result
#     python_package_version = PythonPackageVersion.construct(python_package_info)
#   File "/home/fpokorny/.virtualenvs/thoth-notebooks-7XLP4Rya/lib/python3.6/site-packages/thoth/storages/graph/models.py", line 68, in construct
#     name=package_info['result']['name'],
# KeyError: 'name'
# ERROR:thoth.storages.graph.janusgraph:Failed to sync Python package, error is not fatal: {'digests': {'manifest': '02119470e9cd3bf50e6cb76021619342ec985031'}, 'ecosystem': 'Python', 'path': '/opt/app-root/lib/python3.6/site-packages/numpy/lib/setup.py', 'result': {'error': 'no calls to setup found for: /tmp/tmp25bugu_h/rootfs/opt/app-root/lib/python3.6/site-packages/numpy/lib/setup.py'}}
# Traceback (most recent call last):
#   File "/home/fpokorny/.virtualenvs/thoth-notebooks-7XLP4Rya/lib/python3.6/site-packages/thoth/storages/graph/janusgraph.py", line 212, in sync_analysis_result
#     python_package_version = PythonPackageVersion.construct(python_package_info)
#   File "/home/fpokorny/.virtualenvs/thoth-notebooks-7XLP4Rya/lib/python3.6/site-packages/thoth/storages/graph/models.py", line 68, in construct
#     name=package_info['result']['name'],
# KeyError: 'name'
# ERROR:thoth.storages.graph.janusgraph:Failed to sync Python package, error is not fatal: {'digests': {'manifest': '9225a83ce85be4ebcb68db14afdf32c46079d4e0'}, 'ecosystem': 'Python', 'path': '/opt/app-root/lib/python3.6/site-packages/numpy/linalg/setup.py', 'result': {'error': 'no calls to setup found for: /tmp/tmp25bugu_h/rootfs/opt/app-root/lib/python3.6/site-packages/numpy/linalg/setup.py'}}
# Traceback (most recent call last):
#   File "/home/fpokorny/.virtualenvs/thoth-notebooks-7XLP4Rya/lib/python3.6/site-packages/thoth/storages/graph/janusgraph.py", line 212, in sync_analysis_result
#     python_package_version = PythonPackageVersion.construct(python_package_info)
#   File "/home/fpokorny/.virtualenvs/thoth-notebooks-7XLP4Rya/lib/python3.6/site-packages/thoth/storages/graph/models.py", line 68, in construct
#     name=package_info['result']['name'],
# KeyError: 'name'
# ERROR:thoth.storages.graph.janusgraph:Failed to sync Python package, error is not fatal: {'digests': {'manifest': 'e4562b8b302e1998529dd582767363dd961c7987'}, 'ecosystem': 'Python', 'path': '/opt/app-root/lib/python3.6/site-packages/numpy/ma/setup.py', 'result': {'error': 'no calls to setup found for: /tmp/tmp25bugu_h/rootfs/opt/app-root/lib/python3.6/site-packages/numpy/ma/setup.py'}}
# Traceback (most recent call last):
#   File "/home/fpokorny/.virtualenvs/thoth-notebooks-7XLP4Rya/lib/python3.6/site-packages/thoth/storages/graph/janusgraph.py", line 212, in sync_analysis_result
#     python_package_version = PythonPackageVersion.construct(python_package_info)
#   File "/home/fpokorny/.virtualenvs/thoth-notebooks-7XLP4Rya/lib/python3.6/site-packages/thoth/storages/graph/models.py", line 68, in construct
#     name=package_info['result']['name'],
# KeyError: 'name'
# ERROR:thoth.storages.graph.janusgraph:Failed to sync Python package, error is not fatal: {'digests': {'manifest': '182848d986caf013be63a6d1e546f3dd6a117fe3'}, 'ecosystem': 'Python', 'path': '/opt/app-root/lib/python3.6/site-packages/numpy/matrixlib/setup.py', 'result': {'error': 'no calls to setup found for: /tmp/tmp25bugu_h/rootfs/opt/app-root/lib/python3.6/site-packages/numpy/matrixlib/setup.py'}}
# Traceback (most recent call last):
#   File "/home/fpokorny/.virtualenvs/thoth-notebooks-7XLP4Rya/lib/python3.6/site-packages/thoth/storages/graph/janusgraph.py", line 212, in sync_analysis_result
#     python_package_version = PythonPackageVersion.construct(python_package_info)
#   File "/home/fpokorny/.virtualenvs/thoth-notebooks-7XLP4Rya/lib/python3.6/site-packages/thoth/storages/graph/models.py", line 68, in construct
#     name=package_info['result']['name'],
# KeyError: 'name'
# ERROR:thoth.storages.graph.janusgraph:Failed to sync Python package, error is not fatal: {'digests': {'manifest': '80e1bb9ec02b2665a22381a3ad2608214c9dd923'}, 'ecosystem': 'Python', 'path': '/opt/app-root/lib/python3.6/site-packages/numpy/polynomial/setup.py', 'result': {'error': 'no calls to setup found for: /tmp/tmp25bugu_h/rootfs/opt/app-root/lib/python3.6/site-packages/numpy/polynomial/setup.py'}}
# Traceback (most recent call last):
#   File "/home/fpokorny/.virtualenvs/thoth-notebooks-7XLP4Rya/lib/python3.6/site-packages/thoth/storages/graph/janusgraph.py", line 212, in sync_analysis_result
#     python_package_version = PythonPackageVersion.construct(python_package_info)
#   File "/home/fpokorny/.virtualenvs/thoth-notebooks-7XLP4Rya/lib/python3.6/site-packages/thoth/storages/graph/models.py", line 68, in construct
#     name=package_info['result']['name'],
# KeyError: 'name'
# ERROR:thoth.storages.graph.janusgraph:Failed to sync Python package, error is not fatal: {'digests': {'manifest': 'ae1f99cb8e4db2637f3e7a6f005fc1e4d26938f4'}, 'ecosystem': 'Python', 'path': '/opt/app-root/lib/python3.6/site-packages/numpy/random/setup.py', 'result': {'error': 'no calls to setup found for: /tmp/tmp25bugu_h/rootfs/opt/app-root/lib/python3.6/site-packages/numpy/random/setup.py'}}
# Traceback (most recent call last):
#   File "/home/fpokorny/.virtualenvs/thoth-notebooks-7XLP4Rya/lib/python3.6/site-packages/thoth/storages/graph/janusgraph.py", line 212, in sync_analysis_result
#     python_package_version = PythonPackageVersion.construct(python_package_info)
#   File "/home/fpokorny/.virtualenvs/thoth-notebooks-7XLP4Rya/lib/python3.6/site-packages/thoth/storages/graph/models.py", line 68, in construct
#     name=package_info['result']['name'],
# KeyError: 'name'
# ERROR:thoth.storages.graph.janusgraph:Failed to sync Python package, error is not fatal: {'digests': {'manifest': 'd8c348d3295b598533beaee4c02708bd997cc8ae'}, 'ecosystem': 'Python', 'path': '/opt/app-root/lib/python3.6/site-packages/numpy/setup.py', 'result': {'error': 'no calls to setup found for: /tmp/tmp25bugu_h/rootfs/opt/app-root/lib/python3.6/site-packages/numpy/setup.py'}}
# Traceback (most recent call last):
#   File "/home/fpokorny/.virtualenvs/thoth-notebooks-7XLP4Rya/lib/python3.6/site-packages/thoth/storages/graph/janusgraph.py", line 212, in sync_analysis_result
#     python_package_version = PythonPackageVersion.construct(python_package_info)
#   File "/home/fpokorny/.virtualenvs/thoth-notebooks-7XLP4Rya/lib/python3.6/site-packages/thoth/storages/graph/models.py", line 68, in construct
#     name=package_info['result']['name'],
# KeyError: 'name'
# ERROR:thoth.storages.graph.janusgraph:Failed to sync Python package, error is not fatal: {'digests': {'manifest': '5eacb723093dc6b1167569ed3d0c1e07d80068d9'}, 'ecosystem': 'Python', 'path': '/opt/app-root/lib/python3.6/site-packages/numpy/testing/setup.py', 'result': {'error': 'no calls to setup found for: /tmp/tmp25bugu_h/rootfs/opt/app-root/lib/python3.6/site-packages/numpy/testing/setup.py'}}
# Traceback (most recent call last):
#   File "/home/fpokorny/.virtualenvs/thoth-notebooks-7XLP4Rya/lib/python3.6/site-packages/thoth/storages/graph/janusgraph.py", line 212, in sync_analysis_result
#     python_package_version = PythonPackageVersion.construct(python_package_info)
#   File "/home/fpokorny/.virtualenvs/thoth-notebooks-7XLP4Rya/lib/python3.6/site-packages/thoth/storages/graph/models.py", line 68, in construct
#     name=package_info['result']['name'],
# KeyError: 'name'
# ERROR:thoth.storages.graph.janusgraph:Failed to sync Python package, error is not fatal: {'digests': {'manifest': '04ec62f06a556ebb1002efabddf91e1afb23a667'}, 'ecosystem': 'Python', 'path': '/opt/app-root/lib/python3.6/site-packages/scipy/_lib/setup.py'}
# Traceback (most recent call last):
#   File "/home/fpokorny/.virtualenvs/thoth-notebooks-7XLP4Rya/lib/python3.6/site-packages/thoth/storages/graph/janusgraph.py", line 212, in sync_analysis_result
#     python_package_version = PythonPackageVersion.construct(python_package_info)
#   File "/home/fpokorny/.virtualenvs/thoth-notebooks-7XLP4Rya/lib/python3.6/site-packages/thoth/storages/graph/models.py", line 68, in construct
#     name=package_info['result']['name'],
# KeyError: 'result'
# ERROR:thoth.storages.graph.janusgraph:Failed to sync Python package, error is not fatal: {'digests': {'manifest': 'ce918a00590fb744bff6748548a976ed385beeec'}, 'ecosystem': 'Python', 'path': '/opt/app-root/lib/python3.6/site-packages/scipy/cluster/setup.py', 'result': {'error': 'no calls to setup found for: /tmp/tmp25bugu_h/rootfs/opt/app-root/lib/python3.6/site-packages/scipy/cluster/setup.py'}}
# Traceback (most recent call last):
#   File "/home/fpokorny/.virtualenvs/thoth-notebooks-7XLP4Rya/lib/python3.6/site-packages/thoth/storages/graph/janusgraph.py", line 212, in sync_analysis_result
#     python_package_version = PythonPackageVersion.construct(python_package_info)
#   File "/home/fpokorny/.virtualenvs/thoth-notebooks-7XLP4Rya/lib/python3.6/site-packages/thoth/storages/graph/models.py", line 68, in construct
#     name=package_info['result']['name'],
# KeyError: 'name'
# ERROR:thoth.storages.graph.janusgraph:Failed to sync Python package, error is not fatal: {'digests': {'manifest': 'a9cdb32174db46e06cbf026e12053ec0fd603636'}, 'ecosystem': 'Python', 'path': '/opt/app-root/lib/python3.6/site-packages/scipy/constants/setup.py', 'result': {'error': 'no calls to setup found for: /tmp/tmp25bugu_h/rootfs/opt/app-root/lib/python3.6/site-packages/scipy/constants/setup.py'}}
# Traceback (most recent call last):
#   File "/home/fpokorny/.virtualenvs/thoth-notebooks-7XLP4Rya/lib/python3.6/site-packages/thoth/storages/graph/janusgraph.py", line 212, in sync_analysis_result
#     python_package_version = PythonPackageVersion.construct(python_package_info)
#   File "/home/fpokorny/.virtualenvs/thoth-notebooks-7XLP4Rya/lib/python3.6/site-packages/thoth/storages/graph/models.py", line 68, in construct
#     name=package_info['result']['name'],
# KeyError: 'name'
# ERROR:thoth.storages.graph.janusgraph:Failed to sync Python package, error is not fatal: {'digests': {'manifest': '827862f2272a8a45b0cf7cce2bcb3982e39c0262'}, 'ecosystem': 'Python', 'path': '/opt/app-root/lib/python3.6/site-packages/scipy/fftpack/setup.py', 'result': {'error': 'no calls to setup found for: /tmp/tmp25bugu_h/rootfs/opt/app-root/lib/python3.6/site-packages/scipy/fftpack/setup.py'}}
# Traceback (most recent call last):
#   File "/home/fpokorny/.virtualenvs/thoth-notebooks-7XLP4Rya/lib/python3.6/site-packages/thoth/storages/graph/janusgraph.py", line 212, in sync_analysis_result
#     python_package_version = PythonPackageVersion.construct(python_package_info)
#   File "/home/fpokorny/.virtualenvs/thoth-notebooks-7XLP4Rya/lib/python3.6/site-packages/thoth/storages/graph/models.py", line 68, in construct
#     name=package_info['result']['name'],
# KeyError: 'name'
# ERROR:thoth.storages.graph.janusgraph:Failed to sync Python package, error is not fatal: {'digests': {'manifest': 'a794ac17cc43b567d6528e2eaca1ee37e535e6d8'}, 'ecosystem': 'Python', 'path': '/opt/app-root/lib/python3.6/site-packages/scipy/integrate/setup.py', 'result': {'error': 'no calls to setup found for: /tmp/tmp25bugu_h/rootfs/opt/app-root/lib/python3.6/site-packages/scipy/integrate/setup.py'}}
# Traceback (most recent call last):
#   File "/home/fpokorny/.virtualenvs/thoth-notebooks-7XLP4Rya/lib/python3.6/site-packages/thoth/storages/graph/janusgraph.py", line 212, in sync_analysis_result
#     python_package_version = PythonPackageVersion.construct(python_package_info)
#   File "/home/fpokorny/.virtualenvs/thoth-notebooks-7XLP4Rya/lib/python3.6/site-packages/thoth/storages/graph/models.py", line 68, in construct
#     name=package_info['result']['name'],
# KeyError: 'name'
# ERROR:thoth.storages.graph.janusgraph:Failed to sync Python package, error is not fatal: {'digests': {'manifest': 'ed61f87e14fc94fddec16b143deb39f56014945b'}, 'ecosystem': 'Python', 'path': '/opt/app-root/lib/python3.6/site-packages/scipy/interpolate/setup.py', 'result': {'error': 'no calls to setup found for: /tmp/tmp25bugu_h/rootfs/opt/app-root/lib/python3.6/site-packages/scipy/interpolate/setup.py'}}
# Traceback (most recent call last):
#   File "/home/fpokorny/.virtualenvs/thoth-notebooks-7XLP4Rya/lib/python3.6/site-packages/thoth/storages/graph/janusgraph.py", line 212, in sync_analysis_result
#     python_package_version = PythonPackageVersion.construct(python_package_info)
#   File "/home/fpokorny/.virtualenvs/thoth-notebooks-7XLP4Rya/lib/python3.6/site-packages/thoth/storages/graph/models.py", line 68, in construct
#     name=package_info['result']['name'],
# KeyError: 'name'
# ERROR:thoth.storages.graph.janusgraph:Failed to sync Python package, error is not fatal: {'digests': {'manifest': '107a91a9af82f00f7c111f08df67a88b47c63685'}, 'ecosystem': 'Python', 'path': '/opt/app-root/lib/python3.6/site-packages/scipy
setup.py'}}
# Traceback (most recent call last):
#   File "/home/fpokorny/.virtualenvs/thoth-notebooks-7XLP4Rya/lib/python3.6/site-packages/thoth/storages/graph/janusgraph.py", line 212, in sync_analysis_result
#     python_package_version = PythonPackageVersion.construct(python_package_info)
#   File "/home/fpokorny/.virtualenvs/thoth-notebooks-7XLP4Rya/lib/python3.6/site-packages/thoth/storages/graph/models.py", line 68, in construct
#     name=package_info['result']['name'],
# KeyError: 'name'
# ERROR:thoth.storages.graph.janusgraph:Failed to sync Python package, error is not fatal: {'digests': {'manifest': 'b2183d87a0f616fb13a0c50c5806cc51e2929d61'}, 'ecosystem': 'Python', 'path': '/opt/app-root/lib/python3.6/site-packages/sklearn/setup.py', 'result': {'error': 'no calls to setup found for: /tmp/tmp25bugu_h/rootfs/opt/app-root/lib/python3.6/site-packages/sklearn/setup.py'}}
# Traceback (most recent call last):
#   File "/home/fpokorny/.virtualenvs/thoth-notebooks-7XLP4Rya/lib/python3.6/site-packages/thoth/storages/graph/janusgraph.py", line 212, in sync_analysis_result
#     python_package_version = PythonPackageVersion.construct(python_package_info)
#   File "/home/fpokorny/.virtualenvs/thoth-notebooks-7XLP4Rya/lib/python3.6/site-packages/thoth/storages/graph/models.py", line 68, in construct
#     name=package_info['result']['name'],
# KeyError: 'name'
# ERROR:thoth.storages.graph.janusgraph:Failed to sync Python package, error is not fatal: {'digests': {'manifest': '7ca0e496eb01411d2048e5ce73137dcb20e24324'}, 'ecosystem': 'Python', 'path': '/opt/app-root/lib/python3.6/site-packages/sklearn/svm/setup.py', 'result': {'error': 'no calls to setup found for: /tmp/tmp25bugu_h/rootfs/opt/app-root/lib/python3.6/site-packages/sklearn/svm/setup.py'}}
# Traceback (most recent call last):
#   File "/home/fpokorny/.virtualenvs/thoth-notebooks-7XLP4Rya/lib/python3.6/site-packages/thoth/storages/graph/janusgraph.py", line 212, in sync_analysis_result
#     python_package_version = PythonPackageVersion.construct(python_package_info)
#   File "/home/fpokorny/.virtualenvs/thoth-notebooks-7XLP4Rya/lib/python3.6/site-packages/thoth/storages/graph/models.py", line 68, in construct
#     name=package_info['result']['name'],
# KeyError: 'name'
# ERROR:thoth.storages.graph.janusgraph:Failed to sync Python package, error is not fatal: {'digests': {'manifest': '5f8d9458e44f097b60e09456292f2bbd896a75f6'}, 'ecosystem': 'Python', 'path': '/opt/app-root/lib/python3.6/site-packages/sklearn/tree/setup.py', 'result': {'error': 'no calls to setup found for: /tmp/tmp25bugu_h/rootfs/opt/app-root/lib/python3.6/site-packages/sklearn/tree/setup.py'}}
# Traceback (most recent call last):
#   File "/home/fpokorny/.virtualenvs/thoth-notebooks-7XLP4Rya/lib/python3.6/site-packages/thoth/storages/graph/janusgraph.py", line 212, in sync_analysis_result
#     python_package_version = PythonPackageVersion.construct(python_package_info)
#   File "/home/fpokorny/.virtualenvs/thoth-notebooks-7XLP4Rya/lib/python3.6/site-packages/thoth/storages/graph/models.py", line 68, in construct
#     name=package_info['result']['name'],
# KeyError: 'name'
# ERROR:thoth.storages.graph.janusgraph:Failed to sync Python package, error is not fatal: {'digests': {'manifest': 'e47b1d5e9b1d2a2cd0554e848bce6441d2209360'}, 'ecosystem': 'Python', 'path': '/opt/app-root/lib/python3.6/site-packages/sklearn/utils/setup.py', 'result': {'error': 'no calls to setup found for: /tmp/tmp25bugu_h/rootfs/opt/app-root/lib/python3.6/site-packages/sklearn/utils/setup.py'}}
# Traceback (most recent call last):
#   File "/home/fpokorny/.virtualenvs/thoth-notebooks-7XLP4Rya/lib/python3.6/site-packages/thoth/storages/graph/janusgraph.py", line 212, in sync_analysis_result
#     python_package_version = PythonPackageVersion.construct(python_package_info)
#   File "/home/fpokorny/.virtualenvs/thoth-notebooks-7XLP4Rya/lib/python3.6/site-packages/thoth/storages/graph/models.py", line 68, in construct
#     name=package_info['result']['name'],
# KeyError: 'name'
# ERROR:thoth.storages.graph.janusgraph:Failed to sync Python package, error is not fatal: {'digests': {'manifest': '1855857cc844a266cf9d8092d7fe038dad254b5b'}, 'ecosystem': 'Python', 'path': '/opt/app-root/lib/python3.6/site-packages/sklearn/utils/sparsetools/setup.py', 'result': {'error': 'no calls to setup found for: /tmp/tmp25bugu_h/rootfs/opt/app-root/lib/python3.6/site-packages/sklearn/utils/sparsetools/setup.py'}}
# Traceback (most recent call last):
#   File "/home/fpokorny/.virtualenvs/thoth-notebooks-7XLP4Rya/lib/python3.6/site-packages/thoth/storages/graph/janusgraph.py", line 212, in sync_analysis_result
#     python_package_version = PythonPackageVersion.construct(python_package_info)
#   File "/home/fpokorny/.virtualenvs/thoth-notebooks-7XLP4Rya/lib/python3.6/site-packages/thoth/storages/graph/models.py", line 68, in construct
#     name=package_info['result']['name'],
# KeyError: 'name'
# ERROR:thoth.storages.graph.janusgraph:Failed to sync Python package, error is not fatal: {'digests': {'manifest': 'a2aae58dbc144ace99c9ca9306619ceb07e0fe11'}, 'ecosystem': 'Python-RequirementsTXT', 'path': '/opt/app-root/share/doc/networkx-2.1/requirements.txt', 'result': {'dependencies': ['-r requirements/default.txt', '-r requirements/test.txt']}}
# Traceback (most recent call last):
#   File "/home/fpokorny/.virtualenvs/thoth-notebooks-7XLP4Rya/lib/python3.6/site-packages/thoth/storages/graph/janusgraph.py", line 212, in sync_analysis_result
#     python_package_version = PythonPackageVersion.construct(python_package_info)
#   File "/home/fpokorny/.virtualenvs/thoth-notebooks-7XLP4Rya/lib/python3.6/site-packages/thoth/storages/graph/models.py", line 68, in construct
#     name=package_info['result']['name'],
# KeyError: 'name'
# CPU times: user 32.5 s, sys: 827 ms, total: 33.4 s
# Wall time: 2min 54s

# %%
print(f"Number of vertexes present in graph: {gqr(graph_db.g.V().count().next()).result:d}")
# Out:
# Number of vertexes present in graph: 2827

# %%
print(f"Number of edges present in graph: {gqr(graph_db.g.E().count().next()).result:d}")
# Out:
# Number of edges present in graph: 9515

# %% [markdown]
# ## Syncing solver results - without adapter cache

# %%
gqr(graph_db.g.V().drop().next())
assert gqr(graph_db.g.V().count().next()).result == 0

# %%
solver_document = solver_results.retrieve_document('fridex-thoth-solver-fc27-thoth-solver-fc27-92qtv')

# %%
# %%time
# %env THOTH_STORAGES_DISABLE_CACHE=1

graph_db.sync_solver_result(solver_document)
# Out:
# DEBUG:thoth.storages.graph.utils:Disabling edge graph cache
# DEBUG:thoth.storages.graph.utils:Disabling vertex graph cache
# env: THOTH_STORAGES_DISABLE_CACHE=1
# CPU times: user 41.7 s, sys: 2.08 s, total: 43.8 s
# Wall time: 10min 29s

# %%
print(f"Number of vertexes present in graph: {gqr(graph_db.g.V().count().next()).result:d}")
# Out:
# Number of vertexes present in graph: 653

# %%
print(f"Number of edges present in graph: {gqr(graph_db.g.E().count().next()).result:d}")
# Out:
# Number of edges present in graph: 9075

# %% [markdown]
# ## Syncing solver results - with adapter cache

# %%
gqr(graph_db.g.V().drop().next())
assert gqr(graph_db.g.V().count().next()).result == 0

# %%
# %%time
# %env THOTH_STORAGES_DISABLE_CACHE=0

graph_db.sync_solver_result(solver_document)
# Out:
# DEBUG:thoth.storages.graph.utils:Enabling edge graph cache
# DEBUG:thoth.storages.graph.utils:Enabling vertex graph cache
# env: THOTH_STORAGES_DISABLE_CACHE=0
# CPU times: user 27.5 s, sys: 799 ms, total: 28.3 s
# Wall time: 1min 26s

# %%
print(f"Number of vertexes present in graph: {gqr(graph_db.g.V().count().next()).result:d}")
# Out:
# Number of vertexes present in graph: 653

# %%
print(f"Number of edges present in graph: {gqr(graph_db.g.E().count().next()).result:d}")
# Out:
# Number of edges present in graph: 9075
