# %% [markdown]
# # Accessing results of Thoth's analyzers

# %% [markdown]
# This notebook will guide you on how to use thoth storage adapters for analyzer results so that you can access data that are stored on Ceph in a safe way.
#
#
# ## Accessing solver results
#
# Let's first focus on the `SolverResultsStore` adapter that gives you an ability to access data about packages that were extracted based on package version range resolution. Let's import the adapter first:

# %%
from thoth.lab import obtain_location
from thoth.storages import SolverResultsStore

# %% [markdown]
# As you can see above, we also imported function `obtain_location()` that makes sure you will access correct Thoth's Ceph instance. To instantiate this adapter, this Jupyter notebook has to have present credentials in environment variables as well as information about backet that should be accessed. If that is the case, adapter will automatically pick these environment variables and make sure you access correct documents. Otherwise you need to explicitly state adapter configuration on instantiation:

# %%
# Obtain host of the Ceph instance that is available on the upshift cluster - we will explicitly use that instance.
# This can be also accessible via env variables so no need to state it explicitly.
THOTH_LOCATION = obtain_location('thoth-upshift-ceph', verify=False)

solver_results = SolverResultsStore(
    'thoth-sbu',  # Name of Thoth deployment, we are acessing thoth data that is available on SBU cluster.
    host=THOTH_LOCATION,  # Optionally explicit.
    # These are available in Jupyter envirnment, if not, you need to explicitly provide them.
    #key_id='TBD',
    #secret_key='TBD',
    #bucket='TBD'
)


solver_results.connect()

# %% [markdown]
# Now we can check what methods are available to list, retrieve or store data on Ceph (if you have sufficient privileges):

# %%
help(solver_results)
# Out:
# Help on SolverResultsStore in module thoth.storages.solvers object:
#
# class SolverResultsStore(thoth.storages.result_base.ResultStorageBase)
#  |  Adapter base for storing results.
#  |
#  |  Method resolution order:
#  |      SolverResultsStore
#  |      thoth.storages.result_base.ResultStorageBase
#  |      thoth.storages.base.StorageBase
#  |      builtins.object
#  |
#  |  Data and other attributes defined here:
#  |
#  |  RESULT_TYPE = 'solver'
#  |
#  |  __abstractmethods__ = frozenset()
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from thoth.storages.result_base.ResultStorageBase:
#  |
#  |  __init__(self, deployment_name=None, *, host:str=None, key_id:str=None, secret_key:str=None, bucket:str=None, region:str=None)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  connect(self) -> None
#  |      Connect the given storage adapter.
#  |
#  |  get_document_listing(self) -> Generator[str, NoneType, NoneType]
#  |      Get listing of documents available in Ceph as a generator.
#  |
#  |  is_connected(self) -> bool
#  |      Check if the given database adapter is in connected state.
#  |
#  |  iterate_results(self) -> Generator[tuple, NoneType, NoneType]
#  |      Iterate over results available in the Ceph.
#  |
#  |  retrieve_document(self, document_id:str) -> dict
#  |      Retrieve a document from Ceph by its id.
#  |
#  |  store_document(self, document:dict) -> str
#  |      Store the given document in Ceph.
#  |
#  |  ----------------------------------------------------------------------
#  |  Class methods inherited from thoth.storages.result_base.ResultStorageBase:
#  |
#  |  get_document_id(document:dict) -> str from abc.ABCMeta
#  |      Get document id under which the given document should be stored.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors inherited from thoth.storages.base.StorageBase:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)

# %% [markdown]
# Now, let's get document ids of first 10 solver results available on Ceph:

# %%
from itertools import islice

list(islice(solver_results.get_document_listing(), 10))
# Out:
# ['fridex-thoth-solver-fc27-thoth-solver-fc27-1kb10',
#  'fridex-thoth-solver-fc27-thoth-solver-fc27-3bs80',
#  'fridex-thoth-solver-fc27-thoth-solver-fc27-3w5w8',
#  'fridex-thoth-solver-fc27-thoth-solver-fc27-44q8r',
#  'fridex-thoth-solver-fc27-thoth-solver-fc27-4v04m',
#  'fridex-thoth-solver-fc27-thoth-solver-fc27-57mrc',
#  'fridex-thoth-solver-fc27-thoth-solver-fc27-5c883',
#  'fridex-thoth-solver-fc27-thoth-solver-fc27-5k2kk',
#  'fridex-thoth-solver-fc27-thoth-solver-fc27-5swrl',
#  'fridex-thoth-solver-fc27-thoth-solver-fc27-61cm4']

# %% [markdown]
# And let's try to retrieve a document with some document id available in the listing above:

# %%
solver_results.retrieve_document('fridex-thoth-solver-fc27-thoth-solver-fc27-1kb10')
# Out:
# {'metadata': {'analyzer': 'thoth-solver',
#   'analyzer_version': '1.0.0rc2',
#   'arguments': {'pypi': {'exclude_packages': None,
#     'index': None,
#     'no_pretty': False,
#     'no_transitive': True,
#     'output': 'http://thoth-result-api/api/v1/solver-result',
#     'requirements': 'scipy'},
#    'thoth-solver': {'no_color': False, 'verbose': True}},
#   'datetime': '2018-03-14T20:51:09.341614',
#   'distribution': {'codename': 'Twenty Seven',
#    'id': 'fedora',
#    'like': '',
#    'version': '27',
#    'version_parts': {'build_number': '', 'major': '27', 'minor': ''}},
#   'hostname': 'fridex-thoth-solver-fc27-thoth-solver-fc27-1kb10',
#   'python': {'api_version': 1013,
#    'implementation_name': 'cpython',
#    'major': 3,
#    'micro': 4,
#    'minor': 6,
#    'releaselevel': 'final',
#    'serial': 0}},
#  'result': {'environment': [{'dependencies': [],
#     'package_name': 'virtualenv',
#     'package_version': '15.1.0'},
#    {'dependencies': [], 'package_name': 'urllib3', 'package_version': '1.22'},
#    {'dependencies': [{'package_name': 'click', 'required_version': None},
#      {'package_name': 'rainbow-logging-handler', 'required_version': None},
#      {'package_name': 'pip', 'required_version': None},
#      {'package_name': 'virtualenv', 'required_version': None},
#      {'package_name': 'pipdeptree', 'required_version': None},
#      {'package_name': 'hashin', 'required_version': None},
#      {'package_name': 'thoth-analyzer', 'required_version': '>=0.0.2'}],
#     'package_name': 'thoth-solver',
#     'package_version': '1.0.0rc2'},
#    {'dependencies': [{'package_name': 'requests',
#       'required_version': '==2.18.4'},
#      {'package_name': 'click', 'required_version': '==6.7'},
#      {'package_name': 'distro', 'required_version': '==1.2.0'},
#      {'package_name': 'pexpect', 'required_version': '==4.4.0'},
#      {'package_name': 'certifi', 'required_version': '==2018.1.18'},
#      {'package_name': 'ptyprocess', 'required_version': '==0.5.2'},
#      {'package_name': 'idna', 'required_version': '==2.6'},
#      {'package_name': 'chardet', 'required_version': '==3.0.4'},
#      {'package_name': 'urllib3', 'required_version': '==1.22'},
#      {'package_name': 'delegator.py', 'required_version': '==0.1.0'}],
#     'package_name': 'thoth-analyzer',
#     'package_version': '0.0.4'},
#    {'dependencies': [{'package_name': 'idna',
#       'required_version': '>=2.5,<2.7'},
#      {'package_name': 'certifi', 'required_version': '>=2017.4.17'},
#      {'package_name': 'chardet', 'required_version': '>=3.0.2,<3.1.0'},
#      {'package_name': 'urllib3', 'required_version': '<1.23,>=1.21.1'}],
#     'package_name': 'requests',
#     'package_version': '2.18.4'},
#    {'dependencies': [{'package_name': 'logutils', 'required_version': None},
#      {'package_name': 'colorama', 'required_version': None}],
#     'package_name': 'rainbow-logging-handler',
#     'package_version': '2.2.2'},
#    {'dependencies': [],
#     'package_name': 'ptyprocess',
#     'package_version': '0.5.2'},
#    {'dependencies': [{'package_name': 'pip', 'required_version': '>=6.0.0'}],
#     'package_name': 'pipdeptree',
#     'package_version': '0.11.0'},
#    {'dependencies': [{'package_name': 'ptyprocess',
#       'required_version': '>=0.5'}],
#     'package_name': 'pexpect',
#     'package_version': '4.4.0'},
#    {'dependencies': [],
#     'package_name': 'logutils',
#     'package_version': '0.3.5'},
#    {'dependencies': [], 'package_name': 'idna', 'package_version': '2.6'},
#    {'dependencies': [], 'package_name': 'hashin', 'package_version': '0.11.5'},
#    {'dependencies': [], 'package_name': 'distro', 'package_version': '1.2.0'},
#    {'dependencies': [{'package_name': 'pexpect',
#       'required_version': '>=4.1.0'}],
#     'package_name': 'delegator.py',
#     'package_version': '0.1.0'},
#    {'dependencies': [],
#     'package_name': 'colorama',
#     'package_version': '0.3.9'},
#    {'dependencies': [], 'package_name': 'click', 'package_version': '6.7'},
#    {'dependencies': [], 'package_name': 'chardet', 'package_version': '3.0.4'},
#    {'dependencies': [],
#     'package_name': 'certifi',
#     'package_version': '2018.1.18'},
#    {'dependencies': [], 'package_name': 'rpm', 'package_version': '4.14.1'},
#    {'dependencies': [], 'package_name': 'gpg', 'package_version': '1.9.0'},
#    {'dependencies': [], 'package_name': 'six', 'package_version': '1.11.0'},
#    {'dependencies': [],
#     'package_name': 'setuptools',
#     'package_version': '37.0.0'},
#    {'dependencies': [], 'package_name': 'pip', 'package_version': '9.0.1'},
#    {'dependencies': [{'package_name': 'six', 'required_version': None}],
#     'package_name': 'iniparse',
#     'package_version': '0.4'}],
#   'errors': [{'details': {'command': 'python3 -m pip install --force-reinstall --user --no-cache-dir --no-deps scipy==0.18.0',
#      'message': 'Command exited with non-zero status code (1): Command "python setup.py egg_info" failed with error code 1 in /tmp/pip-build-amih_gt4/scipy/\n',
#      'return_code': 1,
#      'stderr': 'Command "python setup.py egg_info" failed with error code 1 in /tmp/pip-build-amih_gt4/scipy/\n',
#      'stdout': 'Collecting scipy==0.18.0\n  Downloading scipy-0.18.0.tar.gz (13.2MB)\n    Complete output from command python setup.py egg_info:\n    /bin/sh: svnversion: command not found\n    /bin/sh: svnversion: command not found\n    non-existing path in \'numpy/distutils\': \'site.cfg\'\n    Could not locate executable gfortran\n    Could not locate executable f95\n    Could not locate executable ifort\n    Could not locate executable ifc\n    Could not locate executable lf95\n    Could not locate executable pgfortran\n    Could not locate executable f90\n    Could not locate executable f77\n    Could not locate executable fort\n    Could not locate executable efort\n    Could not locate executable efc\n    Could not locate executable g77\n    Could not locate executable g95\n    Could not locate executable pathf95\n    Could not locate executable nagfor\n    don\'t know how to compile Fortran code on platform \'posix\'\n    Running from numpy source directory.\n    /tmp/easy_install-tg_ld3fz/numpy-1.14.2/setup.py:369: UserWarning: Unrecognized setuptools command, proceeding with generating Cython sources and expanding templates\n      run_build = parse_setuppy_commands()\n    /tmp/easy_install-tg_ld3fz/numpy-1.14.2/numpy/distutils/system_info.py:624: UserWarning:\n        Atlas (http://math-atlas.sourceforge.net/) libraries not found.\n        Directories to search for the libraries can be specified in the\n        numpy/distutils/site.cfg file (section [atlas]) or by setting\n        the ATLAS environment variable.\n      self.calc_info()\n    /tmp/easy_install-tg_ld3fz/numpy-1.14.2/numpy/distutils/system_info.py:624: UserWarning:\n        Blas (http://www.netlib.org/blas/) libraries not found.\n        Directories to search for the libraries can be specified in the\n        numpy/distutils/site.cfg file (section [blas]) or by setting\n        the BLAS environment variable.\n      self.calc_info()\n    /tmp/easy_install-tg_ld3fz/numpy-1.14.2/numpy/distutils/system_info.py:624: UserWarning:\n        Blas (http://www.netlib.org/blas/) sources not found.\n        Directories to search for the sources can be specified in the\n        numpy/distutils/site.cfg file (section [blas_src]) or by setting\n        the BLAS_SRC environment variable.\n      self.calc_info()\n    /tmp/easy_install-tg_ld3fz/numpy-1.14.2/numpy/distutils/system_info.py:624: UserWarning:\n        Lapack (http://www.netlib.org/lapack/) libraries not found.\n        Directories to search for the libraries can be specified in the\n        numpy/distutils/site.cfg file (section [lapack]) or by setting\n        the LAPACK environment variable.\n      self.calc_info()\n    /tmp/easy_install-tg_ld3fz/numpy-1.14.2/numpy/distutils/system_info.py:624: UserWarning:\n        Lapack (http://www.netlib.org/lapack/) sources not found.\n        Directories to search for the sources can be specified in the\n        numpy/distutils/site.cfg file (section [lapack_src]) or by setting\n        the LAPACK_SRC environment variable.\n      self.calc_info()\n    /usr/lib64/python3.6/distutils/dist.py:261: UserWarning: Unknown distribution option: \'define_macros\'\n      warnings.warn(msg)\n    Traceback (most recent call last):\n      File "/usr/lib/python3.6/site-packages/setuptools/sandbox.py", line 154, in save_modules\n        yield saved\n      File "/usr/lib/python3.6/site-packages/setuptools/sandbox.py", line 195, in setup_context\n        yield\n      File "/usr/lib/python3.6/site-packages/setuptools/sandbox.py", line 250, in run_setup\n        _execfile(setup_script, ns)\n      File "/usr/lib/python3.6/site-packages/setuptools/sandbox.py", line 45, in _execfile\n        exec(code, globals, locals)\n      File "/tmp/easy_install-tg_ld3fz/numpy-1.14.2/setup.py", line 394, in <module>\n        if run_build:\n      File "/tmp/easy_install-tg_ld3fz/numpy-1.14.2/setup.py", line 386, in setup_package\n        # Raise errors for unsupported commands, improve help output, etc.\n ...
#      'timeout': 60},
#     'package_name': 'scipy',
#     'type': 'command_error',
#     'version': '0.18.0'},
#    {'details': {'command': 'python3 -m pip install --force-reinstall --user --no-cache-dir --no-deps scipy==0.18.0rc2',
#      'message': 'Command exited with non-zero status code (1): Command "python setup.py egg_info" failed with error code 1 in /tmp/pip-build-g36etvoa/scipy/\n',
#      'return_code': 1,
#      'stderr': 'Command "python setup.py egg_info" failed with error code 1 in /tmp/pip-build-g36etvoa/scipy/\n',
#      'stdout': 'Collecting scipy==0.18.0rc2\n  Downloading scipy-0.18.0rc2.zip (14.6MB)\n    Complete output from command python setup.py egg_info:\n    /bin/sh: svnversion: command not found\n    /bin/sh: svnversion: command not found\n    non-existing path in \'numpy/distutils\': \'site.cfg\'\n    Could not locate executable gfortran\n    Could not locate executable f95\n    Could not locate executable ifort\n    Could not locate executable ifc\n    Could not locate executable lf95\n    Could not locate executable pgfortran\n    Could not locate executable f90\n    Could not locate executable f77\n    Could not locate executable fort\n    Could not locate executable efort\n    Could not locate executable efc\n    Could not locate executable g77\n    Could not locate executable g95\n    Could not locate executable pathf95\n    Could not locate executable nagfor\n    don\'t know how to compile Fortran code on platform \'posix\'\n    Running from numpy source directory.\n    /tmp/easy_install-jdtut24x/numpy-1.14.2/setup.py:369: UserWarning: Unrecognized setuptools command, proceeding with generating Cython sources and expanding templates\n      run_build = parse_setuppy_commands()\n    /tmp/easy_install-jdtut24x/numpy-1.14.2/numpy/distutils/system_info.py:624: UserWarning:\n        Atlas (http://math-atlas.sourceforge.net/) libraries not found.\n        Directories to search for the libraries can be specified in the\n        numpy/distutils/site.cfg file (section [atlas]) or by setting\n        the ATLAS environment variable.\n      self.calc_info()\n    /tmp/easy_install-jdtut24x/numpy-1.14.2/numpy/distutils/system_info.py:624: UserWarning:\n        Blas (http://www.netlib.org/blas/) libraries not found.\n        Directories to search for the libraries can be specified in the\n        numpy/distutils/site.cfg file (section [blas]) or by setting\n        the BLAS environment variable.\n      self.calc_info()\n    /tmp/easy_install-jdtut24x/numpy-1.14.2/numpy/distutils/system_info.py:624: UserWarning:\n        Blas (http://www.netlib.org/blas/) sources not found.\n        Directories to search for the sources can be specified in the\n        numpy/distutils/site.cfg file (section [blas_src]) or by setting\n        the BLAS_SRC environment variable.\n      self.calc_info()\n    /tmp/easy_install-jdtut24x/numpy-1.14.2/numpy/distutils/system_info.py:624: UserWarning:\n        Lapack (http://www.netlib.org/lapack/) libraries not found.\n        Directories to search for the libraries can be specified in the\n        numpy/distutils/site.cfg file (section [lapack]) or by setting\n        the LAPACK environment variable.\n      self.calc_info()\n    /tmp/easy_install-jdtut24x/numpy-1.14.2/numpy/distutils/system_info.py:624: UserWarning:\n        Lapack (http://www.netlib.org/lapack/) sources not found.\n        Directories to search for the sources can be specified in the\n        numpy/distutils/site.cfg file (section [lapack_src]) or by setting\n        the LAPACK_SRC environment variable.\n      self.calc_info()\n    /usr/lib64/python3.6/distutils/dist.py:261: UserWarning: Unknown distribution option: \'define_macros\'\n      warnings.warn(msg)\n    Traceback (most recent call last):\n      File "/usr/lib/python3.6/site-packages/setuptools/sandbox.py", line 154, in save_modules\n        yield saved\n      File "/usr/lib/python3.6/site-packages/setuptools/sandbox.py", line 195, in setup_context\n        yield\n      File "/usr/lib/python3.6/site-packages/setuptools/sandbox.py", line 250, in run_setup\n        _execfile(setup_script, ns)\n      File "/usr/lib/python3.6/site-packages/setuptools/sandbox.py", line 45, in _execfile\n        exec(code, globals, locals)\n      File "/tmp/easy_install-jdtut24x/numpy-1.14.2/setup.py", line 394, in <module>\n        if run_build:\n      File "/tmp/easy_install-jdtut24x/numpy-1.14.2/setup.py", line 386, in setup_package\n        # Raise errors for unsupported commands, improve help output, etc ...
#      'timeout': 60},
#     'package_name': 'scipy',
#     'type': 'command_error',
#     'version': '0.18.0rc2'},
#    {'details': {'command': 'python3 -m pip install --force-reinstall --user --no-cache-dir --no-deps scipy==0.17.1',
#      'message': 'Command exited with non-zero status code (1): Command "python setup.py egg_info" failed with error code 1 in /tmp/pip-build-7nsxpgxw/scipy/\n',
#      'return_code': 1,
#      'stderr': 'Command "python setup.py egg_info" failed with error code 1 in /tmp/pip-build-7nsxpgxw/scipy/\n',
#      'stdout': 'Collecting scipy==0.17.1\n  Downloading scipy-0.17.1.tar.gz (12.4MB)\n    Complete output from command python setup.py egg_info:\n    /bin/sh: svnversion: command not found\n    /bin/sh: svnversion: command not found\n    non-existing path in \'numpy/distutils\': \'site.cfg\'\n    Could not locate executable gfortran\n    Could not locate executable f95\n    Could not locate executable ifort\n    Could not locate executable ifc\n    Could not locate executable lf95\n    Could not locate executable pgfortran\n    Could not locate executable f90\n    Could not locate executable f77\n    Could not locate executable fort\n    Could not locate executable efort\n    Could not locate executable efc\n    Could not locate executable g77\n    Could not locate executable g95\n    Could not locate executable pathf95\n    Could not locate executable nagfor\n    don\'t know how to compile Fortran code on platform \'posix\'\n    Running from numpy source directory.\n    /tmp/easy_install-989d9yk8/numpy-1.14.2/setup.py:369: UserWarning: Unrecognized setuptools command, proceeding with generating Cython sources and expanding templates\n      run_build = parse_setuppy_commands()\n    /tmp/easy_install-989d9yk8/numpy-1.14.2/numpy/distutils/system_info.py:624: UserWarning:\n        Atlas (http://math-atlas.sourceforge.net/) libraries not found.\n        Directories to search for the libraries can be specified in the\n        numpy/distutils/site.cfg file (section [atlas]) or by setting\n        the ATLAS environment variable.\n      self.calc_info()\n    /tmp/easy_install-989d9yk8/numpy-1.14.2/numpy/distutils/system_info.py:624: UserWarning:\n        Blas (http://www.netlib.org/blas/) libraries not found.\n        Directories to search for the libraries can be specified in the\n        numpy/distutils/site.cfg file (section [blas]) or by setting\n        the BLAS environment variable.\n      self.calc_info()\n    /tmp/easy_install-989d9yk8/numpy-1.14.2/numpy/distutils/system_info.py:624: UserWarning:\n        Blas (http://www.netlib.org/blas/) sources not found.\n        Directories to search for the sources can be specified in the\n        numpy/distutils/site.cfg file (section [blas_src]) or by setting\n        the BLAS_SRC environment variable.\n      self.calc_info()\n    /tmp/easy_install-989d9yk8/numpy-1.14.2/numpy/distutils/system_info.py:624: UserWarning:\n        Lapack (http://www.netlib.org/lapack/) libraries not found.\n        Directories to search for the libraries can be specified in the\n        numpy/distutils/site.cfg file (section [lapack]) or by setting\n        the LAPACK environment variable.\n      self.calc_info()\n    /tmp/easy_install-989d9yk8/numpy-1.14.2/numpy/distutils/system_info.py:624: UserWarning:\n        Lapack (http://www.netlib.org/lapack/) sources not found.\n        Directories to search for the sources can be specified in the\n        numpy/distutils/site.cfg file (section [lapack_src]) or by setting\n        the LAPACK_SRC environment variable.\n      self.calc_info()\n    /usr/lib64/python3.6/distutils/dist.py:261: UserWarning: Unknown distribution option: \'define_macros\'\n      warnings.warn(msg)\n    Traceback (most recent call last):\n      File "/usr/lib/python3.6/site-packages/setuptools/sandbox.py", line 154, in save_modules\n        yield saved\n      File "/usr/lib/python3.6/site-packages/setuptools/sandbox.py", line 195, in setup_context\n        yield\n      File "/usr/lib/python3.6/site-packages/setuptools/sandbox.py", line 250, in run_setup\n        _execfile(setup_script, ns)\n      File "/usr/lib/python3.6/site-packages/setuptools/sandbox.py", line 45, in _execfile\n        exec(code, globals, locals)\n      File "/tmp/easy_install-989d9yk8/numpy-1.14.2/setup.py", line 394, in <module>\n      File "/tmp/easy_install-989d9yk8/numpy-1.14.2/setup.py", line 386, in setup_package\n      File "/tmp/easy_install-989d9yk8/numpy-1.14.2/numpy/distutils/core.py", line 169, in setup\n  ...
#      'timeout': 60},
#     'package_name': 'scipy',
#     'type': 'command_error',
#     'version': '0.17.1'},
#    {'details': {'command': 'python3 -m pip install --force-reinstall --user --no-cache-dir --no-deps scipy==0.17.0',
#      'message': 'Command exited with non-zero status code (1): Command "python setup.py egg_info" failed with error code 1 in /tmp/pip-build-qrvphdz9/scipy/\n',
#      'return_code': 1,
#      'stderr': 'Command "python setup.py egg_info" failed with error code 1 in /tmp/pip-build-qrvphdz9/scipy/\n',
#      'stdout': 'Collecting scipy==0.17.0\n  Downloading scipy-0.17.0.tar.gz (12.4MB)\n    Complete output from command python setup.py egg_info:\n    /bin/sh: svnversion: command not found\n    /bin/sh: svnversion: command not found\n    non-existing path in \'numpy/distutils\': \'site.cfg\'\n    Could not locate executable gfortran\n    Could not locate executable f95\n    Could not locate executable ifort\n    Could not locate executable ifc\n    Could not locate executable lf95\n    Could not locate executable pgfortran\n    Could not locate executable f90\n    Could not locate executable f77\n    Could not locate executable fort\n    Could not locate executable efort\n    Could not locate executable efc\n    Could not locate executable g77\n    Could not locate executable g95\n    Could not locate executable pathf95\n    Could not locate executable nagfor\n    don\'t know how to compile Fortran code on platform \'posix\'\n    Running from numpy source directory.\n    /tmp/easy_install-yzkhaqlt/numpy-1.14.2/setup.py:369: UserWarning: Unrecognized setuptools command, proceeding with generating Cython sources and expanding templates\n      run_build = parse_setuppy_commands()\n    /tmp/easy_install-yzkhaqlt/numpy-1.14.2/numpy/distutils/system_info.py:624: UserWarning:\n        Atlas (http://math-atlas.sourceforge.net/) libraries not found.\n        Directories to search for the libraries can be specified in the\n        numpy/distutils/site.cfg file (section [atlas]) or by setting\n        the ATLAS environment variable.\n      self.calc_info()\n    /tmp/easy_install-yzkhaqlt/numpy-1.14.2/numpy/distutils/system_info.py:624: UserWarning:\n        Blas (http://www.netlib.org/blas/) libraries not found.\n        Directories to search for the libraries can be specified in the\n        numpy/distutils/site.cfg file (section [blas]) or by setting\n        the BLAS environment variable.\n      self.calc_info()\n    /tmp/easy_install-yzkhaqlt/numpy-1.14.2/numpy/distutils/system_info.py:624: UserWarning:\n        Blas (http://www.netlib.org/blas/) sources not found.\n        Directories to search for the sources can be specified in the\n        numpy/distutils/site.cfg file (section [blas_src]) or by setting\n        the BLAS_SRC environment variable.\n      self.calc_info()\n    /tmp/easy_install-yzkhaqlt/numpy-1.14.2/numpy/distutils/system_info.py:624: UserWarning:\n        Lapack (http://www.netlib.org/lapack/) libraries not found.\n        Directories to search for the libraries can be specified in the\n        numpy/distutils/site.cfg file (section [lapack]) or by setting\n        the LAPACK environment variable.\n      self.calc_info()\n    /tmp/easy_install-yzkhaqlt/numpy-1.14.2/numpy/distutils/system_info.py:624: UserWarning:\n        Lapack (http://www.netlib.org/lapack/) sources not found.\n        Directories to search for the sources can be specified in the\n        numpy/distutils/site.cfg file (section [lapack_src]) or by setting\n        the LAPACK_SRC environment variable.\n      self.calc_info()\n    /usr/lib64/python3.6/distutils/dist.py:261: UserWarning: Unknown distribution option: \'define_macros\'\n      warnings.warn(msg)\n    Traceback (most recent call last):\n      File "/usr/lib/python3.6/site-packages/setuptools/sandbox.py", line 154, in save_modules\n        yield saved\n      File "/usr/lib/python3.6/site-packages/setuptools/sandbox.py", line 195, in setup_context\n        yield\n      File "/usr/lib/python3.6/site-packages/setuptools/sandbox.py", line 250, in run_setup\n        _execfile(setup_script, ns)\n      File "/usr/lib/python3.6/site-packages/setuptools/sandbox.py", line 45, in _execfile\n        exec(code, globals, locals)\n      File "/tmp/easy_install-yzkhaqlt/numpy-1.14.2/setup.py", line 394, in <module>\n      File "/tmp/easy_install-yzkhaqlt/numpy-1.14.2/setup.py", line 386, in setup_package\n      File "/tmp/easy_install-yzkhaqlt/numpy-1.14.2/numpy/distutils/core.py", line 169, in setup\n  ...
#      'timeout': 60},
#     'package_name': 'scipy',
#     'type': 'command_error',
#     'version': '0.17.0'},
#    {'details': {'command': 'python3 -m pip install --force-reinstall --user --no-cache-dir --no-deps scipy==0.16.1',
#      'message': 'Command exited with non-zero status code (1): Command "python setup.py egg_info" failed with error code 1 in /tmp/pip-build-ezd7yt9g/scipy/\n',
#      'return_code': 1,
#      'stderr': 'Command "python setup.py egg_info" failed with error code 1 in /tmp/pip-build-ezd7yt9g/scipy/\n',
#      'stdout': 'Collecting scipy==0.16.1\n  Downloading scipy-0.16.1.tar.gz (12.2MB)\n    Complete output from command python setup.py egg_info:\n    /bin/sh: svnversion: command not found\n    /bin/sh: svnversion: command not found\n    non-existing path in \'numpy/distutils\': \'site.cfg\'\n    Could not locate executable gfortran\n    Could not locate executable f95\n    Could not locate executable ifort\n    Could not locate executable ifc\n    Could not locate executable lf95\n    Could not locate executable pgfortran\n    Could not locate executable f90\n    Could not locate executable f77\n    Could not locate executable fort\n    Could not locate executable efort\n    Could not locate executable efc\n    Could not locate executable g77\n    Could not locate executable g95\n    Could not locate executable pathf95\n    Could not locate executable nagfor\n    don\'t know how to compile Fortran code on platform \'posix\'\n    Running from numpy source directory.\n    /tmp/easy_install-7yka197a/numpy-1.14.2/setup.py:369: UserWarning: Unrecognized setuptools command, proceeding with generating Cython sources and expanding templates\n      run_build = parse_setuppy_commands()\n    /tmp/easy_install-7yka197a/numpy-1.14.2/numpy/distutils/system_info.py:624: UserWarning:\n        Atlas (http://math-atlas.sourceforge.net/) libraries not found.\n        Directories to search for the libraries can be specified in the\n        numpy/distutils/site.cfg file (section [atlas]) or by setting\n        the ATLAS environment variable.\n      self.calc_info()\n    /tmp/easy_install-7yka197a/numpy-1.14.2/numpy/distutils/system_info.py:624: UserWarning:\n        Blas (http://www.netlib.org/blas/) libraries not found.\n        Directories to search for the libraries can be specified in the\n        numpy/distutils/site.cfg file (section [blas]) or by setting\n        the BLAS environment variable.\n      self.calc_info()\n    /tmp/easy_install-7yka197a/numpy-1.14.2/numpy/distutils/system_info.py:624: UserWarning:\n        Blas (http://www.netlib.org/blas/) sources not found.\n        Directories to search for the sources can be specified in the\n        numpy/distutils/site.cfg file (section [blas_src]) or by setting\n        the BLAS_SRC environment variable.\n      self.calc_info()\n    /tmp/easy_install-7yka197a/numpy-1.14.2/numpy/distutils/system_info.py:624: UserWarning:\n        Lapack (http://www.netlib.org/lapack/) libraries not found.\n        Directories to search for the libraries can be specified in the\n        numpy/distutils/site.cfg file (section [lapack]) or by setting\n        the LAPACK environment variable.\n      self.calc_info()\n    /tmp/easy_install-7yka197a/numpy-1.14.2/numpy/distutils/system_info.py:624: UserWarning:\n        Lapack (http://www.netlib.org/lapack/) sources not found.\n        Directories to search for the sources can be specified in the\n        numpy/distutils/site.cfg file (section [lapack_src]) or by setting\n        the LAPACK_SRC environment variable.\n      self.calc_info()\n    /usr/lib64/python3.6/distutils/dist.py:261: UserWarning: Unknown distribution option: \'define_macros\'\n      warnings.warn(msg)\n    Traceback (most recent call last):\n      File "/usr/lib/python3.6/site-packages/setuptools/sandbox.py", line 154, in save_modules\n        yield saved\n      File "/usr/lib/python3.6/site-packages/setuptools/sandbox.py", line 195, in setup_context\n        yield\n      File "/usr/lib/python3.6/site-packages/setuptools/sandbox.py", line 250, in run_setup\n        _execfile(setup_script, ns)\n      File "/usr/lib/python3.6/site-packages/setuptools/sandbox.py", line 45, in _execfile\n        exec(code, globals, locals)\n      File "/tmp/easy_install-7yka197a/numpy-1.14.2/setup.py", line 394, in <module>\n      File "/tmp/easy_install-7yka197a/numpy-1.14.2/setup.py", line 386, in setup_package\n      File "/tmp/easy_install-7yka197a/numpy-1.14.2/numpy/distutils/core.py", line 169, in setup\n  ...
#      'timeout': 60},
#     'package_name': 'scipy',
#     'type': 'command_error',
#     'version': '0.16.1'},
#    {'details': {'command': 'python3 -m pip install --force-reinstall --user --no-cache-dir --no-deps scipy==0.16.0',
#      'message': 'Command exited with non-zero status code (1): Command "python setup.py egg_info" failed with error code 1 in /tmp/pip-build-zefgiohh/scipy/\n',
#      'return_code': 1,
#      'stderr': 'Command "python setup.py egg_info" failed with error code 1 in /tmp/pip-build-zefgiohh/scipy/\n',
#      'stdout': 'Collecting scipy==0.16.0\n  Downloading scipy-0.16.0.tar.gz (18.1MB)\n    Complete output from command python setup.py egg_info:\n    /bin/sh: svnversion: command not found\n    /bin/sh: svnversion: command not found\n    non-existing path in \'numpy/distutils\': \'site.cfg\'\n    Could not locate executable gfortran\n    Could not locate executable f95\n    Could not locate executable ifort\n    Could not locate executable ifc\n    Could not locate executable lf95\n    Could not locate executable pgfortran\n    Could not locate executable f90\n    Could not locate executable f77\n    Could not locate executable fort\n    Could not locate executable efort\n    Could not locate executable efc\n    Could not locate executable g77\n    Could not locate executable g95\n    Could not locate executable pathf95\n    Could not locate executable nagfor\n    don\'t know how to compile Fortran code on platform \'posix\'\n    Running from numpy source directory.\n    /tmp/easy_install-2bbzydgn/numpy-1.14.2/setup.py:369: UserWarning: Unrecognized setuptools command, proceeding with generating Cython sources and expanding templates\n      run_build = parse_setuppy_commands()\n    /tmp/easy_install-2bbzydgn/numpy-1.14.2/numpy/distutils/system_info.py:624: UserWarning:\n        Atlas (http://math-atlas.sourceforge.net/) libraries not found.\n        Directories to search for the libraries can be specified in the\n        numpy/distutils/site.cfg file (section [atlas]) or by setting\n        the ATLAS environment variable.\n      self.calc_info()\n    /tmp/easy_install-2bbzydgn/numpy-1.14.2/numpy/distutils/system_info.py:624: UserWarning:\n        Blas (http://www.netlib.org/blas/) libraries not found.\n        Directories to search for the libraries can be specified in the\n        numpy/distutils/site.cfg file (section [blas]) or by setting\n        the BLAS environment variable.\n      self.calc_info()\n    /tmp/easy_install-2bbzydgn/numpy-1.14.2/numpy/distutils/system_info.py:624: UserWarning:\n        Blas (http://www.netlib.org/blas/) sources not found.\n        Directories to search for the sources can be specified in the\n        numpy/distutils/site.cfg file (section [blas_src]) or by setting\n        the BLAS_SRC environment variable.\n      self.calc_info()\n    /tmp/easy_install-2bbzydgn/numpy-1.14.2/numpy/distutils/system_info.py:624: UserWarning:\n        Lapack (http://www.netlib.org/lapack/) libraries not found.\n        Directories to search for the libraries can be specified in the\n        numpy/distutils/site.cfg file (section [lapack]) or by setting\n        the LAPACK environment variable.\n      self.calc_info()\n    /tmp/easy_install-2bbzydgn/numpy-1.14.2/numpy/distutils/system_info.py:624: UserWarning:\n        Lapack (http://www.netlib.org/lapack/) sources not found.\n        Directories to search for the sources can be specified in the\n        numpy/distutils/site.cfg file (section [lapack_src]) or by setting\n        the LAPACK_SRC environment variable.\n      self.calc_info()\n    /usr/lib64/python3.6/distutils/dist.py:261: UserWarning: Unknown distribution option: \'define_macros\'\n      warnings.warn(msg)\n    Traceback (most recent call last):\n      File "/usr/lib/python3.6/site-packages/setuptools/sandbox.py", line 154, in save_modules\n        yield saved\n      File "/usr/lib/python3.6/site-packages/setuptools/sandbox.py", line 195, in setup_context\n        yield\n      File "/usr/lib/python3.6/site-packages/setuptools/sandbox.py", line 250, in run_setup\n        _execfile(setup_script, ns)\n      File "/usr/lib/python3.6/site-packages/setuptools/sandbox.py", line 45, in _execfile\n        exec(code, globals, locals)\n      File "/tmp/easy_install-2bbzydgn/numpy-1.14.2/setup.py", line 394, in <module>\n      File "/tmp/easy_install-2bbzydgn/numpy-1.14.2/setup.py", line 386, in setup_package\n      File "/tmp/easy_install-2bbzydgn/numpy-1.14.2/numpy/distutils/core.py", line 169, in setup\n  ...
#      'timeout': 60},
#     'package_name': 'scipy',
#     'type': 'command_error',
#     'version': '0.16.0'},
#    {'details': {'command': 'python3 -m pip install --force-reinstall --user --no-cache-dir --no-deps scipy==0.15.1',
#      'message': 'Command exited with non-zero status code (1): Command "python setup.py egg_info" failed with error code 1 in /tmp/pip-build-itlgraeg/scipy/\n',
#      'return_code': 1,
#      'stderr': 'Command "python setup.py egg_info" failed with error code 1 in /tmp/pip-build-itlgraeg/scipy/\n',
#      'stdout': 'Collecting scipy==0.15.1\n  Downloading scipy-0.15.1.tar.gz (11.4MB)\n    Complete output from command python setup.py egg_info:\n    /bin/sh: svnversion: command not found\n    /bin/sh: svnversion: command not found\n    non-existing path in \'numpy/distutils\': \'site.cfg\'\n    Could not locate executable gfortran\n    Could not locate executable f95\n    Could not locate executable ifort\n    Could not locate executable ifc\n    Could not locate executable lf95\n    Could not locate executable pgfortran\n    Could not locate executable f90\n    Could not locate executable f77\n    Could not locate executable fort\n    Could not locate executable efort\n    Could not locate executable efc\n    Could not locate executable g77\n    Could not locate executable g95\n    Could not locate executable pathf95\n    Could not locate executable nagfor\n    don\'t know how to compile Fortran code on platform \'posix\'\n    Running from numpy source directory.\n    /tmp/easy_install-mkcel1wa/numpy-1.14.2/setup.py:369: UserWarning: Unrecognized setuptools command, proceeding with generating Cython sources and expanding templates\n      run_build = parse_setuppy_commands()\n    /tmp/easy_install-mkcel1wa/numpy-1.14.2/numpy/distutils/system_info.py:624: UserWarning:\n        Atlas (http://math-atlas.sourceforge.net/) libraries not found.\n        Directories to search for the libraries can be specified in the\n        numpy/distutils/site.cfg file (section [atlas]) or by setting\n        the ATLAS environment variable.\n      self.calc_info()\n    /tmp/easy_install-mkcel1wa/numpy-1.14.2/numpy/distutils/system_info.py:624: UserWarning:\n        Blas (http://www.netlib.org/blas/) libraries not found.\n        Directories to search for the libraries can be specified in the\n        numpy/distutils/site.cfg file (section [blas]) or by setting\n        the BLAS environment variable.\n      self.calc_info()\n    /tmp/easy_install-mkcel1wa/numpy-1.14.2/numpy/distutils/system_info.py:624: UserWarning:\n        Blas (http://www.netlib.org/blas/) sources not found.\n        Directories to search for the sources can be specified in the\n        numpy/distutils/site.cfg file (section [blas_src]) or by setting\n        the BLAS_SRC environment variable.\n      self.calc_info()\n    /tmp/easy_install-mkcel1wa/numpy-1.14.2/numpy/distutils/system_info.py:624: UserWarning:\n        Lapack (http://www.netlib.org/lapack/) libraries not found.\n        Directories to search for the libraries can be specified in the\n        numpy/distutils/site.cfg file (section [lapack]) or by setting\n        the LAPACK environment variable.\n      self.calc_info()\n    /tmp/easy_install-mkcel1wa/numpy-1.14.2/numpy/distutils/system_info.py:624: UserWarning:\n        Lapack (http://www.netlib.org/lapack/) sources not found.\n        Directories to search for the sources can be specified in the\n        numpy/distutils/site.cfg file (section [lapack_src]) or by setting\n        the LAPACK_SRC environment variable.\n      self.calc_info()\n    /usr/lib64/python3.6/distutils/dist.py:261: UserWarning: Unknown distribution option: \'define_macros\'\n      warnings.warn(msg)\n    Traceback (most recent call last):\n      File "/usr/lib/python3.6/site-packages/setuptools/sandbox.py", line 154, in save_modules\n        yield saved\n      File "/usr/lib/python3.6/site-packages/setuptools/sandbox.py", line 195, in setup_context\n        yield\n      File "/usr/lib/python3.6/site-packages/setuptools/sandbox.py", line 250, in run_setup\n        _execfile(setup_script, ns)\n      File "/usr/lib/python3.6/site-packages/setuptools/sandbox.py", line 45, in _execfile\n        exec(code, globals, locals)\n      File "/tmp/easy_install-mkcel1wa/numpy-1.14.2/setup.py", line 394, in <module>\n      File "/tmp/easy_install-mkcel1wa/numpy-1.14.2/setup.py", line 386, in setup_package\n      File "/tmp/easy_install-mkcel1wa/numpy-1.14.2/numpy/distutils/core.py", line 169, in setup\n  ...
#      'timeout': 60},
#     'package_name': 'scipy',
#     'type': 'command_error',
#     'version': '0.15.1'},
#    {'details': {'command': 'python3 -m pip install --force-reinstall --user --no-cache-dir --no-deps scipy==0.15.0',
#      'message': 'Command exited with non-zero status code (1): Command "python setup.py egg_info" failed with error code 1 in /tmp/pip-build-5c_q810j/scipy/\n',
#      'return_code': 1,
#      'stderr': 'Command "python setup.py egg_info" failed with error code 1 in /tmp/pip-build-5c_q810j/scipy/\n',
#      'stdout': 'Collecting scipy==0.15.0\n  Downloading scipy-0.15.0.tar.gz (11.4MB)\n    Complete output from command python setup.py egg_info:\n    /bin/sh: svnversion: command not found\n    /bin/sh: svnversion: command not found\n    non-existing path in \'numpy/distutils\': \'site.cfg\'\n    Could not locate executable gfortran\n    Could not locate executable f95\n    Could not locate executable ifort\n    Could not locate executable ifc\n    Could not locate executable lf95\n    Could not locate executable pgfortran\n    Could not locate executable f90\n    Could not locate executable f77\n    Could not locate executable fort\n    Could not locate executable efort\n    Could not locate executable efc\n    Could not locate executable g77\n    Could not locate executable g95\n    Could not locate executable pathf95\n    Could not locate executable nagfor\n    don\'t know how to compile Fortran code on platform \'posix\'\n    Running from numpy source directory.\n    /tmp/easy_install-h9mfilns/numpy-1.14.2/setup.py:369: UserWarning: Unrecognized setuptools command, proceeding with generating Cython sources and expanding templates\n      run_build = parse_setuppy_commands()\n    /tmp/easy_install-h9mfilns/numpy-1.14.2/numpy/distutils/system_info.py:624: UserWarning:\n        Atlas (http://math-atlas.sourceforge.net/) libraries not found.\n        Directories to search for the libraries can be specified in the\n        numpy/distutils/site.cfg file (section [atlas]) or by setting\n        the ATLAS environment variable.\n      self.calc_info()\n    /tmp/easy_install-h9mfilns/numpy-1.14.2/numpy/distutils/system_info.py:624: UserWarning:\n        Blas (http://www.netlib.org/blas/) libraries not found.\n        Directories to search for the libraries can be specified in the\n        numpy/distutils/site.cfg file (section [blas]) or by setting\n        the BLAS environment variable.\n      self.calc_info()\n    /tmp/easy_install-h9mfilns/numpy-1.14.2/numpy/distutils/system_info.py:624: UserWarning:\n        Blas (http://www.netlib.org/blas/) sources not found.\n        Directories to search for the sources can be specified in the\n        numpy/distutils/site.cfg file (section [blas_src]) or by setting\n        the BLAS_SRC environment variable.\n      self.calc_info()\n    /tmp/easy_install-h9mfilns/numpy-1.14.2/numpy/distutils/system_info.py:624: UserWarning:\n        Lapack (http://www.netlib.org/lapack/) libraries not found.\n        Directories to search for the libraries can be specified in the\n        numpy/distutils/site.cfg file (section [lapack]) or by setting\n        the LAPACK environment variable.\n      self.calc_info()\n    /tmp/easy_install-h9mfilns/numpy-1.14.2/numpy/distutils/system_info.py:624: UserWarning:\n        Lapack (http://www.netlib.org/lapack/) sources not found.\n        Directories to search for the sources can be specified in the\n        numpy/distutils/site.cfg file (section [lapack_src]) or by setting\n        the LAPACK_SRC environment variable.\n      self.calc_info()\n    /usr/lib64/python3.6/distutils/dist.py:261: UserWarning: Unknown distribution option: \'define_macros\'\n      warnings.warn(msg)\n    Traceback (most recent call last):\n      File "/usr/lib/python3.6/site-packages/setuptools/sandbox.py", line 154, in save_modules\n        yield saved\n      File "/usr/lib/python3.6/site-packages/setuptools/sandbox.py", line 195, in setup_context\n        yield\n      File "/usr/lib/python3.6/site-packages/setuptools/sandbox.py", line 250, in run_setup\n        _execfile(setup_script, ns)\n      File "/usr/lib/python3.6/site-packages/setuptools/sandbox.py", line 45, in _execfile\n        exec(code, globals, locals)\n      File "/tmp/easy_install-h9mfilns/numpy-1.14.2/setup.py", line 394, in <module>\n      File "/tmp/easy_install-h9mfilns/numpy-1.14.2/setup.py", line 386, in setup_package\n      File "/tmp/easy_install-h9mfilns/numpy-1.14.2/numpy/distutils/core.py", line 169, in setup\n  ...
#      'timeout': 60},
#     'package_name': 'scipy',
#     'type': 'command_error',
#     'version': '0.15.0'},
#    {'details': {'command': 'python3 -m pip install --force-reinstall --user --no-cache-dir --no-deps scipy==0.14.1',
#      'message': 'Command exited with non-zero status code (1): Command "python setup.py egg_info" failed with error code 1 in /tmp/pip-build-aendbni5/scipy/\n',
#      'return_code': 1,
#      'stderr': 'Command "python setup.py egg_info" failed with error code 1 in /tmp/pip-build-aendbni5/scipy/\n',
#      'stdout': 'Collecting scipy==0.14.1\n  Downloading scipy-0.14.1.tar.gz (10.9MB)\n    Complete output from command python setup.py egg_info:\n    /bin/sh: svnversion: command not found\n    /bin/sh: svnversion: command not found\n    non-existing path in \'numpy/distutils\': \'site.cfg\'\n    Could not locate executable gfortran\n    Could not locate executable f95\n    Could not locate executable ifort\n    Could not locate executable ifc\n    Could not locate executable lf95\n    Could not locate executable pgfortran\n    Could not locate executable f90\n    Could not locate executable f77\n    Could not locate executable fort\n    Could not locate executable efort\n    Could not locate executable efc\n    Could not locate executable g77\n    Could not locate executable g95\n    Could not locate executable pathf95\n    Could not locate executable nagfor\n    don\'t know how to compile Fortran code on platform \'posix\'\n    Running from numpy source directory.\n    /tmp/easy_install-fu2661op/numpy-1.14.2/setup.py:369: UserWarning: Unrecognized setuptools command, proceeding with generating Cython sources and expanding templates\n      run_build = parse_setuppy_commands()\n    /tmp/easy_install-fu2661op/numpy-1.14.2/numpy/distutils/system_info.py:624: UserWarning:\n        Atlas (http://math-atlas.sourceforge.net/) libraries not found.\n        Directories to search for the libraries can be specified in the\n        numpy/distutils/site.cfg file (section [atlas]) or by setting\n        the ATLAS environment variable.\n      self.calc_info()\n    /tmp/easy_install-fu2661op/numpy-1.14.2/numpy/distutils/system_info.py:624: UserWarning:\n        Blas (http://www.netlib.org/blas/) libraries not found.\n        Directories to search for the libraries can be specified in the\n        numpy/distutils/site.cfg file (section [blas]) or by setting\n        the BLAS environment variable.\n      self.calc_info()\n    /tmp/easy_install-fu2661op/numpy-1.14.2/numpy/distutils/system_info.py:624: UserWarning:\n        Blas (http://www.netlib.org/blas/) sources not found.\n        Directories to search for the sources can be specified in the\n        numpy/distutils/site.cfg file (section [blas_src]) or by setting\n        the BLAS_SRC environment variable.\n      self.calc_info()\n    /tmp/easy_install-fu2661op/numpy-1.14.2/numpy/distutils/system_info.py:624: UserWarning:\n        Lapack (http://www.netlib.org/lapack/) libraries not found.\n        Directories to search for the libraries can be specified in the\n        numpy/distutils/site.cfg file (section [lapack]) or by setting\n        the LAPACK environment variable.\n      self.calc_info()\n    /tmp/easy_install-fu2661op/numpy-1.14.2/numpy/distutils/system_info.py:624: UserWarning:\n        Lapack (http://www.netlib.org/lapack/) sources not found.\n        Directories to search for the sources can be specified in the\n        numpy/distutils/site.cfg file (section [lapack_src]) or by setting\n        the LAPACK_SRC environment variable.\n      self.calc_info()\n    /usr/lib64/python3.6/distutils/dist.py:261: UserWarning: Unknown distribution option: \'define_macros\'\n      warnings.warn(msg)\n    Traceback (most recent call last):\n      File "/usr/lib/python3.6/site-packages/setuptools/sandbox.py", line 154, in save_modules\n        yield saved\n      File "/usr/lib/python3.6/site-packages/setuptools/sandbox.py", line 195, in setup_context\n        yield\n      File "/usr/lib/python3.6/site-packages/setuptools/sandbox.py", line 250, in run_setup\n        _execfile(setup_script, ns)\n      File "/usr/lib/python3.6/site-packages/setuptools/sandbox.py", line 45, in _execfile\n        exec(code, globals, locals)\n      File "/tmp/easy_install-fu2661op/numpy-1.14.2/setup.py", line 394, in <module>\n      File "/tmp/easy_install-fu2661op/numpy-1.14.2/setup.py", line 386, in setup_package\n      File "/tmp/easy_install-fu2661op/numpy-1.14.2/numpy/distutils/core.py", line 169, in setup\n  ...
#      'timeout': 60},
#     'package_name': 'scipy',
#     'type': 'command_error',
#     'version': '0.14.1'},
#    {'details': {'command': 'python3 -m pip install --force-reinstall --user --no-cache-dir --no-deps scipy==0.14.0',
#      'message': 'Command exited with non-zero status code (1): Command "/usr/bin/python3 -u -c "import setuptools, tokenize;__file__=\'/tmp/pip-build-jakriyht/scipy/setup.py\';f=getattr(tokenize, \'open\', open)(__file__);code=f.read().replace(\'\\r\\n\', \'\\n\');f.close();exec(compile(code, __file__, \'exec\'))" install --record /tmp/pip-gfzix4hu-record/install-record.txt --single-version-externally-managed --compile --user --prefix=" failed with error code 1 in /tmp/pip-build-jakriyht/scipy/\n',
#      'return_code': 1,
#      'stderr': 'Command "/usr/bin/python3 -u -c "import setuptools, tokenize;__file__=\'/tmp/pip-build-jakriyht/scipy/setup.py\';f=getattr(tokenize, \'open\', open)(__file__);code=f.read().replace(\'\\r\\n\', \'\\n\');f.close();exec(compile(code, __file__, \'exec\'))" install --record /tmp/pip-gfzix4hu-record/install-record.txt --single-version-externally-managed --compile --user --prefix=" failed with error code 1 in /tmp/pip-build-jakriyht/scipy/\n',
#      'stdout': 'Collecting scipy==0.14.0\n  Downloading scipy-0.14.0.zip (11.5MB)\nInstalling collected packages: scipy\n  Running setup.py install for scipy: started\n    Running setup.py install for scipy: finished with status \'error\'\n    Complete output from command /usr/bin/python3 -u -c "import setuptools, tokenize;__file__=\'/tmp/pip-build-jakriyht/scipy/setup.py\';f=getattr(tokenize, \'open\', open)(__file__);code=f.read().replace(\'\\r\\n\', \'\\n\');f.close();exec(compile(code, __file__, \'exec\'))" install --record /tmp/pip-gfzix4hu-record/install-record.txt --single-version-externally-managed --compile --user --prefix=:\n    Traceback (most recent call last):\n      File "<string>", line 1, in <module>\n      File "/tmp/pip-build-jakriyht/scipy/setup.py", line 237, in <module>\n        setup_package()\n      File "/tmp/pip-build-jakriyht/scipy/setup.py", line 225, in setup_package\n        from numpy.distutils.core import setup\n    ModuleNotFoundError: No module named \'numpy\'\n    \n    ----------------------------------------\n',
#      'timeout': 60},
#     'package_name': 'scipy',
#     'type': 'command_error',
#     'version': '0.14.0'},
#    {'details': {'command': 'python3 -m pip install --force-reinstall --user --no-cache-dir --no-deps scipy==0.14.1rc1',
# ...
#       {'hash': 'bd8a8d17e493d4363cf5e31c2343f6d482e2280172e444b712dabbda325db8479971c2231af53c1e3909b45ee2c9702431d082d538f66ab520b5cd497dc5a689',
#        'url': 'https://pypi.python.org/packages/2f/11/fa97aa5ff90b7b2f5988f64c2502a805bb6083f56b45fca27e93420f3574/scipy-0.19.1-cp27-cp27m-manylinux1_i686.whl'},
#       {'hash': 'a63d4428a1b31394f3cc3d0e5498655556b1616eb3c2621ccc0e0ead0b9ad00e46144da320613e627751bc291387898832450b871f3c4961d0f16a682344e323',
#        'url': 'https://pypi.python.org/packages/74/18/2bd4719bcd359121a4ea56b833b1fc2cc2d3ddea8cb2699bbebae72bda18/scipy-0.19.1-cp27-cp27m-manylinux1_x86_64.whl'},
#       {'hash': 'a4f44ecefcd85140055c1d5fe5709b0f8f8244258ab27bf9cf6c2d1ec29f2616b025a87088b1183ca8211cdbd3961e80d0edb26716c436d1137353c9ec7bd1a8',
#        'url': 'https://pypi.python.org/packages/a2/6b/814afdf98fed9defaec70052e29a7d10eb992bcabb01098677e361846a7a/scipy-0.19.1-cp27-cp27mu-manylinux1_i686.whl'},
#       {'hash': 'cc25e56ec1c4034930ed69a1016c52d3490d414cacbc0b7e153eb1befa4ed2491724dbf7902ac5b7d79b1b4d9c698db63ae0a53de449b9946fee62662b35492a',
#        'url': 'https://pypi.python.org/packages/8e/43/a7b400e7ea07220fb419f0669ff17f5ef71653cf32827315224bc9dda9d4/scipy-0.19.1-cp27-cp27mu-manylinux1_x86_64.whl'},
#       {'hash': '043f5290047d12f0d9dd8994f13ecf2683c1ad20fe8dd0462fb622ee25cbcb4798ba8c96bde9e7957c8ad043c704d6c26b8d83834f53996a2f92f539d5236a34',
#        'url': 'https://pypi.python.org/packages/be/31/40391528eb94e7686d1075a28fb80e45962cc0eaa6843d1a5c8677dab3af/scipy-0.19.1-cp34-cp34m-macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.macosx_10_10_intel.macosx_10_10_x86_64.whl'},
#       {'hash': '58fc935f0ab638b1e090484b9959df2f406e0136c100e902efb433af8335202326a97d93147d0211542a831f6a422cecf308576e58054a73c8d23606b8c3c6ae',
#        'url': 'https://pypi.python.org/packages/23/fc/57fb7cd7d8869b6457faeaf329c47c3630ba0d0875d4b40b79d1602d23fa/scipy-0.19.1-cp34-cp34m-manylinux1_i686.whl'},
#       {'hash': '9c2a9253607ce22030453350457d20a0269beca34470bd7f7e71dbe81fb599b125ca98556587894d591ade0717c0eda297df89f295d40f03529dced41ce9c9de',
#        'url': 'https://pypi.python.org/packages/5e/35/3ecc16e083ed82a0a234a27a9d77d817c0abab0db43eb31a451bded3b49d/scipy-0.19.1-cp34-cp34m-manylinux1_x86_64.whl'},
#       {'hash': '3d24901bc83dc34c9abef0737ebec42d04717fe6ecdb5568bd8aa83584dabfe3cbbe136b78b6b7065448c5111cb49d2742ca0b6ee0ed4112c03b421bd1b0fdab',
#        'url': 'https://pypi.python.org/packages/75/88/63dd10deab739027163b2f034faedd189da728d8010ad2aaef6d527c7286/scipy-0.19.1-cp35-cp35m-macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.macosx_10_10_intel.macosx_10_10_x86_64.whl'},
#       {'hash': '1e09595dafe10809bade58d90295eaef0b9957604abd9ccbeb041a73ec75d3fd8a7fd8a0baed1f3b137aa39a6b3c94c56c3fd8f4d0824582a65d283cd2dcdc33',
#        'url': 'https://pypi.python.org/packages/70/e9/e61b0855638d341dfea5a6cea7cfeb08d1e8b7fe7bb6060ec15fcb5815ec/scipy-0.19.1-cp35-cp35m-manylinux1_i686.whl'},
#       {'hash': '17c5087a43e31b3817511a5aef80cedda2d1e92edb9b9081ad2d48266c38494234a1ef383619fe4b5f7f3fc4a040425ea66ae9ffabeb884cacbcd7fa99270623',
#        'url': 'https://pypi.python.org/packages/a7/a5/447e56abc3854a343c2f01c8fb274570057bc2550b71bd5134a264d4251e/scipy-0.19.1-cp35-cp35m-manylinux1_x86_64.whl'},
#       {'hash': '0c30c7c7dde7ca53300648a952dda9a0e2448002e0f6d9c809adbcbb888eb05a59a002717e3b65b35f6c22508891150179bfaeedc0f6a502fe4c774d0a44d40e',
#        'url': 'https://pypi.python.org/packages/5c/81/5a40e4abcbd0c303e002d1e1fa15fefadcc2bb1b8d28e49e12a01f5f1a5a/scipy-0.19.1-cp36-cp36m-macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.macosx_10_10_intel.macosx_10_10_x86_64.whl'},
#       {'hash': 'd693487060eb823fbfe6df9d2d9d47f8257647c9edbacc7bcb8b21e6f6da95d54ae1db57771baf43aff2b6e6d563835741edefb791a93e0cddb01bc7869440c8',
#        'url': 'https://pypi.python.org/packages/9b/4a/eaf906fab762e85590678ffc1e220b4c697325cf5eac0c2e9d79a026afbd/scipy-0.19.1-cp36-cp36m-manylinux1_i686.whl'},
#       {'hash': 'e8c3e3c0fabc27e80f620412ca2be2e079e9819dd957fa8d5acfa8e3463a23c1d36eb9823b8a75bfd8dd3dec21386e2fee580f5bf1f29b47e0a92a5091f37b6b',
#        'url': 'https://pypi.python.org/packages/0e/46/da8d7166102d29695330f7c0b912955498542988542c0d2ae3ea0389c68d/scipy-0.19.1-cp36-cp36m-manylinux1_x86_64.whl'},
#       {'hash': '5c124c44c672dcb53c31f8592fd9f74189f04cb0bade99476a2a6eb4844338e3e9842f27a148b007b7eed25cbfde090a697575a381ebe4ca066abdf54c214203',
#        'url': 'https://pypi.python.org/packages/52/67/d9ef9b5058d4a9e3f0ae641ec151790622cbeb37f157de5773358e2bf3da/scipy-0.19.1.tar.gz'}],
#      'package': 'scipy',
#      'version': '0.19.1'},
#     'package_name': 'scipy',
#     'package_version': '0.19.1'},
#    {'dependencies': [{'package_name': 'numpy',
#       'required_version': '>=1.8.2',
#       'resolved_versions': ['1.8.2',
#        '1.9.0',
#        '1.9.1',
#        '1.9.2',
#        '1.9.3',
#        '1.10.0',
#        '1.10.1',
#        '1.10.2',
#        '1.10.3',
#        '1.10.4',
#        '1.11.2rc1',
#        '1.11.1rc1',
#        '1.11.0rc2',
#        '1.11.0rc1',
#        '1.11.0b3',
#        '1.11.0',
#        '1.11.1',
#        '1.11.2',
#        '1.11.3',
#        '1.12.1rc1',
#        '1.12.0rc2',
#        '1.12.0rc1',
#        '1.12.0b1',
#        '1.12.0',
#        '1.12.1',
#        '1.13.0rc2',
#        '1.13.0rc1',
#        '1.13.0',
#        '1.13.1',
#        '1.13.3',
#        '1.14.0rc1',
#        '1.14.0',
#        '1.14.1',
#        '1.14.2']}],
#     'hash_type': 'sha512',
#     'hashes': {'hashes': [{'hash': '75f801b324e192d031afc245fe287aafad64fb52e6a2e25c228a36fec4c2b5ad7fbfffdab414705c4562c9ad02962a69df60634bab247dd6406fd8027013457e',
#        'url': 'https://pypi.python.org/packages/72/eb/d398b9f63ee936575edc62520477d6c2353ed013bacd656bd0c8bc1d0fa7/scipy-0.19.0-cp27-cp27m-macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.macosx_10_10_intel.macosx_10_10_x86_64.whl'},
#       {'hash': '299e8871e9c765350ec292de81be7fc27cf35033b88956328110dd346314aacb706017a33248a544d3c72c5e85117c71d170c246529904f097f7aa40036794b5',
#        'url': 'https://pypi.python.org/packages/74/d2/dd67138a84d499025a8f6b412517fe4a73e9561b35fc09e9f8b9c59e3403/scipy-0.19.0-cp27-cp27m-manylinux1_i686.whl'},
#       {'hash': 'c0e7fff5f2d2c8124a386335d1e5faa26b5b1b877805d0f7f205dbc908cffa91eebb7f655484724b2e486c407f46e46a22c8254fcf7965532399092229c769a9',
#        'url': 'https://pypi.python.org/packages/ae/94/28ca6f9311e2351bb68da41ff8c1bc8f82bb82791f2ecd34efa953e60576/scipy-0.19.0-cp27-cp27m-manylinux1_x86_64.whl'},
#       {'hash': '62a3addbd758c9d4c16602220572ba4d9d5d53a2a5ecf2ba96e0c72bd6b8f11771948eab47ea14e6f93826ce5a2af436298420e375584677d10fa62227ae1c65',
#        'url': 'https://pypi.python.org/packages/88/55/7344997a3fec322a774e9d418db36a01ab6c1eb95a54e69babdfba07f1a2/scipy-0.19.0-cp27-cp27mu-manylinux1_i686.whl'},
#       {'hash': 'be246987d03be31bf04443cee3a42f8a5f85f0ee004e3c1558254d19ae148c92d79150d02f6f6a76b9027275a804e80b4e67e1847d11b657ba028a36030c6fac',
#        'url': 'https://pypi.python.org/packages/eb/7e/27b3b9e26cb64e081799546a756059baf285eb886a771e9d26743876ccbb/scipy-0.19.0-cp27-cp27mu-manylinux1_x86_64.whl'},
#       {'hash': 'b72d71228b94ee722478e6ff525455ee35ac0d97f71db467be8dcfcfe7240a2d3297db11f72031fd8d5d96edf61e1737f55bcb5cd81299814bcc7c4a0a07b6b5',
#        'url': 'https://pypi.python.org/packages/ba/8a/c3f53e4afd4bc296b86fc90e2bd5c73673442763fcfa0155b1f70ce2b5f9/scipy-0.19.0-cp34-cp34m-macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.macosx_10_10_intel.macosx_10_10_x86_64.whl'},
#       {'hash': 'ff818995888abd2a2812f4360780418c07b867a9704eb811ff14cff4696b0a08d85462cc4a6b152e6f3c5b2c53f1eb3ca2fc529d716ceb04293a934bb3eb270c',
#        'url': 'https://pypi.python.org/packages/bd/fb/79fa65e6a583d0cce42dd2c8ba104db440e6f25ca706588d97e81d4c9d5e/scipy-0.19.0-cp34-cp34m-manylinux1_i686.whl'},
#       {'hash': '96dee72685dbb224b147ee813acc91b9cd4f2fd45441e16724d5f63ae1511d603f9e916f59c11bc87c97b149d6e62eee671fe93345b6fdf765ddf4f5bebd7323',
#        'url': 'https://pypi.python.org/packages/65/ab/86c8f34f336d5a28e5f0f1d53438de58a0177eedfc3890d889b6f5f53442/scipy-0.19.0-cp34-cp34m-manylinux1_x86_64.whl'},
#       {'hash': '3c24010c0df8831faa9c02e4f0591ecd2216052a9caac34013de88fd10c36e6cf6b1a01b1a40290ed6c21c8f60ca322303f48a2764488f9c2ef9eb528e1c51a9',
#        'url': 'https://pypi.python.org/packages/07/2f/a21e12fecad483b9b624dca1dc6802822519b9325f46c58d829e4f9e1ddd/scipy-0.19.0-cp35-cp35m-macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.macosx_10_10_intel.macosx_10_10_x86_64.whl'},
#       {'hash': '072f3f58148f4e798a8a3c1c83f0d1471c6e255dacff43c4130f1bb9f55335e92abe7c21a483bfdcbe88f75868fdb6ea597cf8adc59d93841bf6649689a038b6',
#        'url': 'https://pypi.python.org/packages/3a/4f/f1b7401773e8a8c119400fe4f67b0c25ee5ce7b1d7672c8cdab2dd9a63f3/scipy-0.19.0-cp35-cp35m-manylinux1_i686.whl'},
#       {'hash': 'fcfb140c3d386a48edd48f88b82d64336c30ec576d97c293a2541e8ba9cc88e6cd1c3ffe83e7b23006542fff8c51c3de9cecd9218fee2252eb707d2d19b49b34',
#        'url': 'https://pypi.python.org/packages/20/97/0d5d86f38bba887a3b2b40c69977c334ecfff2c475d1e29491047c90538a/scipy-0.19.0-cp35-cp35m-manylinux1_x86_64.whl'},
#       {'hash': '7137d2147396f0274119c2f7d017253c03d1739ae7d8bc154d92d4b2bb160178d3fc268fbd8bc43825befb04db64b49087aa785ef7e027eec4d695f1122d2807',
#        'url': 'https://pypi.python.org/packages/35/5c/88a2f023cbadf3d84520cc9c3bffa0da93480a08f28a4d07f2a5543c71a9/scipy-0.19.0-cp36-cp36m-macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.macosx_10_10_intel.macosx_10_10_x86_64.whl'},
#       {'hash': 'bd91dd4d99e38c88f07e01e97f8e2ebeb37557bddb50bafa38df2fe6d61f9b4d3f0abcecab13304bb21613690c218cae3c0fae289e69270773198c1ae6e87a8b',
#        'url': 'https://pypi.python.org/packages/bf/f2/1dc85bfbbbf96faf2340a807285cf3f742eb0037fe2558b5ea3572fa76b6/scipy-0.19.0-cp36-cp36m-manylinux1_i686.whl'},
#       {'hash': '3b61e983291eaef37027ec5fdcd36b5322f085842fd86464d0cb294c466f3a06a397d294b6ddacfada74c697f737df7c8949150317243d73a654e966d93b3c4b',
#        'url': 'https://pypi.python.org/packages/d0/7b/415fd5bb215f28b423d32dc98126f700ebe7f1efa53e65377ed6ed55df99/scipy-0.19.0-cp36-cp36m-manylinux1_x86_64.whl'},
#       {'hash': '3144bc14155ae790f2aba5ca6b22cbe5e7170ae1ad305774601ac22e479e1377197e47e3cd7033a5ca3464f5e944db91d3c4615111eb3369cbdd3f9079ae8c54',
#        'url': 'https://pypi.python.org/packages/e5/93/9a8290e7eb5d4f7cb53b9a7ad7b92b9827ecceaddfd04c2a83f195d8767d/scipy-0.19.0.zip'}],
#      'package': 'scipy',
#      'version': '0.19.0'},
#     'package_name': 'scipy',
#     'package_version': '0.19.0'},
#    {'dependencies': [],
#     'hash_type': 'sha512',
#     'hashes': {'hashes': [{'hash': '3a33fbab323754d1b46a44a5cc2d09871ef1287141ba078c921a00a57edaffecb040dc253b972d0d6e80f9909335fdd29d5138c64a1ec55fc181b126c574a353',
#        'url': 'https://pypi.python.org/packages/0d/6d/953ec7721b3addfe36b55f77ba6b70ffddcfa66db427816954b43bd85e65/scipy-0.18.1-cp27-cp27m-macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.macosx_10_10_intel.macosx_10_10_x86_64.whl'},
#       {'hash': 'd3325b731a29aca4dc1b58536c36e2515e0aafb899287645d1c44aeba5d6a749605afd321b2b4c862210651570725c5b16c2b42cca6dadf63c2126aad8366bd4',
#        'url': 'https://pypi.python.org/packages/3f/52/6fa39a8c03610e68be9e1c5c0b8dfe8fc4b0981a7789447aed79efc8dc2e/scipy-0.18.1-cp27-cp27m-manylinux1_i686.whl'},
#       {'hash': '3a91d36c4471470550905148fc04fbb5ec59ba8604fac069e1ed7485e5785c4bd460815c85fbbf4119ee23daf8c0766b8cf6175810c9413d2850508167104fe3',
#        'url': 'https://pypi.python.org/packages/72/41/44846a3c6f83b9d884f964d97b3cf4934078b65beecc741508d83613daa0/scipy-0.18.1-cp27-cp27m-manylinux1_x86_64.whl'},
#       {'hash': '348f90dc7625362d0fb45fac1ec9197b4e3445edd22ed611dba630556d89ff2e6bf76d95a18791c055c3d11044a4f7ced7449f1de78ca931f3e80abccf9b6fc6',
#        'url': 'https://pypi.python.org/packages/2f/a7/743bc344a197ca0301601f3de895210bf78169f34583040cd83a086fae33/scipy-0.18.1-cp27-cp27mu-manylinux1_i686.whl'},
#       {'hash': '833532dd54e3420dd8e5a929a0c989388c7befc8cd9926569edae26cba31518f61af45899e8507337c1d7ad3bb3e7c475ca890ab8a132cbaad44ff9d811ecf37',
#        'url': 'https://pypi.python.org/packages/13/cb/8e74d28e1519b34636e4d985d49d01c23778064e01eb102914f844cd6051/scipy-0.18.1-cp27-cp27mu-manylinux1_x86_64.whl'},
#       {'hash': 'b6683693ae4037552338a4f6335a003d1c5391d14fc736d6a082d51a494c786736fd9fe36ac0bac83cefa44b1df7f4645802acc49c9a946a14e1d951c5c24665',
#        'url': 'https://pypi.python.org/packages/8a/2e/cd53468ce7d2d6f85f321265238d5f5cca846af448621042fc6b7ab31a21/scipy-0.18.1-cp34-cp34m-macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.macosx_10_10_intel.macosx_10_10_x86_64.whl'},
#       {'hash': 'b709026a9b3760cb28b5dc15715d3bae415ee19c15471ba491987ec57e42a5bb80b1c1de63f2c7364dcd0a87e28f5868a2e0a92c260a32f1fca45df19a3edba6',
#        'url': 'https://pypi.python.org/packages/dc/16/9560208cb7b34c67f1f0260bbade755869586bccc88c92011e3c12d3fa47/scipy-0.18.1-cp34-cp34m-manylinux1_i686.whl'},
#       {'hash': 'c100dad4a83e4f88bf45854fa59099057e1a1c47a6ba36031b8fb14af52d4ea3a2bc4ad05987bcd9855affb74279ceb6399d87644de31746bc829ab4ce916f5f',
#        'url': 'https://pypi.python.org/packages/59/6c/f70014a506b25fde32580f9398c16d5b20d52ec3ae6fc16302df9e68b361/scipy-0.18.1-cp34-cp34m-manylinux1_x86_64.whl'},
#       {'hash': 'da0c6fabd58fb4f142f11c46d09f94cbfae6fc0c2eb50367b553dbe3d95405e3c0cfe7c89f51dc0b5ac1a7d052a93a03410576bed8e4b8eaac11155df225cd68',
#        'url': 'https://pypi.python.org/packages/26/cf/52c326bbecc804e038e80c633255d57123aaa88a3777f404eeb55633dd5a/scipy-0.18.1-cp35-cp35m-macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.macosx_10_10_intel.macosx_10_10_x86_64.whl'},
#       {'hash': '9117e7d24b4fe40154e10316a3c048222a2017cafe7e2f1507298404429434ef77bb6606d964528754b46782c6086f66557a6a92bc1f1eff00229dafad3017a4',
#        'url': 'https://pypi.python.org/packages/b0/bf/3196bb46c8fccee9b2c6964d5de1d1ac2414262b8aef8c5bea4514d9587a/scipy-0.18.1-cp35-cp35m-manylinux1_i686.whl'},
#       {'hash': 'd7111d43137e9913e379512c0f38110edf3a5f16c75eebd9d023b36a0317c9000c1e00af04b911953264ef84f91f4408d476a6fcd6c719b0a03e93efb097e6b4',
#        'url': 'https://pypi.python.org/packages/f5/a8/87c83acd5899c8017a220092a09fc54f89150130683ba1d2e14aafe898f4/scipy-0.18.1-cp35-cp35m-manylinux1_x86_64.whl'},
#       {'hash': '8bfad1feac32721fbc8c0e76f64e797e56286824c16ab1006c6289dfc3da0dbcbd4aa821722c1dfb234bc60467397783ba1fafa400e28f159b151fd615d6e4fe',
#        'url': 'https://pypi.python.org/packages/62/24/5ba8aeb4a3f49f5d34926ee19e02ac4dda1a7f4ff6ef96bd2597ddb0e11e/scipy-0.18.1-cp36-cp36m-macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.macosx_10_10_intel.macosx_10_10_x86_64.whl'},
#       {'hash': 'e7e4ff787d653116ce1ccd854dc8cee941a70c541ced48d2810d8f74feaa8760798c545059940f71cc544fa1a268edf7dee96e58152fa0308bf5d5b601c3387b',
#        'url': 'https://pypi.python.org/packages/97/5f/18714e4ae759fd5fef643c8f578fbef1a513f5302681a3b20f80f09700c9/scipy-0.18.1-cp36-cp36m-manylinux1_i686.whl'},
#       {'hash': '086a06cabcbfbd7a445e0b72265c170debeb901605b69961085c99923f57d1b7abec5ebc351d150df5f40a25045223cc64e759b50c28874c0ebfe11df25eccdb',
#        'url': 'https://pypi.python.org/packages/74/c0/f0bf4eaef1b6aa7bdd1ae5597ce1d9e729417b3ca085c47d0f1c640d34f8/scipy-0.18.1-cp36-cp36m-manylinux1_x86_64.whl'},
#       {'hash': 'f2ee21c808141d8002f69e48e7cf006e36982b1a7041323a8f4d803a1de3d191ffcc40227aac351dd876c28843de366ef89e9cf84dc106fadac86a3f40491659',
#        'url': 'https://pypi.python.org/packages/22/41/b1538a75309ae4913cdbbdc8d1cc54cae6d37981d2759532c1aa37a41121/scipy-0.18.1.tar.gz'},
#       {'hash': 'a219d3b554b034ed3bda2b0d54edb31928d8dcbe8d503d863c476f93ba605f53e5183f1f252052c15ff6a444e6515387612267fa718da5b51b7cda3b22f514f0',
#        'url': 'https://pypi.python.org/packages/f8/85/37e205d2c48a9691078bd3cd6b22237e399dc1ba049d31ba8e57da44b5be/scipy-0.18.1.zip'}],
#      'package': 'scipy',
#      'version': '0.18.1'},
#     'package_name': 'scipy',
#     'package_version': '0.18.1'}],
#   'unresolved': []}}

# %% [markdown]
# ## Accessing image scan results
#
# Similarly we can access results of image scans. To access these results, let's instantiate adapter responsible for listing, retrieving or storing these results. The semantics is same as in case of solver results.

# %%
from thoth.lab import obtain_location
from thoth.storages import AnalysisResultsStore

# %% [markdown]
# Let's instantiate the adapter:

# %%
# Obtain host of the Ceph instance that is available on the upshift cluster - we will explicitly use that instance.
# This can be also accessible via env variables so no need to state it explicitly.
THOTH_LOCATION = obtain_location('thoth-upshift-ceph', verify=False)

analysis_results = AnalysisResultsStore(
    'thoth-sbu',  # Name of Thoth deployment, we are acessing thoth data that is available on SBU cluster.
    host=THOTH_LOCATION,  # Optionally explicit.
    # These are available in Jupyter envirnment, if not, you need to explicitly provide them.
    #key_id='TBD',
    #secret_key='TBD',
    #bucket='TBD'
)


analysis_results.connect()

# %% [markdown]
# And let's get information about available methods:

# %%
help(analysis_results)
# Out:
# Help on AnalysisResultsStore in module thoth.storages.analyses object:
#
# class AnalysisResultsStore(thoth.storages.result_base.ResultStorageBase)
#  |  Adapter base for storing results.
#  |
#  |  Method resolution order:
#  |      AnalysisResultsStore
#  |      thoth.storages.result_base.ResultStorageBase
#  |      thoth.storages.base.StorageBase
#  |      builtins.object
#  |
#  |  Data and other attributes defined here:
#  |
#  |  RESULT_TYPE = 'analysis'
#  |
#  |  __abstractmethods__ = frozenset()
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from thoth.storages.result_base.ResultStorageBase:
#  |
#  |  __init__(self, deployment_name=None, *, host:str=None, key_id:str=None, secret_key:str=None, bucket:str=None, region:str=None)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  connect(self) -> None
#  |      Connect the given storage adapter.
#  |
#  |  get_document_listing(self) -> Generator[str, NoneType, NoneType]
#  |      Get listing of documents available in Ceph as a generator.
#  |
#  |  is_connected(self) -> bool
#  |      Check if the given database adapter is in connected state.
#  |
#  |  iterate_results(self) -> Generator[tuple, NoneType, NoneType]
#  |      Iterate over results available in the Ceph.
#  |
#  |  retrieve_document(self, document_id:str) -> dict
#  |      Retrieve a document from Ceph by its id.
#  |
#  |  store_document(self, document:dict) -> str
#  |      Store the given document in Ceph.
#  |
#  |  ----------------------------------------------------------------------
#  |  Class methods inherited from thoth.storages.result_base.ResultStorageBase:
#  |
#  |  get_document_id(document:dict) -> str from abc.ABCMeta
#  |      Get document id under which the given document should be stored.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors inherited from thoth.storages.base.StorageBase:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)

# %% [markdown]
# In the final cell, we will iterate over two results available on Ceph by retrieving document id and document itself:

# %%
from itertools import islice
from pprint import pprint


for document_id, document in islice(analysis_results.iterate_results(), 2):
    print("Result of analysis result {!r}:".format(document_id))
    pprint(document)
# Out:
# Result of analysis result 'fridex-thoth-package-extract-fedora-27-l36tv':
# {'metadata': {'analyzer': 'thoth-package-extract',
#               'analyzer_version': '1.0.0rc3',
#               'arguments': {'extract-image': {'image': 'fedora:27',
#                                               'no_pretty': False,
#                                               'output': 'http://thoth-result-api/api/v1/analysis-result',
#                                               'timeout': 0},
#                             'thoth-package-extract': {'no_color': False,
#                                                       'verbose': True}},
#               'datetime': '2018-03-19T16:29:06.140086',
#               'distribution': {'codename': 'Twenty Seven',
#                                'id': 'fedora',
#                                'like': '',
#                                'version': '27',
#                                'version_parts': {'build_number': '',
#                                                  'major': '27',
#                                                  'minor': ''}},
#               'hostname': 'fridex-thoth-package-extract-fedora-27-l36tv',
#               'python': {'api_version': 1013,
#                          'implementation_name': 'cpython',
#                          'major': 3,
#                          'micro': 4,
#                          'minor': 6,
#                          'releaselevel': 'final',
#                          'serial': 0}},
#  'result': {'mercator': [{'digests': {'manifest': '10460bb1fe6c167f6ef25f56cf940fab6fb40dd1'},
#                           'ecosystem': 'Python-Dist',
#                           'path': '/usr/lib/python3.6/site-packages/iniparse-0.4-py3.6.egg-info/PKG-INFO',
#                           'result': {'author': 'Paramjit Oberoi',
#                                      'author-email': 'param@cs.wisc.edu',
#                                      'classifier': 'Development Status :: 5 - '
#                                                    'Production/Stable\n'
#                                                    'Intended Audience :: '
#                                                    'Developers\n'
#                                                    'License :: OSI Approved :: '
#                                                    'MIT License\n'
#                                                    'License :: OSI Approved :: '
#                                                    'Python Software Foundation '
#                                                    'License\n'
#                                                    'Operating System :: OS '
#                                                    'Independent\n'
#                                                    'Programming Language :: '
#                                                    'Python\n'
#                                                    'Programming Language :: '
#                                                    'Python :: 2Programming '
#                                                    'Language :: Python :: 2.6\n'
#                                                    'Programming Language :: '
#                                                    'Python :: 2.7\n'
#                                                    'Programming Language :: '
#                                                    'Python :: 3\n'
#                                                    'Programming Language :: '
#                                                    'Python :: 3.3\n'
#                                                    'Programming Language :: '
#                                                    'Python :: 3.4Topic :: '
#                                                    'Software Development :: '
#                                                    'Libraries :: Python '
#                                                    'Modules',
#                                      'description': 'iniparse is an INI parser '
#                                                     'for  Python which is API '
#                                                     'compatible\n'
#                                                     'with the standard '
#                                                     "library's ConfigParser, "
#                                                     'preserves structure of '
#                                                     'INI\n'
#                                                     'files (order of sections '
#                                                     '& options, indentation, '
#                                                     'comments, and blank\n'
#                                                     'lines are preserved when '
#                                                     'data is updated), and is '
#                                                     'more convenient to\n'
#                                                     'use.',
#                                      'home-page': 'http://code.google.com/p/iniparse/',
#                                      'license': 'MIT',
#                                      'name': 'iniparse',
#                                      'platform': 'UNKNOWN',
#                                      'summary': 'Accessing and Modifying INI '
#                                                 'files',
#                                      'version': '0.4'}},
#                          {'digests': {'manifest': '638db309ccb9ca512fc1c7c9ac207028038b8d5c'},
#                           'ecosystem': 'Python-Dist',
#                           'path': '/usr/lib/python3.6/site-packages/pip-9.0.1.dist-info/metadata.json',
#                           'result': {'classifiers': ['Development Status :: 5 '
#                                                      '- Production/Stable',
#                                                      'Intended Audience :: '
#                                                      'Developers',
#                                                      'License :: OSI Approved '
#                                                      ':: MIT License',
#                                                      'Topic :: Software '
#                                                      'Development :: Build '
#                                                      'Tools',
#                                                      'Programming Language :: '
#                                                      'Python :: 2',
#                                                      'Programming Language :: '
#                                                      'Python :: 2.6',
#                                                      'Programming Language :: '
#                                                      'Python :: 2.7',
#                                                      'Programming Language :: '
#                                                      'Python :: 3',
#                                                      'Programming Language :: '
#                                                      'Python :: 3.3',
#                                                      'Programming Language :: '
#                                                      'Python :: 3.4',
#                                                      'Programming Language :: '
#                                                      'Python :: 3.5',
#                                                      'Programming Language :: '
#                                                      'Python :: Implementation '
#                                                      ':: PyPy'],
#                                      'extensions': {'python.commands': {'wrap_console': {'pip': 'pip:main',
#                                                                                          'pip3': 'pip:main',
#                                                                                          'pip3.6': 'pip:main'}},
#                                                     'python.details': {'contacts': [{'email': 'python-virtualenv@groups.google.com',
#                                                                                      'name': 'The '
#                                                                                              'pip '
#                                                                                              'developers',
#                                                                                      'role': 'author'}],
#                                                                        'document_names': {'description': 'DESCRIPTION.rst'},
#                                                                        'project_urls': {'Home': 'https://pip.pypa.io/'}},
#                                                     'python.exports': {'console_scripts': {'pip': 'pip:main',
#                                                                                            'pip3': 'pip:main',
#                                                                                            'pip3.6': 'pip:main'}}},
#                                      'extras': ['testing'],
#                                      'generator': 'bdist_wheel (0.30.0.a0)',
#                                      'keywords': ['easy_install',
#                                                   'distutils',
#                                                   'setuptools',
#                                                   'egg',
#                                                   'virtualenv'],
#                                      'license': 'MIT',
#                                      'metadata_version': '2.0',
#                                      'name': 'pip',
#                                      'requires_python': '>=2.6,!=3.0.*,!=3.1.*,!=3.2.*',
#                                      'run_requires': [{'extra': 'testing',
#                                                        'requires': ['mock',
#                                                                     'pretend',
#                                                                     'pytest',
#                                                                     'scripttest '
#                                                                     '(>=1.3)',
#                                                                     'virtualenv '
#                                                                     '(>=1.10)']}],
#                                      'summary': 'The PyPA recommended tool for '
#                                                 'installing Python packages.',
#                                      'test_requires': [{'requires': ['mock',
#                                                                      'pretend',
#                                                                      'pytest',
#                                                                      'scripttest '
#                                                                      '(>=1.3)',
#                                                                      'virtualenv '
#                                                                      '(>=1.10)']}],
#                                      'version': '9.0.1'}},
#                          {'digests': {'manifest': '17b684b084a699aac2d70e4ceb03ac69b652b493'},
#                           'ecosystem': 'Python-Dist',
#                           'path': '/usr/lib/python3.6/site-packages/setuptools-37.0.0.dist-info/metadata.json',
#                           'result': {'classifiers': ['Development Status :: 5 '
#                                                      '- Production/Stable',
#                                                      'Intended Audience :: '
#                                                      'Developers',
#                                                      'License :: OSI Approved '
#                                                      ':: MIT License',
#                                                      'Operating System :: OS '
#                                                      'Independent',
#                                                      'Programming Language :: '
#                                                      'Python :: 2',
#                                                      'Programming Language :: '
#                                                      'Python :: 2.7',
#                                                      'Programming Language :: '
#                                                      'Python :: 3',
#                                                      'Programming Language :: '
#                                                      'Python :: 3.3',
#                                                      'Programming Language :: '
#                                                      'Python :: 3.4',
#                                                      'Programming Language :: '
#                                                      'Python :: 3.5',
#                                                      'Programming Language :: '
#                                                      'Python :: 3.6',
#                                                      'Topic :: Software '
#                                                      'Development :: Libraries '
#                                                      ':: Python Modules',
#                                                      'Topic :: System :: '
#                                                      'Archiving :: Packaging',
#                                                      'Topic :: System :: '
#                                                      'Systems Administration',
#                                                      'Topic :: Utilities'],
#                                      'description_content_type': 'text/x-rst; '
#                                                                  'charset=UTF-8',
#                                      'extensions': {'python.commands': {'wrap_console': {'easy_install': 'setuptools.command.easy_install:main',
#                                                                                          'easy_install-3.6': 'setuptools.command.easy_install:main'}},
#                                                     'python.details': {'contacts': [{'email': 'distutils-sig@python.org',
#                                                                                      'name': 'Python '
#                                                                                              'Packaging '
#                                                                                              'Authority',
#                                                                                      'role': 'author'}],
#                                                                        'document_names': {'description': 'DESCRIPTION.rst',
#                                                                                           'license': 'LICENSE.txt'},
#                                                                        'project_urls': {'Home': 'https://github.com/pypa/setuptools'}},
#                                                     'python.exports': {'console_scripts': {'easy_install': 'setuptools.command.easy_install:main',
#                                                                                            'easy_install-3.6': 'setuptools.command.easy_install:main'},
#                                                                        'distutils.commands': {'alias': 'setuptools.command.alias:alias',
#                                                                                               'bdist_egg': 'setuptools.command.bdist_egg:bdist_egg',
#                                                                                               'bdist_rpm': 'setuptools.command.bdist_rpm:bdist_rpm',
#                                                                                               'bdist_wininst': 'setuptools.command.bdist_wininst:bdist_wininst',
#                                                                                               'build_clib': 'setuptools.command.build_clib:build_clib',
#                                                                                               'build_ext': 'setuptools.command.build_ext:build_ext',
#                                                                                               'build_py': 'setuptools.command.build_py:build_py',
#                                                                                               'develop': 'setuptools.command.develop:develop',
#                                                                                               'dist_info': 'setuptools.command.dist_info:dist_info',
#                                                                                               'easy_install': 'setuptools.command.easy_install:easy_install',
#                                                                                               'egg_info': 'setuptools.command.egg_info:egg_info',
#                                                                                               'install': 'setuptools.command.install:install',
#                                                                                               'install_egg_info': 'setuptools.command.install_egg_info:install_egg_info',
#                                                                                               'install_lib': 'setuptools.command.install_lib:install_lib',
#                                                                                               'install_scripts': 'setuptools.command.install_scripts:install_scripts',
#                                                                                               'register': 'setuptools.command.register:register',
#                                                                                               'rotate': 'setuptools.command.rotate:rotate',
#                                                                                               'saveopts': 'setuptools.command.saveopts:saveopts',
#                                                                                               'sdist': 'setuptools.command.sdist:sdist',
#                                                                                               'setopt': 'setuptools.command.setopt:setopt',
#                                                                                               'test': 'setuptools.command.test:test',
#                                                                                               'upload': 'setuptools.command.upload:upload',
#                                                                                               'upload_docs': 'setuptools.command.upload_docs:upload_docs'},
#                                                                        'distutils.setup_keywords': {'convert_2to3_doctests': 'setuptools.dist:assert_string_list',
#                                                                                                     'dependency_links': 'setuptools.dist:assert_string_list',
#                                                                                                     'eager_resources': 'setuptools.dist:assert_string_list',
#                                                                                                     'entry_points': 'setuptools.dist:check_entry_points',
#                                                                                                     'exclude_package_data': 'setuptools.dist:check_package_data',
#                                                                                                     'extras_require': 'setuptools.dist:check_extras',
#                                                                                                     'include_package_data': 'setuptools.dist:assert_bool',
#                                                                                                     'install_requires': 'setuptools.dist:check_requirements',
#                                                                                                     'namespace_packages': 'setuptools.dist:check_nsp',
#                                                                                                     'package_data': 'setuptools.dist:check_package_data',
#                                                                                                     'packages': 'setuptools.dist:check_packages',
#                                                                                                     'python_requires': 'setuptools.dist:check_specifier',
#                                                                                                     'setup_requires': 'setuptools.dist:check_requirements',
#                                                                                                     'test_loader': 'setuptools.dist:check_importable',
#                                                                                                     'test_runner': 'setuptools.dist:check_importable',
#                                                                                                     'test_suite': 'setuptools.dist:check_test_suite',
#                                                                                                     'tests_require': 'setuptools.dist:check_requirements',
#                                                                                                     'use_2to3': 'setuptools.dist:assert_bool',
#                                                                                                     'use_2to3_exclude_fixers': 'setuptools.dist:assert_string_list',
#                                                                                                     'use_2to3_fixers': 'setuptools.dist:assert_string_list',
#                                                                                                     'zip_safe': 'setuptools.dist:assert_bool'},
#                                                                        'egg_info.writers': {'PKG-INFO': 'setuptools.command.egg_info:write_pkg_info',
#                                                                                             'dependency_links.txt': 'setuptools.command.egg_info:overwrite_arg',
#                                                                                             'depends.txt': 'setuptools.command.egg_info:warn_depends_obsolete',
#                                                                                             'eager_resources.txt': 'setuptools.command.egg_info:overwrite_arg',
#                                                                                             'entry_points.txt': 'setuptools.command.egg_info:write_entries',
#                                                                                             'namespace_packages.txt': 'setuptools.command.egg_info:overwrite_arg',
#                                                                                             'requires.txt': 'setuptools.command.egg_info:write_requirements',
#                                                                                             'top_level.txt': 'setuptools.command.egg_info:write_toplevel_names'},
#                                                                        'setuptools.installation': {'eggsecutable': 'setuptools.command.easy_install:bootstrap'}}},
#                                      'extras': ['certs', 'ssl'],
#                                      'generator': 'bdist_wheel (0.30.0.a0)',
#                                      'keywords': ['CPAN',
#                                                   'PyPI',
#                                                   'distutils',
#                                                   'eggs',
#                                                   'package',
#                                                   'management'],
#                                      'metadata_version': '2.0',
#                                      'name': 'setuptools',
#                                      'requires_python': '>=2.7,!=3.0.*,!=3.1.*,!=3.2.*',
#                                      'run_requires': [{'extra': 'certs',
#                                                        'requires': ['certifi '
#                                                                     '(==2016.9.26)']},
#                                                       {'environment': "sys_platform=='win32'",
#                                                        'extra': 'ssl',
#                                                        'requires': ['wincertstore '
#                                                                     '(==0.2)']}],
#                                      'summary': 'Easily download, build, '
#                                                 'install, upgrade, and '
#                                                 'uninstall Python packages',
#                                      'version': '37.0.0'}},
#                          {'digests': {'manifest': '1153f208db7328880763cf52bdcf940baf221071'},
#                           'ecosystem': 'Python-Dist',
#                           'path': '/usr/lib/python3.6/site-packages/six-1.11.0.dist-info/metadata.json',
#                           'result': {'classifiers': ['Programming Language :: '
#                                                      'Python :: 2',
#                                                      'Programming Language :: '
#                                                      'Python :: 3',
#                                                      'Intended Audience :: '
#                                                      'Developers',
#                                                      'License :: OSI Approved '
#                                                      ':: MIT License',
#                                                      'Topic :: Software '
#                                                      'Development :: Libraries',
#                                                      'Topic :: Utilities'],
#                                      'extensions': {'python.details': {'contacts': [{'email': 'benjamin@python.org',
#                                                                                      'name': 'Benjamin '
#                                                                                              'Peterson',
#                                                                                      'role': 'author'}],
#                                                                        'document_names': {'description': 'DESCRIPTION.rst'},
#                                                                        'project_urls': {'Home': 'http://pypi.python.org/pypi/six/'}}},
#                                      'generator': 'bdist_wheel (0.30.0.a0)',
#                                      'license': 'MIT',
#                                      'metadata_version': '2.0',
#                                      'name': 'six',
#                                      'summary': 'Python 2 and 3 compatibility '
#                                                 'utilities',
#                                      'test_requires': [{'requires': ['pytest']}],
#                                      'version': '1.11.0'}}],
#             'rpm': ['xkeyboard-config-2.22-1.fc27.noarch',
#                     'emacs-filesystem-25.3-3.fc27.noarch',
#                     'fedora-repos-27-2.noarch',
#                     'setup-2.10.10-1.fc27.noarch',
#                     'basesystem-11-4.fc27.noarch',
#                     'libreport-filesystem-2.9.3-2.fc27.x86_64',
#                     'tzdata-2018c-1.fc27.noarch',
#                     'glibc-langpack-en-2.26-26.fc27.x86_64',
#                     'ncurses-libs-6.0-13.20170722.fc27.x86_64',
#                     'libsepol-2.7-2.fc27.x86_64',
#                     'libselinux-2.7-3.fc27.x86_64',
#                     'info-6.4-6.fc27.x86_64',
#                     'bzip2-libs-1.0.6-24.fc27.x86_64',
#                     'expat-2.2.5-1.fc27.x86_64',
#                     'nspr-4.18.0-1.fc27.x86_64',
#                     'elfutils-libelf-0.170-1.fc27.x86_64',
#                     'libgcrypt-1.8.2-1.fc27.x86_64',
#                     'libxml2-2.9.7-1.fc27.x86_64',
#                     'gmp-6.1.2-6.fc27.x86_64',
#                     'libzstd-1.3.3-1.fc27.x86_64',
#                     'chkconfig-1.10-3.fc27.x86_64',
#                     'libcom_err-1.43.5-2.fc27.x86_64',
#                     'libattr-2.4.47-21.fc27.x86_64',
#                     'sed-4.4-4.fc27.x86_64',
#                     'libunistring-0.9.7-3.fc27.x86_64',
#                     'lz4-libs-1.8.0-1.fc27.x86_64',
#                     'libcap-ng-0.7.8-5.fc27.x86_64',
#                     'nss-softokn-freebl-3.35.0-1.0.fc27.x86_64',
#                     'nss-softokn-3.35.0-1.0.fc27.x86_64',
#                     'keyutils-libs-1.5.10-3.fc27.x86_64',
#                     'grep-3.1-3.fc27.x86_64',
#                     'dbus-libs-1.12.0-1.fc27.x86_64',
#                     'p11-kit-trust-0.23.9-2.fc27.x86_64',
#                     'libusbx-1.0.21-4.fc27.x86_64',
#                     'libpsl-0.18.0-1.fc27.x86_64',
#                     'mpfr-3.1.6-1.fc27.x86_64',
#                     'gdbm-1.13-6.fc27.x86_64',
#                     'libdb-utils-5.3.28-27.fc27.x86_64',
#                     'kmod-libs-25-1.fc27.x86_64',
#                     'coreutils-common-8.27-20.fc27.x86_64',
#                     'elfutils-default-yama-scope-0.170-1.fc27.noarch',
#                     'ncurses-6.0-13.20170722.fc27.x86_64',
#                     'coreutils-8.27-20.fc27.x86_64',
#                     'python3-pip-9.0.1-14.fc27.noarch',
#                     'python3-3.6.4-8.fc27.x86_64',
#                     'libblkid-2.30.2-1.fc27.x86_64',
#                     'libmount-2.30.2-1.fc27.x86_64',
#                     'dbus-glib-0.108-4.fc27.x86_64',
#                     'libutempter-1.1.6-11.fc27.x86_64',
#                     'python3-libcomps-0.1.8-6.fc27.x86_64',
#                     'python3-iniparse-0.4-26.fc27.noarch',
#                     'gzip-1.8-4.fc27.x86_64',
#                     'libpwquality-1.4.0-3.fc27.x86_64',
#                     'nss-pem-1.0.3-6.fc27.x86_64',
#                     'nss-sysinit-3.35.0-1.1.fc27.x86_64',
#                     'libarchive-3.3.1-3.fc27.x86_64',
#                     'trousers-lib-0.3.13-9.fc27.x86_64',
#                     'libsss_nss_idmap-1.16.0-6.fc27.x86_64',
#                     'libsigsegv-2.11-3.fc27.x86_64',
#                     'krb5-libs-1.15.2-7.fc27.x86_64',
#                     'openldap-2.4.45-4.fc27.x86_64',
#                     'qrencode-libs-3.4.4-3.fc27.x86_64',
#                     'gnupg2-2.2.5-1.fc27.x86_64',
#                     'python3-gpg-1.9.0-6.fc27.x86_64',
#                     'util-linux-2.30.2-1.fc27.x86_64',
#                     'iptables-libs-1.6.1-4.fc27.x86_64',
#                     'device-mapper-libs-1.02.144-1.fc27.x86_64',
#                     'systemd-pam-234-10.git5f8984e.fc27.x86_64',
#                     'dbus-1.12.0-1.fc27.x86_64',
#                     'libcurl-7.55.1-9.fc27.x86_64',
#                     'python3-librepo-1.8.0-1.fc27.x86_64',
#                     'rpm-plugin-selinux-4.14.1-1.fc27.x86_64',
#                     'rpm-4.14.1-1.fc27.x86_64',
#                     'libdnf-0.11.1-1.fc27.x86_64',
#                     'deltarpm-3.6-24.fc27.x86_64',
#                     'python3-rpm-4.14.1-1.fc27.x86_64',
#                     'dnf-2.7.5-2.fc27.noarch',
#                     'rpm-plugin-systemd-inhibit-4.14.1-1.fc27.x86_64',
#                     'gnupg2-smime-2.2.5-1.fc27.x86_64',
#                     'nss-tools-3.35.0-1.1.fc27.x86_64',
#                     'pinentry-0.9.7-4.fc27.x86_64',
#                     'shared-mime-info-1.9-1.fc27.x86_64',
#                     'tar-1.29-7.fc27.x86_64',
#                     'libxkbcommon-0.7.1-5.fc27.x86_64',
#                     'rootfiles-8.1-21.fc27.noarch',
#                     'libgcc-7.3.1-5.fc27.x86_64',
#                     'publicsuffix-list-dafsa-20180223-1.fc27.noarch',
#                     'fedora-gpg-keys-27-2.noarch',
#                     'fedora-release-27-1.noarch',
#                     'filesystem-3.3-3.fc27.x86_64',
#                     'ncurses-base-6.0-13.20170722.fc27.noarch',
#                     'dnf-conf-2.7.5-2.fc27.noarch',
#                     'glibc-common-2.26-26.fc27.x86_64',
#                     'glibc-2.26-26.fc27.x86_64',
#                     'bash-4.4.19-1.fc27.x86_64',
#                     'pcre2-10.31-1.fc27.x86_64',
#                     'zlib-1.2.11-4.fc27.x86_64',
#                     'xz-libs-5.2.3-4.fc27.x86_64',
#                     'libgpg-error-1.27-3.fc27.x86_64',
#                     'libdb-5.3.28-27.fc27.x86_64',
#                     'nss-util-3.35.0-1.0.fc27.x86_64',
#                     'libcap-2.25-7.fc27.x86_64',
#                     'popt-1.16-12.fc27.x86_64',
#                     'readline-7.0-7.fc27.x86_64',
#                     'libuuid-2.30.2-1.fc27.x86_64',
#                     'lua-libs-5.3.4-7.fc27.x86_64',
#                     'libassuan-2.5.1-1.fc27.x86_64',
#                     'libffi-3.1-14.fc27.x86_64',
#                     'libacl-2.2.52-18.fc27.x86_64',
#                     'p11-kit-0.23.9-2.fc27.x86_64',
#                     'libidn2-2.0.4-3.fc27.x86_64',
#                     'sqlite-libs-3.20.1-1.fc27.x86_64',
#                     'audit-libs-2.8.2-1.fc27.x86_64',
#                     'libcrypt-nss-2.26-26.fc27.x86_64',
#                     'libksba-1.3.5-5.fc27.x86_64',
#                     'pcre-8.41-5.fc27.x86_64',
#                     'systemd-libs-234-10.git5f8984e.fc27.x86_64',
#                     'libtasn1-4.13-1.fc27.x86_64',
#                     'ca-certificates-2018.2.22-1.0.fc27.noarch',
#                     'libsemanage-2.7-2.fc27.x86_64',
#                     'acl-2.2.52-18.fc27.x86_64',
#                     'nettle-3.4-1.fc27.x86_64',
#                     'libcomps-0.1.8-6.fc27.x86_64',
#                     'libmetalink-0.1.3-4.fc27.x86_64',
#                     'libidn-1.33-4.fc27.x86_64',
#                     'file-libs-5.31-10.fc27.x86_64',
#                     'elfutils-libs-0.170-1.fc27.x86_64',
#                     'openssl-libs-1.1.0g-1.fc27.x86_64',
#                     'crypto-policies-20170816-2.gite0a4066.fc27.noarch',
#                     'python3-setuptools-37.0.0-1.fc27.noarch',
#                     'python3-libs-3.6.4-8.fc27.x86_64',
#                     'shadow-utils-4.5-4.fc27.x86_64',
#                     'glib2-2.54.3-2.fc27.x86_64',
#                     'libsecret-0.18.5-5.fc27.x86_64',
#                     'libfdisk-2.30.2-1.fc27.x86_64',
#                     'python3-six-1.11.0-1.fc27.noarch',
#                     'gnutls-3.5.18-2.fc27.x86_64',
#                     'cracklib-2.9.6-7.fc27.x86_64',
#                     'pam-1.3.0-6.fc27.x86_64',
#                     'nss-3.35.0-1.1.fc27.x86_64',
#                     'ima-evm-utils-1.1-2.fc27.x86_64',
#                     'libssh2-1.8.0-5.fc27.x86_64',
#                     'libsss_idmap-1.16.0-6.fc27.x86_64',
#                     'libverto-0.2.6-11.fc27.x86_64',
#                     'gawk-4.1.4-8.fc27.x86_64',
#                     'cyrus-sasl-lib-2.1.26-34.fc27.x86_64',
#                     'libseccomp-2.3.3-1.fc27.x86_64',
#                     'npth-1.5-3.fc27.x86_64',
#                     'gpgme-1.9.0-6.fc27.x86_64',
#                     'libsmartcols-2.30.2-1.fc27.x86_64',
#                     'libpcap-1.8.1-6.fc27.x86_64',
#                     'device-mapper-1.02.144-1.fc27.x86_64',
#                     'cryptsetup-libs-1.7.5-3.fc27.x86_64',
#                     'systemd-234-10.git5f8984e.fc27.x86_64',
#                     'libnghttp2-1.25.0-1.fc27.x86_64',
#                     'librepo-1.8.0-1.fc27.x86_64',
#                     'curl-7.55.1-9.fc27.x86_64',
#                     'rpm-libs-4.14.1-1.fc27.x86_64',
#                     'libsolv-0.6.33-1.fc27.x86_64',
#                     'python3-hawkey-0.11.1-1.fc27.x86_64',
#                     'rpm-build-libs-4.14.1-1.fc27.x86_64',
#                     'python3-dnf-2.7.5-2.fc27.noarch',
#                     'dnf-yum-2.7.5-2.fc27.noarch',
#                     'trousers-0.3.13-9.fc27.x86_64',
#                     'sssd-client-1.16.0-6.fc27.x86_64',
#                     'cracklib-dicts-2.9.6-7.fc27.x86_64',
#                     'python3-dbus-1.2.4-8.fc27.x86_64',
#                     'vim-minimal-8.0.1553-1.fc27.x86_64',
#                     'diffutils-3.6-3.fc27.x86_64',
#                     'langpacks-en-1.0-10.fc27.noarch',
#                     'gpg-pubkey-f5282ee4-58ac92a3'],
#             'rpm-dependencies': {'acl-2.2.52-18.fc27.x86_64': ['libacl = '
#                                                                '2.2.52-18.fc27',
#                                                                'libacl.so.1()(64bit)',
#                                                                'libacl.so.1(ACL_1.0)(64bit)',
#                                                                'libattr.so.1()(64bit)',
#                                                                'libc.so.6()(64bit)',
#                                                                'libc.so.6(GLIBC_2.14)(64bit)',
#                                                                'libc.so.6(GLIBC_2.2.5)(64bit)',
#                                                                'libc.so.6(GLIBC_2.3.4)(64bit)',
#                                                                'libc.so.6(GLIBC_2.4)(64bit)',
#                                                                'rpmlib(CompressedFileNames) '
#                                                                '<= 3.0.4-1',
#                                                                'rpmlib(FileDigests) '
#                                                                '<= 4.6.0-1',
#                                                                'rpmlib(PayloadFilesHavePrefix) '
#                                                                '<= 4.0-1',
#                                                                'rpmlib(PayloadIsXz) '
#                                                                '<= 5.2-1',
#                                                                'rtld(GNU_HASH)'],
#                                  'audit-libs-2.8.2-1.fc27.x86_64': ['/sbin/ldconfig',
#                                                                     '/sbin/ldconfig',
#                                                                     'config(audit-libs) '
#                                                                     '= '
#                                                                     '2.8.2-1.fc27',
#                                                                     'libaudit.so.1()(64bit)',
#                                                                     'libc.so.6()(64bit)',
#                                                                     'libc.so.6(GLIBC_2.14)(64bit)',
#                                                                     'libc.so.6(GLIBC_2.2.5)(64bit)',
#                                                                     'libc.so.6(GLIBC_2.3)(64bit)',
#                                                                     'libc.so.6(GLIBC_2.3.4)(64bit)',
#                                                                     'libc.so.6(GLIBC_2.4)(64bit)',
#                                                                     'libc.so.6(GLIBC_2.8)(64bit)',
#                                                                     'libcap-ng.so.0()(64bit)',
#                                                                     'rpmlib(CompressedFileNames) '
#                                                                     '<= '
#                                                                     '3.0.4-1',
#                                                                     'rpmlib(FileDigests) '
#                                                                     '<= '
#                                                                     '4.6.0-1',
#                                                                     'rpmlib(PayloadFilesHavePrefix) '
#                                                                     '<= 4.0-1',
#                                                                     'rpmlib(PayloadIsXz) '
#                                                                     '<= 5.2-1',
#                                                                     'rtld(GNU_HASH)'],
#                                  'basesystem-11-4.fc27.noarch': ['filesystem',
#                                                                  'rpmlib(CompressedFileNames) '
#                                                                  '<= 3.0.4-1',
#                                                                  'rpmlib(FileDigests) '
#                                                                  '<= 4.6.0-1',
#                                                                  'rpmlib(PayloadFilesHavePrefix) '
#                                                                  '<= 4.0-1',
#                                                                  'rpmlib(PayloadIsXz) '
#                                                                  '<= 5.2-1',
#                                                                  'setup'],
#                                  'bash-4.4.19-1.fc27.x86_64': ['/bin/sh',
#                                                                'config(bash) = '
#                                                                '4.4.19-1.fc27',
#                                                                'filesystem >= '
#                                                                '3',
#                                                                'libc.so.6()(64bit)',
#                                                                'libc.so.6(GLIBC_2.11)(64bit)',
#                                                                'libc.so.6(GLIBC_2.14)(64bit)',
#                                                                'libc.so.6(GLIBC_2.15)(64bit)',
#                                                                'libc.so.6(GLIBC_2.2.5)(64bit)',
#                                                                'libc.so.6(GLIBC_2.3)(64bit)',
#                                                                'libc.so.6(GLIBC_2.3.4)(64bit)',
#                                                                'libc.so.6(GLIBC_2.4)(64bit)',
#                                                                'libc.so.6(GLIBC_2.8)(64bit)',
#                                                                'libdl.so.2()(64bit)',
#                                                                'libdl.so.2(GLIBC_2.2.5)(64bit)',
#                                                                'libtinfo.so.6()(64bit)',
#                                                                'rpmlib(BuiltinLuaScripts) '
#                                                                '<= 4.2.2-1',
#                                                                'rpmlib(CompressedFileNames) '
#                                                                '<= 3.0.4-1',
#                                                                'rpmlib(FileDigests) '
#                                                                '<= 4.6.0-1',
#                                                                'rpmlib(PayloadFilesHavePrefix) '
#                                                                '<= 4.0-1',
#                                                                'rpmlib(PayloadIsXz) '
#                                                                '<= 5.2-1',
#                                                                'rtld(GNU_HASH)'],
#                                  'bzip2-libs-1.0.6-24.fc27.x86_64': ['/sbin/ldconfig',
#                                                                      '/sbin/ldconfig',
#                                                                      'libc.so.6()(64bit)',
#                                                                      'libc.so.6(GLIBC_2.2.5)(64bit)',
#                                                                      'libc.so.6(GLIBC_2.3)(64bit)',
#                                                                      'libc.so.6(GLIBC_2.3.4)(64bit)',
#                                                                      'libc.so.6(GLIBC_2.4)(64bit)',
#                                                                      'rpmlib(CompressedFileNames) '
#                                                                      '<= '
#                                                                      '3.0.4-1',
#                                                                      'rpmlib(FileDigests) '
#                                                                      '<= '
#                                                                      '4.6.0-1',
#                                                                      'rpmlib(PayloadFilesHavePrefix) '
#                                                                      '<= 4.0-1',
#                                                                      'rpmlib(PayloadIsXz) '
#                                                                      '<= 5.2-1',
#                                                                      'rtld(GNU_HASH)'],
#                                  'ca-certificates-2018.2.22-1.0.fc27.noarch': ['/bin/sh',
#                                                                                '/bin/sh',
#                                                                                '/bin/sh',
#                                                                                'config(ca-certificates) '
#                                                                                '= '
#                                                                                '2018.2.22-1.0.fc27',
#                                                                                'p11-kit '
#                                                                                '>= '
#                                                                                '0.23.4',
#                                                                                'p11-kit-trust '
#                                                                                '>= '
#                                                                                '0.23.4',
#                                                                                'rpmlib(CompressedFileNames) '
#                                                                                '<= '
#                                                                                '3.0.4-1',
#                                                                                'rpmlib(FileDigests) '
#                                                                                '<= '
#                                                                                '4.6.0-1',
#                                                                                'rpmlib(PayloadFilesHavePrefix) '
#                                                                                '<= '
#                                                                                '4.0-1',
#                                                                                'rpmlib(PayloadIsXz) '
#                                                                                '<= '
#                                                                                '5.2-1'],
#                                  'chkconfig-1.10-3.fc27.x86_64': ['libc.so.6()(64bit)',
#                                                                   'libc.so.6(GLIBC_2.14)(64bit)',
#                                                                   'libc.so.6(GLIBC_2.2.5)(64bit)',
#                                                                   'libc.so.6(GLIBC_2.3)(64bit)',
#                                                                   'libc.so.6(GLIBC_2.3.4)(64bit)',
# ...
#                                                            'liblzma.so.5()(64bit)',
#                                                            'liblzma.so.5(XZ_5.0)(64bit)',
#                                                            'liblzma.so.5(XZ_5.1.2alpha)(64bit)',
#                                                            'liblzma.so.5(XZ_5.2.2)(64bit)',
#                                                            'libpthread.so.0()(64bit)',
#                                                            'libpthread.so.0(GLIBC_2.2.5)(64bit)',
#                                                            'rpmlib(CompressedFileNames) '
#                                                            '<= 3.0.4-1',
#                                                            'rpmlib(FileDigests) '
#                                                            '<= 4.6.0-1',
#                                                            'rpmlib(PayloadFilesHavePrefix) '
#                                                            '<= 4.0-1',
#                                                            'rpmlib(PayloadIsXz) '
#                                                            '<= 5.2-1',
#                                                            'rtld(GNU_HASH)',
#                                                            'xz-libs = '
#                                                            '5.2.2-1.el7'],
#                                  'xz-libs-5.2.2-1.el7.x86_64': ['/sbin/ldconfig',
#                                                                 '/sbin/ldconfig',
#                                                                 'libc.so.6()(64bit)',
#                                                                 'libc.so.6(GLIBC_2.14)(64bit)',
#                                                                 'libc.so.6(GLIBC_2.17)(64bit)',
#                                                                 'libc.so.6(GLIBC_2.2.5)(64bit)',
#                                                                 'libc.so.6(GLIBC_2.4)(64bit)',
#                                                                 'libpthread.so.0()(64bit)',
#                                                                 'libpthread.so.0(GLIBC_2.2.5)(64bit)',
#                                                                 'libpthread.so.0(GLIBC_2.3.2)(64bit)',
#                                                                 'libpthread.so.0(GLIBC_2.3.3)(64bit)',
#                                                                 'rpmlib(CompressedFileNames) '
#                                                                 '<= 3.0.4-1',
#                                                                 'rpmlib(FileDigests) '
#                                                                 '<= 4.6.0-1',
#                                                                 'rpmlib(PayloadFilesHavePrefix) '
#                                                                 '<= 4.0-1',
#                                                                 'rpmlib(PayloadIsXz) '
#                                                                 '<= 5.2-1',
#                                                                 'rtld(GNU_HASH)'],
#                                  'yum-3.4.3-154.el7.centos.noarch': ['/usr/bin/python',
#                                                                      'config(yum) '
#                                                                      '= '
#                                                                      '3.4.3-154.el7.centos',
#                                                                      'cpio',
#                                                                      'diffutils',
#                                                                      'pygpgme',
#                                                                      'pyliblzma',
#                                                                      'python '
#                                                                      '>= 2.4',
#                                                                      'python(abi) '
#                                                                      '= 2.7',
#                                                                      'python-iniparse',
#                                                                      'python-sqlite',
#                                                                      'python-urlgrabber '
#                                                                      '>= '
#                                                                      '3.10-8',
#                                                                      'pyxattr',
#                                                                      'rpm >= '
#                                                                      '4.11.3-22',
#                                                                      'rpm-python',
#                                                                      'rpmlib(CompressedFileNames) '
#                                                                      '<= '
#                                                                      '3.0.4-1',
#                                                                      'rpmlib(FileDigests) '
#                                                                      '<= '
#                                                                      '4.6.0-1',
#                                                                      'rpmlib(PayloadFilesHavePrefix) '
#                                                                      '<= 4.0-1',
#                                                                      'rpmlib(PayloadIsXz) '
#                                                                      '<= 5.2-1',
#                                                                      'yum-metadata-parser '
#                                                                      '>= 1.1.0',
#                                                                      'yum-plugin-fastestmirror'],
#                                  'yum-metadata-parser-1.1.4-10.el7.x86_64': ['glib2 '
#                                                                              '>= '
#                                                                              '2.15',
#                                                                              'libc.so.6()(64bit)',
#                                                                              'libc.so.6(GLIBC_2.2.5)(64bit)',
#                                                                              'libc.so.6(GLIBC_2.4)(64bit)',
#                                                                              'libglib-2.0.so.0()(64bit)',
#                                                                              'libpthread.so.0()(64bit)',
#                                                                              'libpython2.7.so.1.0()(64bit)',
#                                                                              'libsqlite3.so.0()(64bit)',
#                                                                              'libxml2.so.2()(64bit)',
#                                                                              'libxml2.so.2(LIBXML2_2.4.30)(64bit)',
#                                                                              'python(abi) '
#                                                                              '= '
#                                                                              '2.7',
#                                                                              'rpmlib(CompressedFileNames) '
#                                                                              '<= '
#                                                                              '3.0.4-1',
#                                                                              'rpmlib(FileDigests) '
#                                                                              '<= '
#                                                                              '4.6.0-1',
#                                                                              'rpmlib(PartialHardlinkSets) '
#                                                                              '<= '
#                                                                              '4.0.4-1',
#                                                                              'rpmlib(PayloadFilesHavePrefix) '
#                                                                              '<= '
#                                                                              '4.0-1',
#                                                                              'rpmlib(PayloadIsXz) '
#                                                                              '<= '
#                                                                              '5.2-1',
#                                                                              'rtld(GNU_HASH)'],
#                                  'yum-plugin-fastestmirror-1.1.31-42.el7.noarch': ['config(yum-plugin-fastestmirror) '
#                                                                                    '= '
#                                                                                    '1.1.31-42.el7',
#                                                                                    'rpmlib(CompressedFileNames) '
#                                                                                    '<= '
#                                                                                    '3.0.4-1',
#                                                                                    'rpmlib(FileDigests) '
#                                                                                    '<= '
#                                                                                    '4.6.0-1',
#                                                                                    'rpmlib(PartialHardlinkSets) '
#                                                                                    '<= '
#                                                                                    '4.0.4-1',
#                                                                                    'rpmlib(PayloadFilesHavePrefix) '
#                                                                                    '<= '
#                                                                                    '4.0-1',
#                                                                                    'rpmlib(PayloadIsXz) '
#                                                                                    '<= '
#                                                                                    '5.2-1',
#                                                                                    'yum '
#                                                                                    '>= '
#                                                                                    '3.0'],
#                                  'yum-plugin-ovl-1.1.31-42.el7.noarch': ['config(yum-plugin-ovl) '
#                                                                          '= '
#                                                                          '1.1.31-42.el7',
#                                                                          'rpmlib(CompressedFileNames) '
#                                                                          '<= '
#                                                                          '3.0.4-1',
#                                                                          'rpmlib(FileDigests) '
#                                                                          '<= '
#                                                                          '4.6.0-1',
#                                                                          'rpmlib(PartialHardlinkSets) '
#                                                                          '<= '
#                                                                          '4.0.4-1',
#                                                                          'rpmlib(PayloadFilesHavePrefix) '
#                                                                          '<= '
#                                                                          '4.0-1',
#                                                                          'rpmlib(PayloadIsXz) '
#                                                                          '<= '
#                                                                          '5.2-1',
#                                                                          'yum '
#                                                                          '>= '
#                                                                          '3.4.3'],
#                                  'yum-utils-1.1.31-42.el7.noarch': ['/usr/bin/python',
#                                                                     'libxml2-python',
#                                                                     'python(abi) '
#                                                                     '= 2.7',
#                                                                     'python-kitchen',
#                                                                     'rpmlib(CompressedFileNames) '
#                                                                     '<= '
#                                                                     '3.0.4-1',
#                                                                     'rpmlib(FileDigests) '
#                                                                     '<= '
#                                                                     '4.6.0-1',
#                                                                     'rpmlib(PartialHardlinkSets) '
#                                                                     '<= '
#                                                                     '4.0.4-1',
#                                                                     'rpmlib(PayloadFilesHavePrefix) '
#                                                                     '<= 4.0-1',
#                                                                     'rpmlib(PayloadIsXz) '
#                                                                     '<= 5.2-1',
#                                                                     'yum >= '
#                                                                     '3.4.3-143'],
#                                  'zlib-1.2.7-17.el7.x86_64': ['/sbin/ldconfig',
#                                                               '/sbin/ldconfig',
#                                                               'libc.so.6()(64bit)',
#                                                               'libc.so.6(GLIBC_2.14)(64bit)',
#                                                               'libc.so.6(GLIBC_2.2.5)(64bit)',
#                                                               'libc.so.6(GLIBC_2.3.4)(64bit)',
#                                                               'libc.so.6(GLIBC_2.4)(64bit)',
#                                                               'rpmlib(CompressedFileNames) '
#                                                               '<= 3.0.4-1',
#                                                               'rpmlib(FileDigests) '
#                                                               '<= 4.6.0-1',
#                                                               'rpmlib(PayloadFilesHavePrefix) '
#                                                               '<= 4.0-1',
#                                                               'rpmlib(PayloadIsXz) '
#                                                               '<= 5.2-1',
#                                                               'rtld(GNU_HASH)']}}}
