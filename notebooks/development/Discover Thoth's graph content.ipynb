# %% [markdown]
# ## Discover Thoth's Graph Structure

# %% [markdown]
# This notebook is addressed to users and developers of Thoth that want to discover the content of Thoth's Graph Database.

# %% [markdown]
# First it's important to look at schema model of Thoth Graph Database.

# %% [markdown]
# ## 1. Connect to JanusGraph Instance

# %% [markdown]
# In order to discover what is inside the Graph Database, we need to connect to JanusGraph instance

# %%
from thoth.storages.graph import GraphDatabase
from thoth.lab import GraphQueryResult as gqr

graph_db = GraphDatabase.create('janusgraph.test.thoth-station.ninja', port=8182)
graph_db.connect()
g = graph_db.g   # We will use raw Gremlin traversal in examples.
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# ~/.local/share/virtualenvs/notebooks-3RWCrxj8/lib/python3.6/site-packages/aiohttp/connector.py in _create_direct_connection(self, req)
#     709                     server_hostname=hinfo['hostname'] if sslcontext else None,
# --> 710                     local_addr=self._local_addr)
#     711                 has_cert = transp.get_extra_info('sslcontext')
#
# ~/.local/share/virtualenvs/notebooks-3RWCrxj8/lib/python3.6/site-packages/uvloop/loop.pyx in create_connection()
#
# ~/.local/share/virtualenvs/notebooks-3RWCrxj8/lib/python3.6/site-packages/uvloop/loop.pyx in uvloop.loop.Loop.create_connection()
#
# TimeoutError: [Errno 110] Connection timed out
#
# The above exception was the direct cause of the following exception:
#
# ClientConnectorError                      Traceback (most recent call last)
# ~/.local/share/virtualenvs/notebooks-3RWCrxj8/lib/python3.6/site-packages/aiohttp/connector.py in connect(self, req)
#     377             try:
# --> 378                 proto = yield from self._create_connection(req)
#     379             except OSError as exc:
#
# ~/.local/share/virtualenvs/notebooks-3RWCrxj8/lib/python3.6/site-packages/aiohttp/connector.py in _create_connection(self, req)
#     686         else:
# --> 687             _, proto = yield from self._create_direct_connection(req)
#     688
#
# ~/.local/share/virtualenvs/notebooks-3RWCrxj8/lib/python3.6/site-packages/aiohttp/connector.py in _create_direct_connection(self, req)
#     736                 'Can not connect to %s:%s [%s]' %
# --> 737                 (req.host, req.port, exc.strerror)) from exc
#     738
#
# ClientConnectorError: [Errno 110] Can not connect to janusgraph.test.thoth-station.ninja:8182 [Connection timed out]
#
# The above exception was the direct cause of the following exception:
#
# ClientConnectorError                      Traceback (most recent call last)
# <ipython-input-1-6678b5f544ba> in <module>
#       3
#       4 graph_db = GraphDatabase.create('janusgraph.test.thoth-station.ninja', port=8182)
# ----> 5 graph_db.connect()
#       6 g = graph_db.g   # We will use raw Gremlin traversal in examples.
#
# ~/work/aicoe/storages/thoth/storages/graph/janusgraph.py in connect(self)
#     180         self.app = loop.run_until_complete(
#     181             Goblin.open(
# --> 182                 loop, get_hashable_id=_get_hashable_id, hosts=self.hosts, port=self.port, serializer=self.serializer
#     183             )
#     184         )
#
# ~/.local/share/virtualenvs/notebooks-3RWCrxj8/lib/python3.6/site-packages/uvloop/loop.pyx in uvloop.loop.Loop.run_until_complete()
#
# ~/.local/share/virtualenvs/notebooks-3RWCrxj8/lib/python3.6/site-packages/goblin/app.py in open(cls, loop, provider, get_hashable_id, aliases, **config)
#      47         cluster = await aiogremlin.Cluster.open(
#      48             loop, aliases=aliases,
# ---> 49             **config)
#      50         app = Goblin(cluster, provider=provider,
#      51                      get_hashable_id=get_hashable_id, aliases=aliases)
#
# ~/.local/share/virtualenvs/notebooks-3RWCrxj8/lib/python3.6/site-packages/aiogremlin/driver/cluster.py in open(cls, loop, aliases, configfile, **config)
#      84         if configfile:
#      85             cluster.config_from_file(configfile)
# ---> 86         await cluster.establish_hosts()
#      87         return cluster
#      88
#
# ~/.local/share/virtualenvs/notebooks-3RWCrxj8/lib/python3.6/site-packages/aiogremlin/driver/cluster.py in establish_hosts(self)
#     132             url = '{}://{}:{}/gremlin'.format(scheme, hostname, port)
#     133             host = await driver.GremlinServer.open(
# --> 134                 url, self._loop, **dict(self._config))
#     135             self._hosts.append(host)
#     136             self._hostmap[hostname] = host
#
# ~/.local/share/virtualenvs/notebooks-3RWCrxj8/lib/python3.6/site-packages/aiogremlin/driver/server.py in open(cls, url, loop, **config)
#      96
#      97         host = cls(url, loop, **config)
# ---> 98         await host.initialize()
#      99         return host
#
# ~/.local/share/virtualenvs/notebooks-3RWCrxj8/lib/python3.6/site-packages/aiogremlin/driver/server.py in initialize(self)
#      71             self._max_times_acquired, self._max_inflight,
#      72             self._response_timeout, self._message_serializer, self._provider)
# ---> 73         await conn_pool.init_pool()
#      74         self._pool = conn_pool
#      75
#
# ~/.local/share/virtualenvs/notebooks-3RWCrxj8/lib/python3.6/site-packages/aiogremlin/driver/pool.py in init_pool(self)
#     129                                               self._response_timeout,
#     130                                               self._message_serializer,
# --> 131                                               self._provider)
#     132             self._available.append(conn)
#     133
#
# ~/.local/share/virtualenvs/notebooks-3RWCrxj8/lib/python3.6/site-packages/aiogremlin/driver/pool.py in _get_connection(self, username, password, max_inflight, response_timeout, message_serializer, provider)
#     198             username=username, password=password,
#     199             response_timeout=response_timeout,
# --> 200             message_serializer=message_serializer, provider=provider)
#     201         conn = PooledConnection(conn, self)
#     202         return conn
#
# ~/.local/share/virtualenvs/notebooks-3RWCrxj8/lib/python3.6/site-packages/aiogremlin/driver/connection.py in open(cls, url, loop, protocol, transport_factory, ssl_context, username, password, max_inflight, response_timeout, message_serializer, provider)
#      95             transport_factory = lambda: AiohttpTransport(loop)
#      96         transport = transport_factory()
# ---> 97         await transport.connect(url, ssl_context=ssl_context)
#      98         return cls(url, transport, protocol, loop, username, password,
#      99                    max_inflight, response_timeout, message_serializer,
#
# ~/.local/share/virtualenvs/notebooks-3RWCrxj8/lib/python3.6/site-packages/aiogremlin/driver/aiohttp/transport.py in connect(self, url, ssl_context)
#      16         self._client_session = aiohttp.ClientSession(
#      17             loop=self._loop, connector=connector)
# ---> 18         self._ws = await self._client_session.ws_connect(url)
#      19         self._connected = True
#      20
#
# ~/.local/share/virtualenvs/notebooks-3RWCrxj8/lib/python3.6/site-packages/aiohttp/helpers.py in __await__(self)
#     100     if PY_35:
#     101         def __await__(self):
# --> 102             ret = yield from self._coro
#     103             return ret
#     104
#
# ~/.local/share/virtualenvs/notebooks-3RWCrxj8/lib/python3.6/site-packages/aiohttp/client.py in _ws_connect(self, url, protocols, timeout, receive_timeout, autoclose, autoping, heartbeat, auth, origin, headers, proxy, proxy_auth)
#     388                                    auth=auth,
#     389                                    proxy=proxy,
# --> 390                                    proxy_auth=proxy_auth)
#     391
#     392         try:
#
# ~/.local/share/virtualenvs/notebooks-3RWCrxj8/lib/python3.6/site-packages/aiohttp/helpers.py in __iter__(self)
#      95     @asyncio.coroutine
#      96     def __iter__(self):
# ---> 97         ret = yield from self._coro
#      98         return ret
#      99
#
# ~/.local/share/virtualenvs/notebooks-3RWCrxj8/lib/python3.6/site-packages/aiohttp/client.py in _request(self, method, url, params, data, json, headers, skip_auto_headers, auth, allow_redirects, max_redirects, encoding, compress, chunked, expect100, read_until_eof, proxy, proxy_auth, timeout)
#     229                     try:
#     230                         with CeilTimeout(self._conn_timeout, loop=self._loop):
# --> 231                             conn = yield from self._connector.connect(req)
#     232                     except asyncio.TimeoutError as exc:
#     233                         raise ServerTimeoutError(
#
# ~/.local/share/virtualenvs/notebooks-3RWCrxj8/lib/python3.6/site-packages/aiohttp/connector.py in connect(self, req)
#     381                     exc.errno,
#     382                     'Cannot connect to host {0[0]}:{0[1]} ssl:{0[2]} [{1}]'
# --> 383                     .format(key, exc.strerror)) from exc
#     384             finally:
#     385                 self._acquired.remove(placeholder)
#
# ClientConnectorError: [Errno 110] Cannot connect to host janusgraph.test.thoth-station.ninja:8182 ssl:False [Can not connect to janusgraph.test.thoth-station.ninja:8182 [Connection timed out]]

# %% [markdown]
# We need to import objects that will be used in the notebook

# %%
import pandas as pd
from pprint import pprint
from thoth.solver import pip_compile
from thoth.storages.graph.models import ALL_MODELS
from gremlin_python.process.graph_traversal import has
from gremlin_python.process.traversal import Operator
from gremlin_python.process.traversal import Pop
from gremlin_python.process.traversal import not_
from gremlin_python.process.traversal import P
from gremlin_python.process.graph_traversal import identity
from gremlin_python.process.graph_traversal import outE
from gremlin_python.process.graph_traversal import out
from gremlin_python.process.graph_traversal import inE
from gremlin_python.process.graph_traversal import inV
from gremlin_python.process.graph_traversal import select
from gremlin_python.process.graph_traversal import values
from gremlin_python.process.graph_traversal import fold
from gremlin_python.process.graph_traversal import constant
from gremlin_python.process.graph_traversal import project

# %% [markdown]
# ## 2. Vertex and Edge Labels

# %% [markdown]
# List all the available vertex labels in the graph database

# %%
# Create list of vertices 
vertex_labels = []
for element in ALL_MODELS:

    if element.__type__ == "vertex":
        vertex_labels.append(element.__label__)
        
# Create the pandas DataFrame 
df = pd.DataFrame(vertex_labels, columns = ['Vertex'])
df
# Out:
#                         Vertex
# 0              rpm_requirement
# 1        buildtime_environment
# 2              python_artifact
# 3         python_package_index
# 4          deb_package_version
# 5          user_software_stack
# 6            build_observation
# 7         hardware_information
# 8             ecosystem_solver
# 9          rpm_package_version
# 10                     package
# 11         runtime_environment
# 12      python_package_version
# 13                         cve
# 14   inspection_software_stack
# 15  software_stack_observation
# 16      adviser_software_stack

# %% [markdown]
# List all the available edge labels in the graph database

# %%
# Create list of edges
edge_labels = []
for element in ALL_MODELS:

    if element.__type__ == "edge":
        edge_labels.append(element.__label__)
        
# Create the pandas DataFrame 
df = pd.DataFrame(edge_labels, columns = ['Edge'])
df
# Out:
#                  Edge
# 0            observed
# 1     deb_pre_depends
# 2            requires
# 3           builds_on
# 4              solved
# 5          depends_on
# 6             runs_on
# 7         has_version
# 8       creates_stack
# 9          is_part_of
# 10       deb_replaces
# 11          builds_in
# 12        deb_depends
# 13  has_vulnerability
# 14            runs_in
# 15       has_artifact

# %% [markdown]
# ## 3 Vertex and Edge Instances

# %% [markdown]
# Let's have an idea of the size of Thoth's Graph

# %%
print(f"Number of vertex instances in the graph database: {gqr(g.V().count().next()).result:d}")
print(f"Number of edge instances in the graph database: {gqr(g.E().count().next()).result:d}")
# Out:
# Number of vertex instances in the graph database: 38877
# Number of edge instances in the graph database: 586892

# %% [markdown]
# Let's see which vertex label has more instances

# %%
# Extract the number of instances for each vertex label

# List of vertex labels
vertex_labels = [element.__label__ for element in ALL_MODELS if element.__type__ == "vertex"]

# Dict of vertex labels and counts 
vertices_number = gqr(g.V().has("__label__").has("__type__", "vertex").groupCount().by("__label__").next()).result

list_vertices_counts = []

for vertex in vertex_labels:
    
    if vertex in vertices_number.keys():
        
        list_vertices_counts.append([vertex, vertices_number[vertex]])
        
    else:
        list_vertices_counts.append([vertex, 0])
        

print(f"\nNumber of vertex instances present in the graph database (sum): {sum(vertex_c[1] for vertex_c in list_vertices_counts)}")
print(f"Number of vertex instances present in the graph database: {gqr(graph_db.g.V().count().next()).result:d}")
# Out:
# Number of vertex instances present in the graph database (sum): 38876
# Number of vertex instances present in the graph database: 38877

# %%
# Show the number of instances for each vertex label
df = pd.DataFrame(list_vertices_counts, columns = ['Vertex', 'N. Instances']).sort_values(by='N. Instances',ascending=False)
df
# Out:
#                         Vertex  N. Instances
# 14      python_package_version         21733
# 5              python_artifact         14706
# 16                     package           941
# 0                          cve           796
# 6              rpm_requirement           513
# 15         rpm_package_version           174
# 7         python_package_index             7
# 13            ecosystem_solver             4
# 3        buildtime_environment             1
# 11         runtime_environment             1
# 4   software_stack_observation             0
# 1    inspection_software_stack             0
# 9          user_software_stack             0
# 10           build_observation             0
# 12        hardware_information             0
# 2       adviser_software_stack             0
# 8          deb_package_version             0

# %% [markdown]
# Let's see which edge label has more instances

# %%
# %%time

# List of edge labels
edge_labels = [element.__label__ for element in ALL_MODELS if element.__type__ == "edge"]

# Dict of edge labels and counts 
edges_number = gqr(g.E().has("__label__").has("__type__", "edge").groupCount().by("__label__").next()).result

list_edges_counts = []

for edge in edge_labels:
    
    if edge in edges_number.keys():
        
        list_edges_counts.append([edge, edges_number[edge]])
        
    else:
        list_edges_counts.append([edge, 0])
        

print(f"\nNumber of edge instances present in the graph database (sum): {sum(edge_c[1] for edge_c in list_edges_counts)}")
print(f"Number of edge instances present in the graph database: {gqr(graph_db.g.E().count().next()).result:d}")
# Out:
# Number of edge instances present in the graph database (sum): 599881
# Number of edge instances present in the graph database: 599881
# CPU times: user 8.6 ms, sys: 1.59 ms, total: 10.2 ms
# Wall time: 47.8 s

# %%
# Show the number of instances for each vertex label
df = pd.DataFrame(list_edges_counts, columns = ['Edge', 'N. Instances']).sort_values(by='N. Instances',ascending=False)
df
# Out:
#                  Edge  N. Instances
# 9              solved        404583
# 10         depends_on        119157
# 1   has_vulnerability         34796
# 12        has_version         22276
# 4        has_artifact         15455
# 7            requires          3350
# 14         is_part_of           264
# 0         deb_depends             0
# 2             runs_in             0
# 3           builds_in             0
# 5            observed             0
# 6     deb_pre_depends             0
# 8           builds_on             0
# 11            runs_on             0
# 13      creates_stack             0
# 15       deb_replaces             0

# %% [markdown]
# # 4. Discover the packages inside Thoth

# %% [markdown]
# Check the allowed sources for the packages inside Thoth database

# %%
urls_list = graph_db.get_python_package_index_urls()

df = pd.DataFrame(urls_list, columns = ['URL'])
df
# Out:
#                                                  URL
# 0                            https://pypi.org/simple
# 1  https://tensorflow.pypi.thoth-station.ninja/in...
# 2  https://tensorflow.pypi.thoth-station.ninja/in...
# 3  https://tensorflow.pypi.thoth-station.ninja/in...
# 4  https://tensorflow.pypi.thoth-station.ninja/in...
# 5  https://tensorflow.pypi.thoth-station.ninja/in...
# 6  https://tensorflow.pypi.thoth-station.ninja/in...

# %% [markdown]
# Let's take a look at which python packages are inside Thoth

# %%
# Select a letter
letter = 'g'

# %%
# Extract Packages for selected letter
all_packages = gqr(
    g.V()
    .has('__label__', 'package')
    .order().by('package_name')
    .project('package').by('package_name')
    .toList()
).result
    
packages_list = [package['package'] for package in all_packages if package['package'][0] == letter]    
print(f"The number of packages for letter {letter} is: {len(packages_list)}\n")
# Out:
# The number of packages for letter g is: 12

# %%
# Visualize packages for selected letter
df = pd.DataFrame(packages_list, columns = [letter])
df
# Out:
#                    g
# 0          gandi-cli
# 1               gast
# 2             genshi
# 3             gevent
# 4   geventhttpclient
# 5             girder
# 6   gitlab-languages
# 7           gns3-gui
# 8            go-http
# 9   google-appengine
# 10      google-pasta
# 11            grpcio

# %% [markdown]
# For the packages extracted, let's see how many versions are available

# %%
# %%time
# Count all package versions (Python and RPM)
package_versions_results = []

for package in packages_list:
    
    n_python_package_versions = gqr(g.V()
                              .has("__label__", "package")
                              .has("package_name", package)
                              .outE()
                              .has("__label__","has_version")
                              .inV()
                              .has('__label__', 'python_package_version')
                              .count()
                              .next()
                             ).result
    
    n_rpm_package_versions = gqr(g.V()
                          .has("__label__", "package")
                          .has("package_name", package)
                          .outE()
                          .has("__label__","has_version")
                          .inV()
                          .has('__label__', 'rpm_package_version')
                          .count()
                          .next()
                         ).result
    
    package_versions_results.append([package,
                                 n_python_package_versions,
                                 n_rpm_package_versions,
                                 n_python_package_versions +  n_rpm_package_versions])

# %%
# Visualize packages for selected letter
df = pd.DataFrame(package_versions_results, columns = ['package_name', 'n_python_package_version',
                                                      'n_rpm_package_version', 'total_package_versions'])
df
# Out:
#         package_name  n_python_package_version  n_rpm_package_version  \
# 0          gandi-cli                         3                      0
# 1               gast                         5                      0
# 2             genshi                        15                      0
# 3             gevent                        18                      0
# 4   geventhttpclient                         2                      0
# 5             girder                        49                      0
# 6   gitlab-languages                        12                      0
# 7           gns3-gui                        51                      0
# 8   google-appengine                         1                      0
# 9       google-pasta                         3                      0
# 10            grpcio                        55                      0
#
#     total_package_versions
# 0                        3
# 1                        5
# 2                       15
# 3                       18
# 4                        2
# 5                       49
# 6                       12
# 7                       51
# 8                        1
# 9                        3
# 10                      55

# %% [markdown]
# # 5. Select one package and discover more about it

# %%
# Select the package
package_name = 'gast'

# %% [markdown]
# We retrieve all the versions available in Thoth's graph from any ecosystem for the selected package

# %%
# %%time

gqr(
    g.V().
    has('package_name', package_name)
    .outE().has('__label__', 'has_version')
    .inV()
    .order().by('package_version')
    .project('package', 'version', 'ecosystem').by('package_name').by('package_version').by('ecosystem')
    .toList()
).to_dataframe()

# %% [markdown]
# # 7. Inspect packages

# %%
packages_vector_all = gqr(g.V().has('__label__', 'package').groupCount().by("package_name").next()).result

# %%
# Check how many packages are inserted in the wrong format
packages_vector = [pkg for pkg in packages_vector_all.keys() if len(pkg) < 55]
wrong_packages_vector = [pkg for pkg in packages_vector_all.keys() if len(pkg) > 55]
print(packages_vector)
print(len(packages_vector))
print(wrong_packages_vector)
print(len(wrong_packages_vector))
# Out:
# ['edrnsite-policy', 'django-autocomplete-light', 'html5', 'blinkpy', 'django-secure-auth', 'anncolvar', 'pyarmor', 'coincurve', 'lxml', 'soupsieve', 'definitions', 'passlib', 'repoze-lru', 'nova', 'django-anymail', 'django-safedelete', 'click', 'sqlalchemy', 'django-make-app', 'js-videojs', 'python-nomad', 'idna', 'notable', 'soappy', 'yaybu', 'beautifulsoup', 'django-modern-rpc', 'django-material', 'flask-micropub', 'pygresql', 'pyjwt', 'pycapnp', 'dulwich', 'eth-hash', 'etherweaver', 'flask-security-fork', 'reg', 'flask-i18n', 'serpent', 'cryptacular', 'satosa', 'pyvcloud', 'swift', 'cinder', 'python-smooch', 'django-anonymizer', 'cryptography', 'django-fiber', 'misago', 'plone', 'pyusb', 'seed-stage-based-messaging', 'pbr', 'rope', 'paste', 'mysql-connector-python', 'mezzanine', 'requests-kerberos', 'pcp', 'fresco', 'croniter', 'gandi-cli', 'bigchaindb-driver', 'pypiserver', 'vermin', 'swauth', 'foolscap', 'cbapi', 'frozendict', 'splash', 'argh', 'kinto-dist', 'katka-core', 'tmc', 'ansible-vault', 'ambient-api', 'python-bugzilla', 'ptah', 'portalocker', 'pex', 'dj-database-url', 'python-otr', 'mr-migrator', 'attrs', 'streamsx-objectstorage', 'msgpack', 'collective-documentviewer', 'isodate', 'django-envelope', 'cosmos-wfm', 'zhmc-ansible-modules', 'zope-html', 'flask-images', 'plone-app-event', 'tox', 'chanjo-report', 'scipy', 'cfscrape', 'quilt', 'markdown2', 'raven', 'pytest-server-fixtures', 'static3', 'authbwc', 'tendenci', 'future', 'ruamel-yaml', 'rlp', 'python-cjson', 'pyshop', 'flask-statsdclient', 'ftw-dashboard-portlets-postit', 'py-ms', 'myghtyutils', 'pip', 'drfdocs', 'birdhousebuilder-recipe-nginx', 'slackeventsapi', 'django-uni-form', 'stormpath-sdk', 'voluptuous-serialize', 'pyramid-weblayer', 'ngraph-mxnet', 'django-filter', 'configparser', 'bincrafters-envy', 'mixminion', 'soapfish', 'mock', 'products-cmfplone', 'livefyre', 'django-watchman', 'supervisor', 'async-timeout', 'django-fernet-fields', 'more-itertools', 'python-saml', 'pconf', 'toro', 'keystonemiddleware', 'urllib3', 'dateable-chronos', 'pymongo', 'django-discord-bind', 'ecdsa', 'cov-core', 'lambda-tools', 'pootle', 'mtprotoproxy', 'base58', 'recurly', 'colorama', 'pillow', 'ply', 'block-io', 'tuf', 'psycopg2', 'marshmallow', 'wsgiref', 'phileo', 'pysandbox', 'python-magic', 'fedmsg', 'pmr2-oauth', 'django-cache-url', 'django-epiceditor', 'gns3-gui', 'aiocouchdb', 'buildbot', 'onegov-form', 'ftw-permissionmanager', 'httpauth', 'aspen', 'pyyaml', 'tensorboard', 'sequoia-client-sdk', 'mantissa', 'flask', 'rsa', 'telemeta', 'oodt', 'pluggy', 'suds', 'voluptuous', 'pep8', 'astral', 'zodb', 'ansible', 'products-ploneformgen', 'ftw-mail', 'celery', 'django-crm', 'markdown', 'python-openflow', 'distribute', 'websockets', 'exifread', 'astor', 'moin', 'rtv', 'django-markupfield', 'hydroshare', 'olefile', 'clam', 'ctypes', 'kubernetes', 'qi-jabberhelpdesk', 'pydal', 'knowledge-repo', 'namedlist', 'keras', 'pyxmlsecurity', 'webob', 'mgp2pdf', 'flask-logger', 'pyftdi', 'django-user-accounts', 'plone-openid', 'jinja2', 'django-newsletter', 'centrifuge', 'django-allauth', 'python-keystoneclient', 'engineio-client', 'httplib2', 'wikklytext', 'apache-libcloud', 'kdcproxy', 'django-ca', 'mosql', 'tripleo-heat-templates', 'nsupdate', 'z3c-form', 'djangae', 'cairosvg', 'pykechain', 'futures', 'pylibftdi', 'bok-choy', 'aiohttp', 'colander', 'keras-preprocessing', 'django-lfs', 'ethereum-abi-utils', 'tweepy', 'django-embed-video', 'django-access-tokens', 'tlslite', 'rinzler', 'collective-noticeboard', 'tiddlyweb', 'redis', 'products-poi', 'quandl-fund-xlsx', 'python-augeas', 'keras-applications', 'django-jet', 'cerulean', 'discogs-client', 'verlib', 'products-ldapuserfolder', 'ftw-meeting', 'irc3', 'priority', 'plone-app-contentmenu', 'creavel', 'opentaxii', 'pyasn1', 'otpauth', 'tensorflow', 'pysam', 'starcluster', 'yubiauth', 'django-lazysignup', 'django-epiced', 'tornado', 'pylru', 'collective-tablepage', 'django-session-security', 'django-select2', 'esptool', 'ht ...
# 653
# ['<VertexProperty(type=<goblin.properties.String object at 0x7f26ffe1d898>, value=readline)', '<VertexProperty(type=<goblin.properties.String object at 0x7fc629e147f0>, value=libidn2)', '<VertexProperty(type=<goblin.properties.String object at 0x7f26ffe1d898>, value=python3-libcomps)', '<VertexProperty(type=<goblin.properties.String object at 0x7fc629e147f0>, value=coreutils)', '<VertexProperty(type=<goblin.properties.String object at 0x7fc629e147f0>, value=gnupg2)', '<VertexProperty(type=<goblin.properties.String object at 0x7fc629e147f0>, value=libmount)', '<VertexProperty(type=<goblin.properties.String object at 0x7fc629e147f0>, value=fedora-release)', '<VertexProperty(type=<goblin.properties.String object at 0x7f26ffe1d898>, value=python3-gpg)', '<VertexProperty(type=<goblin.properties.String object at 0x7fc629e147f0>, value=coreutils-common)', '<VertexProperty(type=<goblin.properties.String object at 0x7fc629e147f0>, value=libcap)', '<VertexProperty(type=<goblin.properties.String object at 0x7f26ffe1d898>, value=libnghttp2)', '<VertexProperty(type=<goblin.properties.String object at 0x7f26ffe1d898>, value=libreport-filesystem)', '<VertexProperty(type=<goblin.properties.String object at 0x7fc629e147f0>, value=grep)', '<VertexProperty(type=<goblin.properties.String object at 0x7f26ffe1d898>, value=p11-kit)', '<VertexProperty(type=<goblin.properties.String object at 0x7f26ffe1d898>, value=qrencode-libs)', '<VertexProperty(type=<goblin.properties.String object at 0x7f26ffe1d898>, value=openssl-libs)', '<VertexProperty(type=<goblin.properties.String object at 0x7f26ffe1d898>, value=langpacks-en)', '<VertexProperty(type=<goblin.properties.String object at 0x7f26ffe1d898>, value=rpm-plugin-systemd-inhibit)', '<VertexProperty(type=<goblin.properties.String object at 0x7f26ffe1d898>, value=basesystem)', '<VertexProperty(type=<goblin.properties.String object at 0x7fc629e147f0>, value=glibc-common)', '<VertexProperty(type=<goblin.properties.String object at 0x7f26ffe1d898>, value=audit-libs)', '<VertexProperty(type=<goblin.properties.String object at 0x7fc629e147f0>, value=curl)', '<VertexProperty(type=<goblin.properties.String object at 0x7f26ffe1d898>, value=libdb-utils)', '<VertexProperty(type=<goblin.properties.String object at 0x7fc629e147f0>, value=libmodulemd1)', '<VertexProperty(type=<goblin.properties.String object at 0x7f26ffe1d898>, value=fedora-gpg-keys)', '<VertexProperty(type=<goblin.properties.String object at 0x7f26ffe1d898>, value=sqlite-libs)', '<VertexProperty(type=<goblin.properties.String object at 0x7f26ffe1d898>, value=libsemanage)', '<VertexProperty(type=<goblin.properties.String object at 0x7f26ffe1d898>, value=ncurses)', '<VertexProperty(type=<goblin.properties.String object at 0x7f26ffe1d898>, value=dnf-yum)', '<VertexProperty(type=<goblin.properties.String object at 0x7f26ffe1d898>, value=libdnf)', '<VertexProperty(type=<goblin.properties.String object at 0x7f26ffe1d898>, value=libpsl)', '<VertexProperty(type=<goblin.properties.String object at 0x7f26ffe1d898>, value=acl)', '<VertexProperty(type=<goblin.properties.String object at 0x7f26ffe1d898>, value=vim-minimal)', '<VertexProperty(type=<goblin.properties.String object at 0x7fc629e147f0>, value=filesystem)', '<VertexProperty(type=<goblin.properties.String object at 0x7fc629e147f0>, value=kmod-libs)', '<VertexProperty(type=<goblin.properties.String object at 0x7f26ffe1d898>, value=chkconfig)', '<VertexProperty(type=<goblin.properties.String object at 0x7f26ffe1d898>, value=cracklib-dicts)', '<VertexProperty(type=<goblin.properties.String object at 0x7f26ffe1d898>, value=gpgme)', '<VertexProperty(type=<goblin.properties.String object at 0x7fc629e147f0>, value=gawk)', '<VertexProperty(type=<goblin.properties.String object at 0x7f26ffe1d898>, value=ima-evm-utils)', '<VertexProperty(type=<goblin.properties.String object at 0x7fc629e147f0>, value=libassuan)', '<VertexProperty(type=<goblin.properties.String object at 0x7fc629e147f0>, value=libksba)', '<Vertex ...
# 267

# %%
# check that all packages name are unique
len(set(packages_vector))
# Out:
# 653

# %%
# Check python packages
python_package_versions = gqr(g.V().has('__label__', 'python_package_version').groupCount().by("package_name").next()).result
python_packages_v = [pkg for pkg in python_package_versions.keys()]
print(python_packages_v)
print(len(python_packages_v))
# Out:
# ['sbp', 'edrnsite-policy', 'tensorflow-estimator', 'django-autocomplete-light', 'html5', 'blinkpy', 'webassets', 'markupsafe', 'django-cms-patched', 'django-secure-auth', 'anncolvar', 'pyarmor', 'trytond', 'mccabe', 'bleach', 'coincurve', 'lxml', 'soupsieve', 'django-hijack', 'uwsgi', 'kotti', 'definitions', 'passlib', 'nova', 'repoze-lru', 'werkzeug', 'django-anymail', 'django-safedelete', 'click', 'sqlalchemy', 'django-make-app', 'js-videojs', 'djblets', 'ooniprobe', 'idna', 'python-nomad', 'pillow-simd', 'cffi', 'py-espeak-ng', 'notable', 'bottle', 'django-storages', 'flask-admin', 'yaybu', 'soappy', 'dpaste', 'pynoorm', 'beautifulsoup', 'markerlib', 'bakercm', 'murano-dashboard', 'django-modern-rpc', 'pigar', 'waitress', 'django-material', 'pyserial', 'stargate', 'boss-cli', 'flask-micropub', 'unicef-locations', 'pygresql', 'pokedex-py', 'pyplanet', 'datacube', 'django-relatives', 'multidict', 'pyjwt', 'pastescript', 'pycapnp', 'rply', 'django-airplane', 'gast', 'mollie-api-python', 'dulwich', 'pyro4', 'ironic-discoverd', 'eth-hash', 'etherweaver', 'flask-security-fork', 'django-basicauth', 'tinydb', 'eth-typing', 'reg', 'restauth', 'oauthlib', 'django-piston', 'astropy', 'flask-i18n', 'peewee', 'serpent', 'cryptacular', 'python-openid', 'satosa', 'pytsite', 'pyvcloud', 'swift', 'cinder', 'django-crispy-forms', 'python-smooch', 'cryptography', 'django-anonymizer', 'dj-static', 'flask-oauthlib', 'django-fiber', 'plone-dexterity', 'pirate-get', 'misago', 'plone', 'pyusb', 'seed-stage-based-messaging', 'pyorient', 'alt-model-checkpoint', 'brasil-gov-portal', 'henosis', 'pbr', 'rope', 'paste', 'mysql-connector-python', 'mezzanine', 'pyanyapi', 'requests-kerberos', 'selector', 'pcp', 'fresco', 'croniter', 'httpretty', 'six', 'pyflakes', 'gandi-cli', 'clearsilver', 'bigchaindb-driver', 'screwdriver', 'pypiserver', 'vermin', 'chardet', 'gitlab-languages', 'mtga', 'swauth', 'foolscap', 'alexandra', 'cbapi', 'pydispatcher', 'frozendict', 'hug', 'splash', 'argh', 'kinto-dist', 'logthing', 'mkdocs-material', 'ricloud', 'conn-check', 'defusedxml', 'katka-core', 'pycparser', 'tmc', 'construct', 'crayons', 'ansible-vault', 'oci', 'neo-python', 'ambient-api', 'python-bugzilla', 'invenio-admin', 'ptah', 'portalocker', 'python', 'pex', 'dj-database-url', 'im', 'mr-migrator', 'python-otr', 'yahoo-earnings-calendar', 'zeep', 'rpc4django', 'attrs', 'coveralls', 'lambdajson', 'cytoolz', 'python-fedora', 'streamsx-objectstorage', 'pycsw', 'msgpack', 'collective-documentviewer', 'openslides', 'tb-nightly', 'deis', 'isodate', 'django-envelope', 'pysaml2', 'awscli', 'pyopenssl', 'cosmos-wfm', 'plone-app-content', 'zhmc-ansible-modules', 'zope-html', 'radicale', 'flask-images', 'pypicloud', 'plone-app-event', 'itsdangerous', 'tox', 'crossbar', 'bodhi', 'chanjo-report', 'scipy', 'cryptography-vectors', 'quilt', 'cfscrape', 'markdown2', 'raven', 'thorn', 'pytest-server-fixtures', 'static3', 'django-rated', 'mistune', 'authbwc', 'pyamf', 'tendenci', 'future', 'rlp', 'ruamel-yaml', 'mercurial', 'container-service-extension', 'pycryptodome', 'eth-utils', 'python-cjson', 'httprunner', 'insecure-package', 'pyshop', 'flask-statsdclient', 'ftw-dashboard-portlets-postit', 'python-dateutil', 'setuptools', 'py-ms', 'form-designer', 'feedparser', 'contentful-management', 'myghtyutils', 'contextlib2', 'pip', 'certifi', 'drfdocs', 'birdhousebuilder-recipe-nginx', 'slackeventsapi', 'cmdln', 'libtaxii', 'contentful', 'idna-ssl', 'django-uni-form', 'products-cmfquickinstallertool', 'stormpath-sdk', 'plone-app-contenttypes', 'tablib', 'rdflib', 'pyramid-weblayer', 'voluptuous-serialize', 'ngraph-mxnet', 'python-pptx', 'requests-futures', 'django-filter', 'textract', 'configparser', 'bincrafters-envy', 'mixminion', 'soapfish', 'mock', 'products-cmfplone', 'django-watchman', 'livefyre', 'supervisor', 'async-timeout', 'django-fernet-fields', 'python-saml', 'more-itertools', 'tryton', 'mako', 'pconf', 'toro', 'keystonemiddleware', 'stormpath', 'urllib3', 'django-celery', ...
# 653

# %%
# Check RPM packages
rpm_package_versions = gqr(g.V().has("__label__", "rpm_package_version").groupCount().by("package_name").next()).result
rpm_packages = [pkg for pkg in rpm_package_versions.keys()]
print(rpm_packages)
print(len(rpm_packages))
# Out:
# ['libidn2', 'rpm-libs', 'curl', 'libsolv', 'chkconfig', 'p11-kit', 'python3-gpg', 'openldap', 'p11-kit-trust', 'coreutils-common', 'dbus-libs', 'python3-pip', 'python3', 'libsss_idmap', 'libseccomp', 'sqlite-libs', 'libattr', 'dnf', 'python3-libdnf', 'gdbm-libs', 'gawk', 'dnf-data', 'libssh', 'keyutils-libs', 'libgcc', 'cryptsetup-libs', 'whois-nls', 'glibc-langpack-en', 'lua-libs', 'libuuid', 'libgpg-error', 'libarchive', 'libunistring', 'rpm-build-libs', 'libdnf', 'libnsl2', 'openssl', 'rpm-sign-libs', 'ncurses-libs', 'device-mapper-libs', 'fedora-gpg-keys', 'systemd-pam', 'glibc-common', 'python3-six', 'ima-evm-utils', 'libffi', 'bzip2-libs', 'libyaml', 'libksba', 'nettle', 'gmp', 'diffutils', 'cracklib', 'python3-hawkey', 'dbus-daemon', 'pcre', 'systemd-libs', 'sed', 'libreport-filesystem', 'libsigsegv', 'python3-rpm', 'vim-minimal', 'libevent', 'python3-unbound', 'libcom_err', 'audit-libs', 'rpm-plugin-systemd-inhibit', 'glibc-minimal-langpack', 'systemd', 'basesystem', 'rootfiles', 'libpsl', 'libmount', 'gpgme', 'gzip', 'libassuan', 'libcap', 'python3-setuptools', 'libxcrypt', 'libdb-utils', 'whois-mkpasswd', 'popt', 'libpwquality', 'libsepol', 'kmod-libs', 'libtasn1', 'ncurses-base', 'libpcap', 'crypto-policies', 'libzstd', 'npth', 'python3-iniparse', 'libsmartcols', 'python3-dnf', 'lz4-libs', 'openssl-pkcs11', 'acl', 'ncurses', 'fedora-repos', 'libnghttp2', 'libcap-ng', 'libcomps', 'libusbx', 'deltarpm', 'python3-libcomps', 'libselinux', 'util-linux', 'shadow-utils', 'rpm-plugin-selinux', 'mpfr', 'pam', 'librepo', 'sssd-client', 'info', 'zchunk-libs', 'dbus-common', 'tar', 'libacl', 'fedora-release', 'libutempter', 'libverto', 'unbound-libs', 'elfutils-libelf', 'dbus', 'langpacks-en', 'iptables-libs', 'elfutils-libs', 'python-setuptools-wheel', 'publicsuffix-list-dafsa', 'device-mapper', 'glibc', 'libsss_nss_idmap', 'libargon2', 'xz-libs', 'ca-certificates', 'gnutls', 'brotli', 'libcurl', 'cracklib-dicts', 'coreutils', 'json-c', 'pcre2', 'libtirpc', 'expat', 'readline', 'libdb', 'krb5-libs', 'libgcrypt', 'gnupg2', 'grep', 'libsemanage', 'libblkid', 'tzdata', 'libfdisk', 'glib2', 'libxml2', 'qrencode-libs', 'elfutils-default-yama-scope', 'python3-libs', 'rpm', 'libstdc++', 'filesystem', 'libmodulemd1', 'cyrus-sasl-lib', 'zlib', 'dbus-tools', 'python-pip-wheel', 'dnf-yum', 'fedora-release-container', 'file-libs', 'setup', 'bash', 'libmetalink', 'openssl-libs']
# 174

# %%
#Check if the error is in python packages or RPM packages
cpp = set(packages_vector) - set(python_packages_v)
print(len(cpp))
crr = set(packages_vector) & set(rpm_packages)
print(len(crr))
# Out:
# 0
# 0

# %% [markdown]
# Check the python package version that have more than one artifact

# %%
gqr(g.V().has("__label__", "python_package_version").where(outE().has("__label__", "has_artifact").count().is_(P.gt(1))).valueMap(True).toList()).result
# Out:
# [{'index_url': ['https://pypi.org/simple'],
#   'package_version': ['20.3.1'],
#   '__label__': ['python_package_version'],
#   'ecosystem': ['pypi'],
#   'id': 147672,
#   '__type__': ['vertex'],
#   'label': 'python_package_version',
#   'package_name': ['setuptools']},
#  {'index_url': ['https://pypi.org/simple'],
#   'package_version': ['3.4.0'],
#   '__label__': ['python_package_version'],
#   'ecosystem': ['pypi'],
#   'id': 410018040,
#   '__type__': ['vertex'],
#   'label': 'python_package_version',
#   'package_name': ['pytest']},
#  {'index_url': ['https://pypi.org/simple'],
#   'package_version': ['0.0.1'],
#   '__label__': ['python_package_version'],
#   'ecosystem': ['pypi'],
#   'id': 1019912,
#   '__type__': ['vertex'],
#   'label': 'python_package_version',
#   'package_name': ['certifi']},
#  {'index_url': ['https://pypi.org/simple'],
#   'package_version': ['2.1.0'],
#   '__label__': ['python_package_version'],
#   'ecosystem': ['pypi'],
#   'id': 1294392,
#   '__type__': ['vertex'],
#   'label': 'python_package_version',
#   'package_name': ['pyflakes']},
#  {'index_url': ['https://pypi.org/simple'],
#   'package_version': ['0.8.12'],
#   '__label__': ['python_package_version'],
#   'ecosystem': ['pypi'],
#   'id': 409735416,
#   '__type__': ['vertex'],
#   'label': 'python_package_version',
#   'package_name': ['httpretty']},
#  {'index_url': ['https://pypi.org/simple'],
#   'package_version': ['2015.9.6'],
#   '__label__': ['python_package_version'],
#   'ecosystem': ['pypi'],
#   'id': 1069248,
#   '__type__': ['vertex'],
#   'label': 'python_package_version',
#   'package_name': ['certifi']},
#  {'index_url': ['https://pypi.org/simple'],
#   'package_version': ['1.11.0a20180817'],
#   '__label__': ['python_package_version'],
#   'ecosystem': ['pypi'],
#   'id': 409698472,
#   '__type__': ['vertex'],
#   'label': 'python_package_version',
#   'package_name': ['tb-nightly']},
#  {'index_url': ['https://pypi.org/simple'],
#   'package_version': ['39.0.1'],
#   '__label__': ['python_package_version'],
#   'ecosystem': ['pypi'],
#   'id': 344248,
#   '__type__': ['vertex'],
#   'label': 'python_package_version',
#   'package_name': ['setuptools']},
#  {'index_url': ['https://pypi.org/simple'],
#   'package_version': ['4.0a6'],
#   '__label__': ['python_package_version'],
#   'ecosystem': ['pypi'],
#   'id': 422072,
#   '__type__': ['vertex'],
#   'label': 'python_package_version',
#   'package_name': ['coverage']},
#  {'index_url': ['https://pypi.org/simple'],
#   'package_version': ['1.13.0a20190219'],
#   '__label__': ['python_package_version'],
#   'ecosystem': ['pypi'],
#   'id': 180344,
#   '__type__': ['vertex'],
#   'label': 'python_package_version',
#   'package_name': ['tb-nightly']},
#  {'index_url': ['https://pypi.org/simple'],
#   'package_version': ['19.7'],
#   '__label__': ['python_package_version'],
#   'ecosystem': ['pypi'],
#   'id': 409751552,
#   '__type__': ['vertex'],
#   'label': 'python_package_version',
#   'package_name': ['setuptools']},
#  {'index_url': ['https://pypi.org/simple'],
#   'package_version': ['13.0.3'],
#   '__label__': ['python_package_version'],
#   'ecosystem': ['pypi'],
#   'id': 53464,
#   '__type__': ['vertex'],
#   'label': 'python_package_version',
#   'package_name': ['virtualenv']},
#  {'index_url': ['https://pypi.org/simple'],
#   'package_version': ['1.11.3'],
#   '__label__': ['python_package_version'],
#   'ecosystem': ['pypi'],
#   'id': 61624,
#   '__type__': ['vertex'],
#   'label': 'python_package_version',
#   'package_name': ['virtualenv']},
#  {'index_url': ['https://pypi.org/simple'],
#   'package_version': ['1.13.0a20190116'],
#   '__label__': ['python_package_version'],
#   'ecosystem': ['pypi'],
#   'id': 409890952,
#   '__type__': ['vertex'],
#   'label': 'python_package_version',
#   'package_name': ['tb-nightly']},
#  {'index_url': ['https://pypi.org/simple'],
#   'package_version': ['32.0.0'],
#   '__label__': ['python_package_version'],
#   'ecosystem': ['pypi'],
#   'id': 262200,
#   '__type__': ['vertex'],
#   'label': 'python_package_version',
#   'package_name': ['setuptools']},
#  {'index_url': ['https://pypi.org/simple'],
#   'package_version': ['1.11.0a20180822'],
#   '__label__': ['python_package_version'],
#   'ecosystem': ['pypi'],
#   'id': 98424,
#   '__type__': ['vertex'],
#   'label': 'python_package_version',
#   'package_name': ['tb-nightly']},
#  {'index_url': ['https://pypi.org/simple'],
#   'package_version': ['25.0.1'],
#   '__label__': ['python_package_version'],
#   'ecosystem': ['pypi'],
#   'id': 147592,
#   '__type__': ['vertex'],
#   'label': 'python_package_version',
#   'package_name': ['setuptools']},
#  {'index_url': ['https://pypi.org/simple'],
#   'package_version': ['1.11.0a20180921'],
#   '__label__': ['python_package_version'],
#   'ecosystem': ['pypi'],
#   'id': 114808,
#   '__type__': ['vertex'],
#   'label': 'python_package_version',
#   'package_name': ['tb-nightly']},
#  {'index_url': ['https://pypi.org/simple'],
#   'package_version': ['1.4.32'],
#   '__label__': ['python_package_version'],
#   'ecosystem': ['pypi'],
#   'id': 73784,
#   '__type__': ['vertex'],
#   'label': 'python_package_version',
#   'package_name': ['py']},
#  {'index_url': ['https://pypi.org/simple'],
#   'package_version': ['7.0'],
#   '__label__': ['python_package_version'],
#   'ecosystem': ['pypi'],
#   'id': 819208360,
#   '__type__': ['vertex'],
#   'label': 'python_package_version',
#   'package_name': ['click']},
#  {'index_url': ['https://pypi.org/simple'],
#   'package_version': ['1.13.0a20190213'],
#   '__label__': ['python_package_version'],
#   'ecosystem': ['pypi'],
#   'id': 409911432,
#   '__type__': ['vertex'],
#   'label': 'python_package_version',
#   'package_name': ['tb-nightly']},
#  {'index_url': ['https://pypi.org/simple'],
#   'package_version': ['1.13.0rc2'],
#   '__label__': ['python_package_version'],
#   'ecosystem': ['pypi'],
#   'id': 413999240,
#   '__type__': ['vertex'],
#   'label': 'python_package_version',
#   'package_name': ['tensorflow']},
#  {'index_url': ['https://pypi.org/simple'],
#   'package_version': ['1.4.0'],
#   '__label__': ['python_package_version'],
#   'ecosystem': ['pypi'],
#   'id': 410996736,
#   '__type__': ['vertex'],
#   'label': 'python_package_version',
#   'package_name': ['pyflakes']},
#  {'index_url': ['https://pypi.org/simple'],
#   'package_version': ['1.5.0a20180105'],
#   '__label__': ['python_package_version'],
#   'ecosystem': ['pypi'],
#   'id': 32816,
#   '__type__': ['vertex'],
#   'label': 'python_package_version',
#   'package_name': ['tb-nightly']},
#  {'index_url': ['https://pypi.org/simple'],
#   'package_version': 

#   '__type__': ['vertex'],
#   'label': 'python_package_version',
#   'package_name': ['pylibftdi']},
#  {'index_url': ['https://pypi.org/simple'],
#   'package_version': ['28.6.1'],
#   '__label__': ['python_package_version'],
#   'ecosystem': ['pypi'],
#   'id': 200760,
#   '__type__': ['vertex'],
#   'label': 'python_package_version',
#   'package_name': ['setuptools']},
#  {'index_url': ['https://pypi.org/simple'],
#   'package_version': ['19.0'],
#   '__label__': ['python_package_version'],
#   'ecosystem': ['pypi'],
#   'id': 1970312,
#   '__type__': ['vertex'],
#   'label': 'python_package_version',
#   'package_name': ['pip']},
#  {'index_url': ['https://pypi.org/simple'],
#   'package_version': ['36.4.0'],
#   '__label__': ['python_package_version'],
#   'ecosystem': ['pypi'],
#   'id': 323768,
#   '__type__': ['vertex'],
#   'label': 'python_package_version',
#   'package_name': ['setuptools']},
#  {'index_url': ['https://pypi.org/simple'],
#   'package_version': ['3.1'],
#   '__label__': ['python_package_version'],
#   'ecosystem': ['pypi'],
#   'id': 180416,
#   '__type__': ['vertex'],
#   'label': 'python_package_version',
#   'package_name': ['pyserial']},
#  {'index_url': ['https://pypi.org/simple'],
#   'package_version': ['18.2'],
#   '__label__': ['python_package_version'],
#   'ecosystem': ['pypi'],
#   'id': 110784,
#   '__type__': ['vertex'],
#   'label': 'python_package_version',
#   'package_name': ['setuptools']},
#  {'index_url': ['https://pypi.org/simple'],
#   'package_version': ['0.5.1'],
#   '__label__': ['python_package_version'],
#   'ecosystem': ['pypi'],
#   'id': 1564912,
#   '__type__': ['vertex'],
#   'label': 'python_package_version',
#   'package_name': ['webencodings']},
#  {'index_url': ['https://pypi.org/simple'],
#   'package_version': ['36.2.1'],
#   '__label__': ['python_package_version'],
#   'ecosystem': ['pypi'],
#   'id': 356408,
#   '__type__': ['vertex'],
#   'label': 'python_package_version',
#   'package_name': ['setuptools']},
#  {'index_url': ['https://pypi.org/simple'],
#   'package_version': ['0.13.4'],
#   '__label__': ['python_package_version'],
#   'ecosystem': ['pypi'],
#   'id': 184352,
#   '__type__': ['vertex'],
#   'label': 'python_package_version',
#   'package_name': ['pyftdi']},
#  {'index_url': ['https://pypi.org/simple'],
#   'package_version': ['1.8.0a20180401'],
#   '__label__': ['python_package_version'],
#   'ecosystem': ['pypi'],
#   'id': 409628776,
#   '__type__': ['vertex'],
#   'label': 'python_package_version',
#   'package_name': ['tb-nightly']},
#  {'index_url': ['https://pypi.org/simple'],
#   'package_version': ['12.1.1'],
#   '__label__': ['python_package_version'],
#   'ecosystem': ['pypi'],
#   'id': 41152,
#   '__type__': ['vertex'],
#   'label': 'python_package_version',
#   'package_name': ['virtualenv']},
#  {'index_url': ['https://pypi.org/simple'],
#   'package_version': ['0.14.1'],
#   '__label__': ['python_package_version'],
#   'ecosystem': ['pypi'],
#   'id': 200736,
#   '__type__': ['vertex'],
#   'label': 'python_package_version',
#   'package_name': ['pylibftdi']},
#  {'index_url': ['https://pypi.org/simple'],
#   'package_version': ['0.29.1'],
#   '__label__': ['python_package_version'],
#   'ecosystem': ['pypi'],
#   'id': 155656,
#   '__type__': ['vertex'],
#   'label': 'python_package_version',
#   'package_name': ['pyftdi']},
#  {'index_url': ['https://pypi.org/simple'],
#   'package_version': ['8.1.2'],
#   '__label__': ['python_package_version'],
#   'ecosystem': ['pypi'],
#   'id': 2064440,
#   '__type__': ['vertex'],
#   'label': 'python_package_version',
#   'package_name': ['pip']},
#  {'index_url': ['https://pypi.org/simple'],
#   'package_version': ['3.2.1'],
#   '__label__': ['python_package_version'],
#   'ecosystem': ['pypi'],
#   'id': 409825280,
#   '__type__': ['vertex'],
#   'label': 'python_package_version',
#   'package_name': ['pyserial']},
#  {'index_url': ['https://pypi.org/simple'],
#   'package_version': ['4.2.0'],
#   '__label__': ['python_package_version'],
#   'ecosystem': ['pypi'],
#   'id': 412487816,
#   '__type__': ['vertex'],
#   'label': 'python_package_version',
#   'package_name': ['pbr']},
#  {'index_url': ['https://pypi.org/simple'],
#   'package_version': ['39.0.0'],
#   '__label__': ['python_package_version'],
#   'ecosystem': ['pypi'],
#   'id': 376888,
#   '__type__': ['vertex'],
#   'label': 'python_package_version',
#   'package_name': ['setuptools']},
#  {'index_url': ['https://pypi.org/simple'],
#   'package_version': ['1.13.0a20181027'],
#   '__label__': ['python_package_version'],
#   'ecosystem': ['pypi'],
#   'id': 135288,
#   '__type__': ['vertex'],
#   'label': 'python_package_version',
#   'package_name': ['tb-nightly']},
#  {'index_url': ['https://pypi.org/simple'],
#   'package_version': ['0.8.14'],
#   '__label__': ['python_package_version'],
#   'ecosystem': ['pypi'],
#   'id': 139448,
#   '__type__': ['vertex'],
#   'label': 'python_package_version',
#   'package_name': ['httpretty']},
#  {'index_url': ['https://pypi.org/simple'],
#   'package_version': ['1.3.0'],
#   '__label__': ['python_package_version'],
#   'ecosystem': ['pypi'],
#   'id': 1319144,
#   '__type__': ['vertex'],
#   'label': 'python_package_version',
#   'package_name': ['pyflakes']},
#  {'index_url': ['https://pypi.org/simple'],
#   'package_version': ['12.0.1'],
#   '__label__': ['python_package_version'],
#   'ecosystem': ['pypi'],
#   'id': 32960,
#   '__type__': ['vertex'],
#   'label': 'python_package_version',
#   'package_name': ['virtualenv']},
#  {'index_url': ['https://pypi.org/simple'],
#   'package_version': ['4.0.1'],
#   '__label__': ['python_package_version'],
#   'ecosystem': ['pypi'],
#   'id': 410132480,
#   '__type__': ['vertex'],
#   'label': 'python_package_version',
#   'package_name': ['pytest']},
#  {'index_url': ['https://pypi.org/simple'],
#   'package_version': ['1.6.0a20180204'],
#   '__label__': ['python_package_version'],
#   'ecosystem': ['pypi'],
#   'id': 49200,
#   '__type__': ['vertex'],
#   'label': 'python_package_version',
#   'package_name': ['tb-nightly']},
#  {'index_url': ['https://pypi.org/simple'],
#   'package_version': ['0.13'],
#   '__label__': ['python_package_version'],
#   'ecosystem': ['pypi'],
#   'id': 168128,
#   '__type__': ['vertex'],
#   'label': 'python_package_version',
#   'package_name': ['pylibftdi']},
#  {'index_url': ['https://pypi.org/simple'],
#   'package_version': ['26.1.1'],
#   '__label__': ['python_package_version'],
#   'ecosystem': ['pypi'],
#   'id': 192696,
#   '__type__': ['vertex'],
#   'label': 'python_package_version',
#   'package_name': ['setuptools']},
#  {'index_url': ['https://pypi.org/simple'],
#   'package_version': ['5.1.2'],
#   '__label__': ['python_package_version'],
#   'ecosystem': ['pypi'],
#   'id': 1421432,
#   '__type__': ['vertex'],
#   'label': 'python_package_version',
#   'package_name': ['pbr']},
#  {'index_url': ['https://pypi.org/simple'],
#   'package_version': ['1.2.0rc1'],
#   '__label__': ['python_package_version'],
#   'ecosystem': ['pypi'],
#   'id': 414113928,
#   '__type__': ['vertex'],
#   'label': 'python_package_version',
#   'package_name': ['scipy']},
#  {'index_url': ['https://pypi.org/simple'],
#   'package_version': ['4.4'],
#   '__label__': ['python_package_version'],
#   'ecosystem': ['pypi'],
#   'id': 1065176,
#   '__type__': ['vertex'],
#   'label': 'python_package_version',
#   'package_name': ['tornado']},
#  {'index_url': ['https://pypi.org/simple'],
#   'package_version': ['0.10.3'],
#   '__label__': ['python_package_version'],
#   'ecosystem': ['pypi'],
#   'id': 1650928,
#   '__type__': ['vertex'],
#   'label': 'python_package_version',
#   'package_name': ['wheel']},
#  {'index_url': ['https://pypi.org/simple'],
#   'package_version': ['1.16.1rc1'],
#   '__label__': ['python_package_version'],
#   'ecosystem': ['pypi'],
#   'id': 410067080,
#   '__type__': ['vertex'],
#   'label': 'python_package_version',
#   'package_name': ['grpcio']},
#  {'index_url': ['https://pypi.org/simple'],
#   'package_version': ['1.11.0a20180810'],
#   '__label__': ['python_package_version'],
#   'ecosystem': ['pypi'],
#   'id': 73968,
#   '__type__': ['vertex'],
#   'label': 'python_package_version',
#   'package_name': ['tb-nightly']},
#  {'index_url': ['https://pypi.org/simple'],
#   'package_version': ['0.8.7'],
#   '__label__': ['python_package_version'],
#   'ecosystem': ['pypi'],
#   'id': 139296,
#   '__type__': ['vertex'],
#   'label': 'python_package_version',
#   'package_name': ['httpretty']},
#  {'index_url': ['https://pypi.org/simple'],
#   'package_version': ['1.2.0'],
#   '__label__': ['python_package_version'],
#   'ecosystem': ['pypi'],
#   'id': 412455048,
#   '__type__': ['vertex'],
#   'label': 'python_package_version',
#   'package_name': ['pbr']},
#  {'index_url': ['https://pypi.org/simple'],
#   'package_version': ['1.7.1'],
#   '__label__': ['python_package_version'],
#   'ecosystem': ['pypi'],
#   'id': 1286152,
#   '__type__': ['vertex'],
#   'label': 'python_package_version',
#   'package_name': ['pep8']},
#  {'index_url': ['https://pypi.org/simple'],
#   'package_version': ['1.13.0a20181217'],
#   '__label__': ['python_package_version'],
#   'ecosystem': ['pypi'],
#   'id': 159952,
#   '__type__': ['vertex'],
#   'label': 'python_package_version',
#   'package_name': ['tb-nightly']},
#  {'index_url': ['https://pypi.org/simple'],
#   'package_version': ['1.13.0a20190221'],
#   '__label__': ['python_package_version'],
#   'ecosystem': ['pypi'],
#   'id': 184528,
#   '__type__': ['vertex'],
#   'label': 'python_package_version',
#   'package_name': ['tb-nightly']},
#  {'index_url': ['https://pypi.org/simple'],
#   'package_version': ['0.26.4'],
#   '__label__': ['python_package_version'],
#   'ecosystem': ['pypi'],
#   'id': 409755896,
#   '__type__': ['vertex'],
#   'label': 'python_package_version',
#   'package_name': ['pyftdi']},
#  {'index_url': ['https://pypi.org/simple'],
#   'package_version': ['20.8.1'],
#   '__label__': ['python_package_version'],
#   'ecosystem': ['pypi'],
#   'id': 159800,
#   '__type__': ['vertex'],
#   'label': 'python_package_version',
#   'package_name': ['setuptools']},
#  {'index_url': ['https://pypi.org/simple'],
#   'package_version': ['1.11.0a20180808'],
#   '__label__': ['python_package_version'],
#   'ecosystem': ['pypi'],
#   'id': 110640,
#   '__type__': ['vertex'],
#   'label': 'python_package_version',
#   'package_name': ['tb-nightly']},
#  {'index_url': ['https://pypi.org/simple'],
#   'package_version': ['0.11.3'],
#   '__label__': ['python_package_version'],
#   'ecosystem': ['pypi'],
#   'id': 10412096,
#   '__type__': ['vertex'],
#   'label': 'python_package_version',
#   'package_name': ['werkzeug']},
#  {'index_url': ['https://pypi.org/simple'],
#   'package_version': ['40.4.3'],
#   '__label__': ['python_package_version'],
#   'ecosystem': ['pypi'],
#   'id': 409944312,
#   '__type__': ['vertex'],
#   'label': 'python_package_version',
#   'package_name': ['setuptools']},
#  {'index_url': ['https://pypi.org/simple'],
#   'package_version': ['1.13.0a20190205'],
#   '__label__': ['python_package_version'],
#   'ecosystem': ['pypi'],
#   'id': 409751656,
#   '__type__': ['vertex'],
#   'label': 'python_package_version',
#   'package_name': ['tb-nightly']},
#  {'index_url': ['https://pypi.org/simple'],
#   'package_version': ['7.1.1'],
#   '__label__': ['python_package_version'],
#   'ecosystem': ['pypi'],
#   'id': 2215968,
#   '__type__': ['vertex'],
#   'label': 'python_package_version',
#   'package_name': ['pip']},
#  {'index_url': ['https://pypi.org/simple'],
#   'package_version': ['1.9.0a20180605'],
#   '__label__': ['python_package_version'],
#   'ecosystem': ['pypi'],
#   'id': 409673896,
#   '__type__': ['vertex'],
#   'label': 'python_package_version',
#   'package_name': ['tb-nightly']},
#  {'index_url': ['https://pypi.org/simple'],
#   'package_version': ['12.0'],
#   '__label__': ['python_package_version'],
#   'ecosystem': ['pypi'],
#   'id': 28808,
#   '__type__': ['vertex'],
#   'label': 'python_package_version',
#   'package_name': ['virtualenv']},
#  {'index_url': ['https://pypi.org/simple'],
#   'package_version': ['1.11.0rc2'],
#   '__label__': ['python_package_version'],
#   'ecosystem': ['pypi'],
#   'id': 229424,
#   '__type__': ['vertex'],
#   'label': 'python_package_version',
#   'package_name': ['grpcio']},
#  {'index_url': ['https://pypi.org/simple'],
#   'package_version': ['5.4.0'],
#   '__label__': ['python_package_version'],
#   'ecosystem': ['pypi'],
#   'id': 411484328,
#   '__type__': ['vertex'],
#   'label': 'python_package_version',
#   'package_name': ['pillow']},
#  {'index_url': ['https://pypi.org/simple'],
#   'package_version': ['40.6.2'],
#   '__label__': ['python_package_version'],
#   'ecosystem': ['pypi'],
#   'id': 380960,
#   '__type__': ['vertex'],
#   'label': 'python_package_version',
#   'package_name': ['setuptools']},
#  {'index_url': ['https://pypi.org/simple'],
#   'package_version': ['5.0a1'],
#   '__label__': ['python_package_version'],
#   'ecosystem': ['pypi'],
#   'id': 434360,
#   '__type__': ['vertex'],
#   'label': 'python_package_version',
#   'package_name': ['coverage']},
#  {'index_url': ['https://pypi.org/simple'],
#   'package_version': ['38.2.5'],
#   '__label__': ['python_package_version'],
#   'ecosystem': ['pypi'],
#   'id': 409993216,
#   '__type__': ['vertex'],
#   'label': 'python_package_version',
#   'package_name': ['setuptools']},
#  {'index_url': ['https://pypi.org/simple'],
#   'package_version': ['1.13.0a20181108'],
#   '__label__': ['python_package_version'],
#   'ecosystem': ['pypi'],
#   'id': 409870472,
#   '__type__': ['vertex'],
#   'label': 'python_package_version',
#   'package_name': ['tb-nightly']},
#  {'index_url': ['https://pypi.org/simple'],
#   'package_version': ['1.13.0a20181124'],
#   '__label__': ['python_package_version'],
#   'ecosystem': ['pypi'],
#   'id': 151672,
#   '__type__': ['vertex'],
#   'label': 'python_package_version',
#   'package_name': ['tb-nightly']},
#  {'index_url': ['https://pypi.org/simple'],
#   'package_version': ['18.3'],
#   '__label__': ['python_package_version'],
#   'ecosystem': ['pypi'],
#   'id': 114880,
#   '__type__': ['vertex'],
#   'label': 'python_package_version',
#   'package_name': ['setuptools']},
#  {'index_url': ['https://pypi.org/simple'],
#   'package_version': ['1.11.0'],
#   '__label__': ['python_package_version'],
#   'ecosystem': ['pypi'],
#   'id': 69664,
#   '__type__': ['vertex'],
#   'label': 'python_package_version',
#   'package_name': ['six']},
#  {'index_url': ['https://pypi.org/simple'],
#   'package_version': ['2016.8.31'],
#   '__label__': ['python_package_version'],
#   'ecosystem': ['pypi'],
#   'id': 1163480,
#   '__type__': ['vertex'],
#   'label': 'python_package_version',
#   'package_name': ['certifi']},
#  {'index_url': ['https://pypi.org/simple'],
#   'package_version': ['0.11.10'],
#   '__label__': ['python_package_version'],
#   'ecosystem': ['pypi'],
#   'id': 5574760,
#   '__type__': ['vertex'],
#   'label': 'python_package_version',
#   'package_name': ['werkzeug']},
#  {'index_url': ['https://pypi.org/simple'],
#   'package_version': ['1.8.0a20180420'],
#   '__label__': ['python_package_version'],
#   'ecosystem': ['pypi'],
#   'id': 409661624,
#   '__type__': ['vertex'],
#   'label': 'python_package_version',
#   'package_name': ['tb-nightly']},
#  {'index_url': ['https://pypi.org/simple'],
#   'package_version': ['1.7.2'],
#   '__label__': ['python_package_version'],
#   'ecosystem': ['pypi'],
#   'id': 409640960,
#   '__type__': ['vertex'],
#   'label': 'python_package_version',
#   'package_name': ['six']},
#  {'index_url': ['https://pypi.org/simple'],
#   'package_version': ['1.13.0a20181106'],
#   '__label__': ['python_package_version'],
#   'ecosystem': ['pypi'],
#   'id': 143568,
#   '__type__': ['vertex'],
#   'label': 'python_package_version',
#   'package_name': ['tb-nightly']},
#  {'index_url': ['https://pypi.org/simple'],
#   'package_version': ['0.3.0'],
#   '__label__': ['python_package_version'],
#   'ecosystem': ['pypi'],
#   'id': 1179704,
#   '__type__': ['vertex'],
#   'label': 'python_package_version',
#   'package_name': ['pluggy']},
#  {'index_url': ['https://pypi.org/simple'],
#   'package_version': ['0.5.3'],
#   '__label__': ['python_package_version'],
#   'ecosystem': ['pypi'],
#   'id': 410820856,
#   '__type__': ['vertex'],
#   'label': 'python_package_version',
#   'package_name': ['mccabe']},
#  {'index_url': ['https://pypi.org/simple'],
#   'package_version': ['0.11.0'],
#   '__label__': ['python_package_version'],
#   'ecosystem': ['pypi'],
#   'id': 1777784,
#   '__type__': ['vertex'],
#   'label': 'python_package_version',
#   'package_name': ['wheel']},
#  {'index_url': ['https://pypi.org/simple'],
#   'package_version': ['4.0.1'],
#   '__label__': ['python_package_version'],
#   'ecosystem': ['pypi'],
#   'id': 483336,
#   '__type__': ['vertex'],
#   'label': 'python_package_version',
#   'package_name': ['coverage']},
#  {'index_url': ['https://pypi.org/simple'],
#   'package_version': ['1.9.1'],
#   '__label__': ['python_package_version'],
#   'ecosystem': ['pypi'],
#   'id': 245880,
#   '__type__': ['vertex'],
#   'label': 'python_package_version',
#   'package_name': ['grpcio']},
#  {'index_url': ['https://pypi.org/simple'],
#   'package_version': ['36.5.0'],
#   '__label__': ['python_package_version'],
#   'ecosystem': ['pypi'],
#   'id': 344096,
#   '__type__': ['vertex'],
#   'label': 'python_package_version',
#   'package_name': ['setuptools']},
#  {'index_url': ['https://pypi.org/simple'],
#   'package_version': ['1.11.1rc1'],
#   '__label__': ['python_package_version'],
#   'ecosystem': ['pypi'],
#   'id': 409829544,
#   '__type__': ['vertex'],
#   'label': 'python_package_version',
#   'package_name': ['grpcio']},
#  {'index_url': ['https://pypi.org/simple'],
#   'package_version': ['1.11.4'],
#   '__label__': ['python_package_version'],
#   'ecosystem': ['pypi'],
#   'id': 28904,
#   '__type__': ['vertex'],
#   'label': 'python_package_version',
#   'package_name': ['virtualenv']},
#  {'index_url': ['https://pypi.org/simple'],
#   'package_version': ['22.0.5'],
#   '__label__': ['python_package_version'],
#   'ecosystem': ['pypi'],
#   'id': 127112,
#   '__type__': ['vertex'],
#   'label': 'python_package_version',
# ...
#   'ecosystem': ['pypi'],
#   'id': 45104,
#   '__type__': ['vertex'],
#   'label': 'python_package_version',
#   'package_name': ['tb-nightly']},
#  {'index_url': ['https://pypi.org/simple'],
#   'package_version': ['14.0.3'],
#   '__label__': ['python_package_version'],
#   'ecosystem': ['pypi'],
#   'id': 409657344,
#   '__type__': ['vertex'],
#   'label': 'python_package_version',
#   'package_name': ['virtualenv']},
#  {'index_url': ['https://pypi.org/simple'],
#   'package_version': ['38.2.4'],
#   '__label__': ['python_package_version'],
#   'ecosystem': ['pypi'],
#   'id': 336064,
#   '__type__': ['vertex'],
#   'label': 'python_package_version',
#   'package_name': ['setuptools']},
#  {'index_url': ['https://pypi.org/simple'],
#   'package_version': ['0.12'],
#   '__label__': ['python_package_version'],
#   'ecosystem': ['pypi'],
#   'id': 1613912,
#   '__type__': ['vertex'],
#   'label': 'python_package_version',
#   'package_name': ['flask']},
#  {'index_url': ['https://pypi.org/simple'],
#   'package_version': ['32.3.0'],
#   '__label__': ['python_package_version'],
#   'ecosystem': ['pypi'],
#   'id': 409915392,
#   '__type__': ['vertex'],
#   'label': 'python_package_version',
#   'package_name': ['setuptools']},
#  {'index_url': ['https://pypi.org/simple'],
#   'package_version': ['1.13.0a20190218'],
#   '__label__': ['python_package_version'],
#   'ecosystem': ['pypi'],
#   'id': 409759848,
#   '__type__': ['vertex'],
#   'label': 'python_package_version',
#   'package_name': ['tb-nightly']},
#  {'index_url': ['https://pypi.org/simple'],
#   'package_version': ['1.13.0a20190209'],
#   '__label__': ['python_package_version'],
#   'ecosystem': ['pypi'],
#   'id': 176248,
#   '__type__': ['vertex'],
#   'label': 'python_package_version',
#   'package_name': ['tb-nightly']},
#  {'index_url': ['https://pypi.org/simple'],
#   'package_version': ['2.8.6'],
#   '__label__': ['python_package_version'],
#   'ecosystem': ['pypi'],
#   'id': 372968,
#   '__type__': ['vertex'],
#   'label': 'python_package_version',
#   'package_name': ['pytest']},
#  {'index_url': ['https://pypi.org/simple'],
#   'package_version': ['3.6.0'],
#   '__label__': ['python_package_version'],
#   'ecosystem': ['pypi'],
#   'id': 639096,
#   '__type__': ['vertex'],
#   'label': 'python_package_version',
#   'package_name': ['protobuf']},
#  {'index_url': ['https://pypi.org/simple'],
#   'package_version': ['0.14.1'],
#   '__label__': ['python_package_version'],
#   'ecosystem': ['pypi'],
#   'id': 1351728,
#   '__type__': ['vertex'],
#   'label': 'python_package_version',
#   'package_name': ['werkzeug']},
#  {'index_url': ['https://pypi.org/simple'],
#   'package_version': ['1.11.3'],
#   '__label__': ['python_package_version'],
#   'ecosystem': ['pypi'],
#   'id': 221304,
#   '__type__': ['vertex'],
#   'label': 'python_package_version',
#   'package_name': ['numpy']},
#  {'index_url': ['https://pypi.org/simple'],
#   'package_version': ['2.8.7'],
#   '__label__': ['python_package_version'],
#   'ecosystem': ['pypi'],
#   'id': 410005752,
#   '__type__': ['vertex'],
#   'label': 'python_package_version',
#   'package_name': ['pytest']},
#  {'index_url': ['https://pypi.org/simple'],
#   'package_version': ['2.10'],
#   '__label__': ['python_package_version'],
#   'ecosystem': ['pypi'],
#   'id': 409604328,
#   '__type__': ['vertex'],
#   'label': 'python_package_version',
#   'package_name': ['jinja2']},
#  {'index_url': ['https://pypi.org/simple'],
#   'package_version': ['2.0.0'],
#   '__label__': ['python_package_version'],
#   'ecosystem': ['pypi'],
#   'id': 1310728,
#   '__type__': ['vertex'],
#   'label': 'python_package_version',
#   'package_name': ['pyflakes']},
#  {'index_url': ['https://pypi.org/simple'],
#   'package_version': ['1.9.0a20180521'],
#   '__label__': ['python_package_version'],
#   'ecosystem': ['pypi'],
#   'id': 409731208,
#   '__type__': ['vertex'],
#   'label': 'python_package_version',
#   'package_name': ['tb-nightly']},
#  {'index_url': ['https://pypi.org/simple'],
#   'package_version': ['12.0.5'],
#   '__label__': ['python_package_version'],
#   'ecosystem': ['pypi'],
#   'id': 409653248,
#   '__type__': ['vertex'],
#   'label': 'python_package_version',
#   'package_name': ['virtualenv']},
#  {'index_url': ['https://pypi.org/simple'],
#   'package_version': ['2.5.2'],
#   '__label__': ['python_package_version'],
#   'ecosystem': ['pypi'],
#   'id': 4152,
#   '__type__': ['vertex'],
#   'label': 'python_package_version',
#   'package_name': ['construct']},
#  {'index_url': ['https://pypi.org/simple'],
#   'package_version': ['15.2.0'],
#   '__label__': ['python_package_version'],
#   'ecosystem': ['pypi'],
#   'id': 409653496,
#   '__type__': ['vertex'],
#   'label': 'python_package_version',
#   'package_name': ['virtualenv']},
#  {'index_url': ['https://pypi.org/simple'],
#   'package_version': ['0.12.4'],
#   '__label__': ['python_package_version'],
#   'ecosystem': ['pypi'],
#   'id': 28872,
#   '__type__': ['vertex'],
#   'label': 'python_package_version',
#   'package_name': ['flask']},
#  {'index_url': ['https://pypi.org/simple'],
#   'package_version': ['1.5.0a20180127'],
#   '__label__': ['python_package_version'],
#   'ecosystem': ['pypi'],
#   'id': 36912,
#   '__type__': ['vertex'],
#   'label': 'python_package_version',
#   'package_name': ['tb-nightly']},
#  {'index_url': ['https://pypi.org/simple'],
#   'package_version': ['3.1.3'],
#   '__label__': ['python_package_version'],
#   'ecosystem': ['pypi'],
#   'id': 425992,
#   '__type__': ['vertex'],
#   'label': 'python_package_version',
#   'package_name': ['pytest']},
#  {'index_url': ['https://pypi.org/simple'],
#   'package_version': ['1.13.0a20190119'],
#   '__label__': ['python_package_version'],
#   'ecosystem': ['pypi'],
#   'id': 409735272,
#   '__type__': ['vertex'],
#   'label': 'python_package_version',
#   'package_name': ['tb-nightly']},
#  {'index_url': ['https://pypi.org/simple'],
#   'package_version': ['0.9.4'],
#   '__label__': ['python_package_version'],
#   'ecosystem': ['pypi'],
#   'id': 143576,
#   '__type__': ['vertex'],
#   'label': 'python_package_version',
#   'package_name': ['httpretty']},
#  {'index_url': ['https://pypi.org/simple'],
#   'package_version': ['1.11.0a20180730'],
#   '__label__': ['python_package_version'],
#   'ecosystem': ['pypi'],
#   'id': 409686120,
#   '__type__': ['vertex'],
#   'label': 'python_package_version',
#   'package_name': ['tb-nightly']},
#  {'index_url': ['https://pypi.org/simple'],
#   'package_version': ['18.6.1'],
#   '__label__': ['python_package_version'],
#   'ecosystem': ['pypi'],
#   'id': 122888,
#   '__type__': ['vertex'],
#   'label': 'python_package_version',
#   'package_name': ['setuptools']},
#  {'index_url': ['https://pypi.org/simple'],
#   'package_version': ['1.13.0a20181220'],
#   '__label__': ['python_package_version'],
#   'ecosystem': ['pypi'],
#   'id': 409727144,
#   '__type__': ['vertex'],
#   'label': 'python_package_version',
#   'package_name': ['tb-nightly']},
#  {'index_url': ['https://pypi.org/simple'],
#   'package_version': ['1.5.0'],
#   '__label__': ['python_package_version'],
#   'ecosystem': ['pypi'],
#   'id': 307448,
#   '__type__': ['vertex'],
#   'label': 'python_package_version',
#   'package_name': ['bleach']},
#  {'index_url': ['https://pypi.org/simple'],
#   'package_version': ['36.2.3'],
#   '__label__': ['python_package_version'],
#   'ecosystem': ['pypi'],
#   'id': 315576,
#   '__type__': ['vertex'],
#   'label': 'python_package_version',
#   'package_name': ['setuptools']},
#  {'index_url': ['https://pypi.org/simple'],
#   'package_version': ['0.12'],
#   '__label__': ['python_package_version'],
#   'ecosystem': ['pypi'],
#   'id': 412565640,
#   '__type__': ['vertex'],
#   'label': 'python_package_version',
#   'package_name': ['werkzeug']},
#  {'index_url': ['https://pypi.org/simple'],
#   'package_version': ['20.10.1'],
#   '__label__': ['python_package_version'],
#   'ecosystem': ['pypi'],
#   'id': 135360,
#   '__type__': ['vertex'],
#   'label': 'python_package_version',
#   'package_name': ['setuptools']},
#  {'index_url': ['https://pypi.org/simple'],
#   'package_version': ['4.0.3'],
#   '__label__': ['python_package_version'],
#   'ecosystem': ['pypi'],
#   'id': 1241328,
#   '__type__': ['vertex'],
#   'label': 'python_package_version',
#   'package_name': ['pbr']},
#  {'index_url': ['https://pypi.org/simple'],
#   'package_version': ['2018.1.18'],
#   '__label__': ['python_package_version'],
#   'ecosystem': ['pypi'],
#   'id': 410763264,
#   '__type__': ['vertex'],
#   'label': 'python_package_version',
#   'package_name': ['certifi']},
#  {'index_url': ['https://pypi.org/simple'],
#   'package_version': ['17.3.0'],
#   '__label__': ['python_package_version'],
#   'ecosystem': ['pypi'],
#   'id': 1191992,
#   '__type__': ['vertex'],
#   'label': 'python_package_version',
#   'package_name': ['attrs']},
#  {'index_url': ['https://pypi.org/simple'],
#   'package_version': ['2018.8.13'],
#   '__label__': ['python_package_version'],
#   'ecosystem': ['pypi'],
#   'id': 1040392,
#   '__type__': ['vertex'],
#   'label': 'python_package_version',
#   'package_name': ['certifi']},
#  {'index_url': ['https://pypi.org/simple'],
#   'package_version': ['3.0.7'],
#   '__label__': ['python_package_version'],
#   'ecosystem': ['pypi'],
#   'id': 450752,
#   '__type__': ['vertex'],
#   'label': 'python_package_version',
#   'package_name': ['pytest']},
#  {'index_url': ['https://pypi.org/simple'],
#   'package_version': ['0.14'],
#   '__label__': ['python_package_version'],
#   'ecosystem': ['pypi'],
#   'id': 409772280,
#   '__type__': ['vertex'],
#   'label': 'python_package_version',
#   'package_name': ['pylibftdi']},
#  {'index_url': ['https://pypi.org/simple'],
#   'package_version': ['1.7.0'],
#   '__label__': ['python_package_version'],
#   'ecosystem': ['pypi'],
#   'id': 409636864,
#   '__type__': ['vertex'],
#   'label': 'python_package_version',
#   'package_name': ['six']},
#  {'index_url': ['https://pypi.org/simple'],
#   'package_version': ['1.7.1'],
#   '__label__': ['python_package_version'],
#   'ecosystem': ['pypi'],
#   'id': 409792616,
#   '__type__': ['vertex'],
#   'label': 'python_package_version',
#   'package_name': ['numpy']},
#  {'index_url': ['https://pypi.org/simple'],
#   'package_version': ['1.8.0a20180322'],
#   '__label__': ['python_package_version'],
#   'ecosystem': ['pypi'],
#   'id': 409649336,
#   '__type__': ['vertex'],
#   'label': 'python_package_version',
#   'package_name': ['tb-nightly']},
#  {'index_url': ['https://pypi.org/simple'],
#   'package_version': ['3.2.0rc1'],
#   '__label__': ['python_package_version'],
#   'ecosystem': ['pypi'],
#   'id': 413487240,
#   '__type__': ['vertex'],
#   'label': 'python_package_version',
#   'package_name': ['protobuf']},
#  {'index_url': ['https://pypi.org/simple'],
#   'package_version': ['18.6'],
#   '__label__': ['python_package_version'],
#   'ecosystem': ['pypi'],
#   'id': 131104,
#   '__type__': ['vertex'],
#   'label': 'python_package_version',
#   'package_name': ['setuptools']},
#  {'index_url': ['https://pypi.org/simple'],
#   'package_version': ['1.11.0a20180818'],
#   '__label__': ['python_package_version'],
#   'ecosystem': ['pypi'],
#   'id': 409788552,
#   '__type__': ['vertex'],
#   'label': 'python_package_version',
#   'package_name': ['tb-nightly']},
#  {'index_url': ['https://pypi.org/simple'],
#   'package_version': ['1.7.0a20180213'],
#   '__label__': ['python_package_version'],
#   'ecosystem': ['pypi'],
#   'id': 409645224,
#   '__type__': ['vertex'],
#   'label': 'python_package_version',
#   'package_name': ['tb-nightly']},
#  {'index_url': ['https://pypi.org/simple'],
#   'package_version': ['0.14'],
#   '__label__': ['python_package_version'],
#   'ecosystem': ['pypi'],
#   'id': 410902632,
#   '__type__': ['vertex'],
#   'label': 'python_package_version',
#   'package_name': ['werkzeug']},
#  {'index_url': ['https://pypi.org/simple'],
#   'package_version': ['0.26.3'],
#   '__label__': ['python_package_version'],
#   'ecosystem': ['pypi'],
#   'id': 409751800,
#   '__type__': ['vertex'],
#   'label': 'python_package_version',
#   'package_name': ['pyftdi']},
#  {'index_url': ['https://pypi.org/simple'],
#   'package_version': ['1.5.1'],
#   '__label__': ['python_package_version'],
#   'ecosystem': ['pypi'],
#   'id': 90296,
#   '__type__': ['vertex'],
#   'label': 'python_package_version',
#   'package_name': ['py']},
#  {'index_url': ['https://pypi.org/simple'],
#   'package_version': ['1.23'],
#   '__label__': ['python_package_version'],
#   'ecosystem': ['pypi'],
#   'id': 659672,
#   '__type__': ['vertex'],
#   'label': 'python_package_version',
#   'package_name': ['urllib3']},
#  {'index_url': ['https://pypi.org/simple'],
#   'package_version': ['0.22.1'],
#   '__label__': ['python_package_version'],
#   'ecosystem': ['pypi'],
#   'id': 147640,
#   '__type__': ['vertex'],
#   'label': 'python_package_version',
#   'package_name': ['pyftdi']},
#  {'index_url': ['https://pypi.org/simple'],
#   'package_version': ['0.16.0'],
#   '__label__': ['python_package_version'],
#   'ecosystem': ['pypi'],
#   'id': 1781880,
#   '__type__': ['vertex'],
#   'label': 'python_package_version',
#   'package_name': ['wheel']},
#  {'index_url': ['https://pypi.org/simple'],
#   'package_version': ['2.8.0rc1'],
#   '__label__': ['python_package_version'],
#   'ecosystem': ['pypi'],
#   'id': 782384,
#   '__type__': ['vertex'],
#   'label': 'python_package_version',
#   'package_name': ['h5py']},
#  {'index_url': ['https://pypi.org/simple'],
#   'package_version': ['0.16.0'],
#   '__label__': ['python_package_version'],
#   'ecosystem': ['pypi'],
#   'id': 409804800,
#   '__type__': ['vertex'],
#   'label': 'python_package_version',
#   'package_name': ['pylibftdi']},
#  {'index_url': ['https://pypi.org/simple'],
#   'package_version': ['18.2.0'],
#   '__label__': ['python_package_version'],
#   'ecosystem': ['pypi'],
#   'id': 979176,
#   '__type__': ['vertex'],
#   'label': 'python_package_version',
#   'package_name': ['attrs']},
#  {'index_url': ['https://pypi.org/simple'],
#   'package_version': ['3.0.1'],
#   '__label__': ['python_package_version'],
#   'ecosystem': ['pypi'],
#   'id': 409821184,
#   '__type__': ['vertex'],
#   'label': 'python_package_version',
#   'package_name': ['pyserial']},
#  {'index_url': ['https://pypi.org/simple'],
#   'package_version': ['1.8.0a20180327'],
#   '__label__': ['python_package_version'],
#   'ecosystem': ['pypi'],
#   'id': 49392,
#   '__type__': ['vertex'],
#   'label': 'python_package_version',
#   'package_name': ['tb-nightly']},
#  {'index_url': ['https://pypi.org/simple'],
#   'package_version': ['0.11.6'],
#   '__label__': ['python_package_version'],
#   'ecosystem': ['pypi'],
#   'id': 5501096,
#   '__type__': ['vertex'],
#   'label': 'python_package_version',
#   'package_name': ['werkzeug']},
#  {'index_url': ['https://pypi.org/simple'],
#   'package_version': ['3.0.3'],
#   '__label__': ['python_package_version'],
#   'ecosystem': ['pypi'],
#   'id': 86208,
#   '__type__': ['vertex'],
#   'label': 'python_package_version',
#   'package_name': ['futures']},
#  {'index_url': ['https://pypi.org/simple'],
#   'package_version': ['36.0.1'],
#   '__label__': ['python_package_version'],
#   'ecosystem': ['pypi'],
#   'id': 315528,
#   '__type__': ['vertex'],
#   'label': 'python_package_version',
#   'package_name': ['setuptools']},
#  {'index_url': ['https://pypi.org/simple'],
#   'package_version': ['0.25.2'],
#   '__label__': ['python_package_version'],
#   'ecosystem': ['pypi'],
#   'id': 151744,
#   '__type__': ['vertex'],
#   'label': 'python_package_version',
#   'package_name': ['pyftdi']},
#  {'index_url': ['https://pypi.org/simple'],
#   'package_version': ['0.6.1'],
#   '__label__': ['python_package_version'],
#   'ecosystem': ['pypi'],
#   'id': 410083464,
#   '__type__': ['vertex'],
#   'label': 'python_package_version',
#   'package_name': ['astor']},
#  {'index_url': ['https://pypi.org/simple'],
#   'package_version': ['1.13.0a20190123'],
#   '__label__': ['python_package_version'],
#   'ecosystem': ['pypi'],
#   'id': 159864,
#   '__type__': ['vertex'],
#   'label': 'python_package_version',
#   'package_name': ['tb-nightly']},
#  {'index_url': ['https://pypi.org/simple'],
#   'package_version': ['1.13.3'],
#   '__label__': ['python_package_version'],
#   'ecosystem': ['pypi'],
#   'id': 409854136,
#   '__type__': ['vertex'],
#   'label': 'python_package_version',
#   'package_name': ['numpy']},
#  {'index_url': ['https://pypi.org/simple'],
#   'package_version': ['2016.9.26'],
#   '__label__': ['python_package_version'],
#   'ecosystem': ['pypi'],
#   'id': 1060896,
#   '__type__': ['vertex'],
#   'label': 'python_package_version',
#   'package_name': ['certifi']},
#  ...]

# %%
gqr(g.V().has("__label__", "python_package_version").where(outE().has("__label__", "has_artifact").count().is_(P.gt(1))).count().toList()).result
# Out:
# [1164]

# %% [markdown]
# Check the edges has_artifact connected to the single python package version

# %%
# %%time

test_package = 'setuptools'
test_package_version = '20.3.1'

n_edges_has_artifact = gqr(g.V().has("__label__", "python_package_version").has('package_name', test_package).has('package_version', test_package_version).outE().has("__label__", "has_artifact").count().next()).result

print(n_edges_has_artifact)
# Out:
# 3
# CPU times: user 1.18 ms, sys: 4.71 ms, total: 5.89 ms
# Wall time: 5.28 s

# %% [markdown]
# Check the corresponding python artifacts for that package version

# %%
# %%time

gqr(g.V().has("__label__", "python_package_version").has('package_name', test_package).has('package_version', test_package_version).outE().has("__label__", "has_artifact").inV().valueMap().toList()).result
# Out:
# CPU times: user 5.6 ms, sys: 0 ns, total: 5.6 ms
# Wall time: 5.45 s
# [{'__label__': ['python_artifact'],
#   '__type__': ['vertex'],
#   'artifact_hash_sha256': ['a1b3f74a1dc7c81368f2bc28a34366cfa6ffe80cdee1451261aabfba1ae1f4a8']},
#  {'__label__': ['python_artifact'],
#   '__type__': ['vertex'],
#   'artifact_hash_sha256': ['5243d74b6f462e5c7042a71c251586ad2c9bb8ebc5474de8e96073c5457e55e8']},
#  {'__label__': ['python_artifact'],
#   '__type__': ['vertex'],
#   'artifact_hash_sha256': ['9553b654fbfef3338c15e9c6751ea4032c3d9f28ef0ed4f73c64c7403cd37b18']}]

# %% [markdown]
# Check which python_artifact has more than one edge connected

# %%
gqr(g.V().has("__label__", "python_artifact").where(inE().has("__label__", "has_artifact").count().is_(P.gt(1))).count().toList()).result
# Out:
# [150]

# %%
gqr(g.V().has("__label__", "python_artifact").where(inE().has("__label__", "has_artifact").count().is_(P.gt(1))).valueMap().toList()).result
# Out:
# [{'__label__': ['python_artifact'],
#   '__type__': ['vertex'],
#   'artifact_hash_sha256': ['295e1f38225ce2bdd85a0524e265e9adea40507333829f3a7d64c588dd78ff21']},
#  {'__label__': ['python_artifact'],
#   '__type__': ['vertex'],
#   'artifact_hash_sha256': 
},
#  {'__label__': ['python_artifact'],
#   '__type__': ['vertex'],
#   'artifact_hash_sha256': ['f7c8a1c45c54e939acf2819b10eee61d29212962d96431653b01556f5ea5b660']},
#  {'__label__': ['python_artifact'],
#   '__type__': ['vertex'],
#   'artifact_hash_sha256': ['d71a1d335f74a8fa3fbd1f5da2304982224dec343d63c5606342b480d7ac1f73']},
#  {'__label__': ['python_artifact'],
#   '__type__': ['vertex'],
#   'artifact_hash_sha256': ['d7bc730a7718b69b2a047db7bceec52120fd76372486459e68aa463ce1f0e38a']},
#  {'__label__': ['python_artifact'],
#   '__type__': ['vertex'],
#   'artifact_hash_sha256': ['ba9fbb249ac5390bff8a1d6aa4b844fd400701069bda7d2e380dfe2217895101']},
#  {'__label__': ['python_artifact'],
#   '__type__': ['vertex'],
#   'artifact_hash_sha256': ['d9801fa058dfe7e01656e580c82205e73f96e411e5e6a89c08b12a9a3bd3db58']},
#  {'__label__': ['python_artifact'],
#   '__type__': ['vertex'],
#   'artifact_hash_sha256': ['a6f0d79b2b63a43c71bc128929be3a17bdf5d0a5f74208d7ad9563b3bf8210e9']},
#  {'__label__': ['python_artifact'],
#   '__type__': ['vertex'],
#   'artifact_hash_sha256': ['99864ed602d8a9d212e339b15ffa438895002eda7b7db20dca5309dac9605ae9']},
#  {'__label__': ['python_artifact'],
#   '__type__': ['vertex'],
#   'artifact_hash_sha256': ['9ae8d473561a214624be065deeb816f5b66da8d49752b59df18e7bdc433b0f62']},
#  {'__label__': ['python_artifact'],
#   '__type__': ['vertex'],
#   'artifact_hash_sha256': ['88ce0282cce70df9045e515f578c78f1ebc35dcabe1d70f800c3583ebda7f5f5']},
#  {'__label__': ['python_artifact'],
#   '__type__': ['vertex'],
#   'artifact_hash_sha256': ['e01d3203230e1786cd91ccfdc8f8454c8069c91bee3962ad93b87a4b2860f537']},
#  {'__label__': ['python_artifact'],
#   '__type__': ['vertex'],
#   'artifact_hash_sha256': ['2abbe0b237b42e075e5a59f90766c0a18cc29aea3baa7a152cc16f62fa556daa']},
#  {'__label__': ['python_artifact'],
#   '__type__': ['vertex'],
#   'artifact_hash_sha256': ['371d0cf3d56c47accc66116a77ad558d76eebaa8458a6b677af71ca606522146']},
#  {'__label__': ['python_artifact'],
#   '__type__': ['vertex'],
#   'artifact_hash_sha256': ['1714ca74bb85524d9d0c9a545d1c16670afcd74b40260a0bf537696e44799d15']},
#  {'__label__': ['python_artifact'],
#   '__type__': ['vertex'],
#   'artifact_hash_sha256': ['2144dea9c0c8e768d8d3c01be49af4ef36e863b584625889524a985522a99ef8']}]

# %% [markdown]
# Select an artifact hash and check why there are two edges connect to it

# %%
artifact_hash = "295e1f38225ce2bdd85a0524e265e9adea40507333829f3a7d64c588dd78ff21"

# %%
gqr(g.V().has("__label__", "python_package_version").where(outE().has("__label__", "has_artifact").inV().has("__label__","python_artifact").has("artifact_hash_sha256", artifact_hash)).valueMap(True).toList()).result
# Out:
# [{'index_url': ['https://pypi.org/simple'],
#   'label': 'python_package_version',
#   'package_version': ['4.3'],
#   'id': 1032384,
#   '__label__': ['python_package_version'],
#   'ecosystem': ['pypi'],
#   '__type__': ['vertex'],
#   'package_name': ['tornado']},
#  {'index_url': ['https://pypi.org/simple'],
#   'label': 'python_package_version',
#   'package_version': ['4.3'],
#   'id': 410489080,
#   '__label__': ['python_package_version'],
#   'ecosystem': ['pypi'],
#   '__type__': ['vertex'],
#   'package_name': ['tornado']}]

# %%
gqr(g.E().has("__label__", "has_artifact").where(inV().has("__label__","python_artifact").has("artifact_hash_sha256", artifact_hash)).valueMap().toList()).result
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-97-47bb64503234> in <module>
# ----> 1 gqr(g.E().has("__label__", "has_artifact").where(inV().has("__label__","python_artifact").has("artifact_hash_sha256", artifact_hash)).valueMap().toList()).result
#
# ~/work/aicoe/lab/thoth/lab/graph.py in __init__(self, result)
#      38         if isinstance(result, typing.Coroutine):
#      39             loop = asyncio.get_event_loop()
# ---> 40             result = loop.run_until_complete(result)
#      41
#      42         self.result = result
#
# ~/.local/share/virtualenvs/notebooks-3RWCrxj8/lib/python3.6/site-packages/uvloop/loop.pyx in uvloop.loop.Loop.run_until_complete()
#
# ~/.local/share/virtualenvs/notebooks-3RWCrxj8/lib/python3.6/site-packages/uvloop/loop.pyx in uvloop.loop.Loop.run_until_complete()
#
# ~/.local/share/virtualenvs/notebooks-3RWCrxj8/lib/python3.6/site-packages/uvloop/loop.pyx in uvloop.loop.Loop.run_forever()
#
# ~/.local/share/virtualenvs/notebooks-3RWCrxj8/lib/python3.6/site-packages/uvloop/loop.pyx in uvloop.loop.Loop._run()
#
# ~/.local/share/virtualenvs/notebooks-3RWCrxj8/lib/python3.6/site-packages/uvloop/handles/poll.pyx in uvloop.loop.__on_uvpoll_event()
#
# ~/.local/share/virtualenvs/notebooks-3RWCrxj8/lib/python3.6/site-packages/uvloop/cbhandles.pyx in uvloop.loop.Handle._run()
#
# ~/.local/share/virtualenvs/notebooks-3RWCrxj8/lib/python3.6/site-packages/uvloop/loop.pyx in uvloop.loop.Loop._read_from_self()
#
# ~/.local/share/virtualenvs/notebooks-3RWCrxj8/lib/python3.6/site-packages/uvloop/loop.pyx in uvloop.loop.Loop._invoke_signals()
#
# ~/.local/share/virtualenvs/notebooks-3RWCrxj8/lib/python3.6/site-packages/uvloop/loop.pyx in uvloop.loop.Loop._ceval_process_signals()
#
# KeyboardInterrupt:

# %% [markdown]
# Take ids of vertices instances for each label

# %%
vertices_ids_per_label = gqr(g.V().has("__label__").group().by("__label__").next()).result

# %%
vertices_ids_total = gqr(g.V().has("__label__").valueMap(True).next()).result
print(vertices_ids_total)

# %%
print(vertices_ids_per_label)
# Out:
# {'ecosystem_solver': [v[410951800], v[4232], v[4280], v[8400]], 'runtime_environment': [v[820236456]], 'cve': [v[5128296], v[3317824], v[5869568], v[5644352], v[942144], v[2089072], v[1302544], v[3788816], v[3821680], v[946280], v[4796528], v[2469952], v[1933352], v[3723512], v[7319616], v[332024], v[1433600], v[3932408], v[643184], v[9994304], v[385272], v[61480], v[5091440], v[745576], v[5148688], v[745512], v[5361832], v[8720448], v[311408], v[1831000], v[5582912], v[2338880], v[290904], v[3039296], v[3670128], v[356368], v[2752616], v[1192184], v[1196096], v[8892480], v[929960], v[1232896], v[57512], v[893016], v[3694760], v[1962152], v[1728760], v[2629736], v[3326056], v[2109504], v[1454096], v[798824], v[3088488], v[5435496], v[3452968], v[3858448], v[410112120], v[4145152], v[5300224], v[1376296], v[1081512], v[3068152], v[5050384], v[1716392], v[4489304], v[1441856], v[1425472], v[1097896], v[1548288], v[820240632], v[3469352], v[1839208], v[1466456], v[3510384], v[410099832], v[1069056], v[2007144], v[5357656], v[2007208], v[2285608], v[4747352], v[745536], v[4309008], v[4263936], v[3055864], v[5107776], v[3760376], v[4890736], v[1007728], v[4210752], v[4005888], v[1060968], v[1478760], v[1937512], v[1089704], v[1433616], v[3813544], v[6754368], v[409981048], v[5206120], v[2347048], v[446488], v[5546152], v[4948216], v[999672], v[655376], v[1814592], v[5009520], v[410681352], v[696568], v[2298104], v[1376368], v[86032], v[2138112], v[6172736], v[163904], v[1011960], v[4005976], v[1208488], v[1020016], v[5325048], v[1105936], v[4452392], v[2891864], v[2420840], v[3801088], v[5144640], v[598080], v[5533760], v[4132904], v[848120], v[4600056], v[966656], v[819728632], v[2723904], v[3928168], v[2400424], v[6340672], v[4128784], v[2412712], v[7299136], v[1818792], v[410677256], v[6217792], v[716912], v[1564672], v[4173888], v[1388792], v[5230608], v[897112], v[1990744], v[1384488], v[1056880], v[3371008], v[2003112], v[1773632], v[5390504], v[4563008], v[2670680], v[3006712], v[1351680], v[1106088], v[1667136], v[4481136], v[3604584], v[4198568], v[3215528], v[820601080], v[5484648], v[1990760], v[3354728], v[1474648], v[5783552], v[135280], v[6930496], v[172032], v[1376320], v[864504], v[1310736], v[3719280], v[704760], v[820003064], v[3526768], v[1560680], v[2326696], v[3588096], v[8642624], v[2494464], v[1687720], v[450576], v[5378216], v[1986600], v[2547776], v[6488128], v[2576496], v[5058648], v[2244696], v[2261104], v[57592], v[5148712], v[1753104], v[4440176], v[835696], v[3883256], v[770088], v[10707008], v[409862152], v[3153984], v[733288], v[5374200], v[2084928], v[409772040], v[2207912], v[344176], v[905216], v[4010232], v[9744448], v[548904], v[820031736], v[3715184], v[3055632], v[3498152], v[1130608], v[1286312], v[5038120], v[69632], v[4841576], v[3420408], v[1888504], v[3612736], v[4055208], v[820015352], v[5386408], v[6201408], v[7700544], v[5664832], v[364544], v[409989352], v[6803520], v[5419048], v[872488], v[3928080], v[5484656], v[581632], v[6832192], v[4988928], v[4055040], v[410296440], v[917544], v[4251648], v[217288], v[4169792], v[5558288], v[3874856], v[4530192], v[2732120], v[1016056], v[3817560], v[5152808], v[5148776], v[3706896], v[1478768], v[1237104], v[4333680], v[110632], v[5443696], v[3518464], v[4452464], v[3686464], v[5115944], v[1806440], v[2289680], v[5484712], v[651328], v[1089552], v[4505768], v[3272816], v[820080888], v[1999016], v[5738600], v[3084288], v[1155112], v[2301952], v[1994920], v[4550760], v[1445928], v[1781800], v[1351768], v[1163304], v[1806400], v[409600], v[1277952], v[3080360], v[1077248], v[1544208], v[335896], v[1015920], v[1167400], v[3383400], v[4083752], v[2711552], v[5013544], v[667896], v[6565952], v[3465280], v[94248], v[4018424], v[6385728], v[69736], v[3350544], v[168064], v[1064960], v[7680064], v[4833384], v[5488704], v[737280], v[10469440], v[3342352], v[4907096], v[3489792], v[5578792], v[557256], v[6561856], v[5120016], v[2879656], v[1011824], v[173 ...

# %% [markdown]
# Take ids for all vertices

# %% [markdown]
# Check query optimization

# %%
# %%time
gqr(g.E()
    .has("__label__", "solved")
    .has("solver_datetime")
    .has("solver_document_id")
    .has("solver_error")
    .has("solver_error_unsolvable")
    .has("solver_error_unparsable")
    .valueMap()
    .select("solver_document_id")
    .dedup()
    .count()
    .next()
   ).result
# Out:
# CPU times: user 4.17 ms, sys: 1.94 ms, total: 6.11 ms
# Wall time: 33.7 s
# 3060

# %%
# %%time
gqr(g.E()
    .has("__label__", "solved")
    .valueMap()
    .select("solver_document_id")
    .dedup()
    .count()
    .next()
   ).result
# Out:
# CPU times: user 2.54 ms, sys: 1.14 ms, total: 3.68 ms
# Wall time: 26 s
# 3060

# %%
# %%time
gqr(g.E()
    .has("__label__", "requires")
    .has("__type__", "edge")
    .has("analysis_datetime")
    .has("analysis_document_id")
    .has("analyzer_name")
    .has("analyzer_version")
    .valueMap()
    .select("analysis_document_id")
    .dedup()
    .count()
    .next()
   ).result
# Out:
# CPU times: user 2.86 ms, sys: 1.86 ms, total: 4.72 ms
# Wall time: 1.53 s
# 1

# %%
# %%time
gqr(g.E()
    .has("__label__", "requires")
    .valueMap()
    .select("analysis_document_id")
    .dedup()
    .count()
    .next()
   ).result

profiling = gqr(g.E()
    .has("__label__", "solved")
    .flatMap(
    has("__type__", "edge")
    .has("solver_datetime")
    .has("solver_document_id")
    .has("solver_error")
    .has("solver_error_unsolvable")
    .has("solver_error_unparsable")
    )
    .valueMap()
    .select("solver_document_id")
    .dedup()  
    .count()
    .profile()
    .next()
   ).result

profiling

# %%
for metric in profiling['@value']['metrics']:
    print()
    print('dur', metric['@value']['dur'])
    print('counts', metric['@value']['counts'])
    print('name', metric['@value']['name'])
    print('annotations', metric['@value']['annotations'])
    print('id', metric['@value']['id'])
# Out:
# dur 24682.713065
# counts {'traverserCount': 402217, 'elementCount': 402217}
# name JanusGraphStep([],[__label__.eq(solved)])
# annotations {'percentDur': 23.304144933768587, 'condition': '(__label__ = solved)', 'isFitted': 'false', 'query': '[]', 'orders': '[]', 'isOrdered': 'true'}
# id 9.0.0()
#
# dur 64836.808368
# counts {'traverserCount': 402217, 'elementCount': 402217}
# name TraversalFlatMapStep([HasStep([__type__.eq(edge)]), ProfileStep, TraversalFilterStep([JanusGraphPropertiesStep([solver_datetime],value), ProfileStep]), ProfileStep, TraversalFilterStep([JanusGraphPropertiesStep([solver_document_id],value), ProfileStep]), ProfileStep, TraversalFilterStep([JanusGraphPropertiesStep([solver_error],value), ProfileStep]), ProfileStep, TraversalFilterStep([JanusGraphPropertiesStep([solver_error_unsolvable],value), ProfileStep]), ProfileStep, TraversalFilterStep([JanusGraphPropertiesStep([solver_error_unparsable],value), ProfileStep]), ProfileStep])
# annotations {'percentDur': 61.215571208555545}
# id 2.0.0()
#
# dur 8867.176001
# counts {'traverserCount': 402217, 'elementCount': 402217}
# name PropertyMapStep(value)
# annotations {'percentDur': 8.37193035207933}
# id 3.0.0()
#
# dur 4594.098946
# counts {'traverserCount': 402217, 'elementCount': 402217}
# name SelectOneStep(last,solver_document_id)
# annotations {'percentDur': 4.3375113341762415}
# id 4.0.0()
#
# dur 2908.955195
# counts {'traverserCount': 3060, 'elementCount': 3060}
# name DedupGlobalStep
# annotations {'percentDur': 2.746485497424756}
# id 5.0.0()
#
# dur 25.797505
# counts {'traverserCount': 1, 'elementCount': 1}
# name CountGlobalStep
# annotations {'percentDur': 0.024356673995538}
# id 6.0.0()

# %%
# %%time
gqr(g.V().has("__label__", "python_package_version").has("__type__", "vertex").has("ecosystem", "pypi").has("package_name").has("package_version").and_(inE().has("__label__", "solved").has("__type__", "edge").has("solver_error", True).has("solver_error_unsolvable", False).has("solver_error_unparsable", True)).count().next()
).result

# %%
# %%time
gqr(g.V().has("__label__", "python_package_version").has("__type__", "vertex").has("ecosystem", "pypi").has("package_name").has("package_version").and_(inE().has("__label__", "solved").has("__type__", "edge").has("solver_error", True).has("solver_error_unsolvable", True).has("solver_error_unparsable", False)).count().next()
).result

# %%
# %%time
gqr(g.V().flatMap(has("__label__", "python_package_version").has("__type__", "vertex").has("ecosystem", "pypi").has("package_name").has("package_version").and_(inE().has("__label__", "solved").has("__type__", "edge").has("solver_error", True).has("solver_error_unsolvable", True).has("solver_error_unparsable", False))).count().next()
).result

# %%
# %%time
results_dict = graph_db.get_error_python_packages_count(unsolvable=True)
print(results_dict)
