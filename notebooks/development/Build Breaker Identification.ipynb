# %% [markdown]
# # Thoth: Build Analysers

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Introduction" data-toc-modified-id="Introduction-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Introduction</a></span><ul class="toc-item"><li><span><a href="#Lead-by-Example:" data-toc-modified-id="Lead-by-Example:-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Lead by Example:</a></span></li><li><span><a href="#How-it-works" data-toc-modified-id="How-it-works-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>How it works</a></span><ul class="toc-item"><li><span><a href="#The-intuition" data-toc-modified-id="The-intuition-1.2.1"><span class="toc-item-num">1.2.1&nbsp;&nbsp;</span>The intuition</a></span></li></ul></li></ul></li><li><span><a href="#Installation" data-toc-modified-id="Installation-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Installation</a></span></li><li><span><a href="#Local-setup" data-toc-modified-id="Local-setup-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Local setup</a></span></li><li><span><a href="#Report" data-toc-modified-id="Report-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Report</a></span></li></ul></div>

# %% [markdown]
# ## Introduction
#
# This is a set of analysers that will retrieve information from build logs.
#
# <br>
#
# ### Lead by Example:
#
# Consider a log produced by the [pip](https://pypi.org/project/pip/) package installer:
#
# > We can also use [pipenv](https://pypi.org/project/pipenv/), see the [How it works](how-it-works) section
#
# <details>
#   <summary> Log file content </summary>
#   <pre>
# Processing /home/macermak/RedHat/aicoe/lab
# Collecting networkx (from thoth-lab==0.0.3)
# Collecting requests (from thoth-lab==0.0.3)
#   Using cached https://files.pythonhosted.org/packages/7d/e3/20f3d364d6c8e5d2353c72a67778eb189176f08e873c9900e10c0287b84b/requests-2.21.0-py2.py3-none-any.whl
# Collecting pandas (from thoth-lab==0.0.3)
#   Using cached https://files.pythonhosted.org/packages/e6/de/a0d3defd8f338eaf53ef716e40ef6d6c277c35d50e09b586e170169cdf0d/pandas-0.24.1-cp36-cp36m-manylinux1_x86_64.whl
# Collecting plotly (from thoth-lab==0.0.3)
#   Using cached https://files.pythonhosted.org/packages/fd/db/003b5cfbc710f4d4982440451185b952269e4080a57ae7e760a2ceb8ce0c/plotly-3.6.1-py2.py3-none-any.whl
# Collecting decorator>=4.3.0 (from networkx->thoth-lab==0.0.3)
#   Using cached https://files.pythonhosted.org/packages/f1/cd/7c8240007e9716b14679bc217a1baefa4432aa30394f7e2ec40a52b1a708/decorator-4.3.2-py2.py3-none-any.whl
# Collecting idna<2.9,>=2.5 (from requests->thoth-lab==0.0.3)
#   Using cached https://files.pythonhosted.org/packages/14/2c/cd551d81dbe15200be1cf41cd03869a46fe7226e7450af7a6545bfc474c9/idna-2.8-py2.py3-none-any.whl
# Collecting urllib3<1.25,>=1.21.1 (from requests->thoth-lab==0.0.3)
#   Using cached https://files.pythonhosted.org/packages/62/00/ee1d7de624db8ba7090d1226aebefab96a2c71cd5cfa7629d6ad3f61b79e/urllib3-1.24.1-py2.py3-none-any.whl
# Collecting certifi>=2017.4.17 (from requests->thoth-lab==0.0.3)
#   Using cached https://files.pythonhosted.org/packages/9f/e0/accfc1b56b57e9750eba272e24c4dddeac86852c2bebd1236674d7887e8a/certifi-2018.11.29-py2.py3-none-any.whl
# Collecting chardet<3.1.0,>=3.0.2 (from requests->thoth-lab==0.0.3)
#   Using cached https://files.pythonhosted.org/packages/bc/a9/01ffebfb562e4274b6487b4bb1ddec7ca55ec7510b22e4c51f14098443b8/chardet-3.0.4-py2.py3-none-any.whl
# Collecting python-dateutil>=2.5.0 (from pandas->thoth-lab==0.0.3)
#   Using cached https://files.pythonhosted.org/packages/41/17/c62faccbfbd163c7f57f3844689e3a78bae1f403648a6afb1d0866d87fbb/python_dateutil-2.8.0-py2.py3-none-any.whl
# Collecting pytz>=2011k (from pandas->thoth-lab==0.0.3)
#   Using cached https://files.pythonhosted.org/packages/61/28/1d3920e4d1d50b19bc5d24398a7cd85cc7b9a75a490570d5a30c57622d34/pytz-2018.9-py2.py3-none-any.whl
# Collecting numpy>=1.12.0 (from pandas->thoth-lab==0.0.3)
#   Using cached https://files.pythonhosted.org/packages/f5/bf/4981bcbee43934f0adb8f764a1e70ab0ee5a448f6505bd04a87a2fda2a8b/numpy-1.16.1-cp36-cp36m-manylinux1_x86_64.whl
# Collecting six (from plotly->thoth-lab==0.0.3)
#   Using cached https://files.pythonhosted.org/packages/73/fb/00a976f728d0d1fecfe898238ce23f502a721c0ac0ecfedb80e0d88c64e9/six-1.12.0-py2.py3-none-any.whl
# Collecting retrying>=1.3.3 (from plotly->thoth-lab==0.0.3)
# Collecting nbformat>=4.2 (from plotly->thoth-lab==0.0.3)
#   Using cached https://files.pythonhosted.org/packages/da/27/9a654d2b6cc1eaa517d1c5a4405166c7f6d72f04f6e7eea41855fe808a46/nbformat-4.4.0-py2.py3-none-any.whl
# Collecting traitlets>=4.1 (from nbformat>=4.2->plotly->thoth-lab==0.0.3)
#   Using cached https://files.pythonhosted.org/packages/93/d6/abcb22de61d78e2fc3959c964628a5771e47e7cc60d53e9342e21ed6cc9a/traitlets-4.3.2-py2.py3-none-any.whl
# Collecting jupyter-core (from nbformat>=4.2->plotly->thoth-lab==0.0.3)
#   Using cached https://files.pythonhosted.org/packages/1d/44/065d2d7bae7bebc06f1dd70d23c36da8c50c0f08b4236716743d706762a8/jupyter_core-4.4.0-py2.py3-none-any.whl
# Collecting jsonschema!=2.5.0,>=2.4 (from nbformat>=4.2->plotly->thoth-lab==0.0.3)
#   Using cached https://files.pythonhosted.org/packages/77/de/47e35a97b2b05c2fadbec67d44cfcdcd09b8086951b331d82de90d2912da/jsonschema-2.6.0-py2.py3-none-any.whl
# Collecting ipython-genutils (from nbformat>=4.2->plotly->thoth-lab==0.0.3)
#   Using cached https://files.pythonhosted.org/packages/fa/bc/9bd3b5c2b4774d5f33b2d544f1460be9df7df2fe42f352135381c347c69a/ipython_genutils-0.2.0-py2.py3-none-any.whl
# Building wheels for collected packages: thoth-lab
#   Running setup.py bdist_wheel for thoth-lab: started
#   Running setup.py bdist_wheel for thoth-lab: finished with status 'done'
#   Stored in directory: /tmp/pip-ephem-wheel-cache-_4menpyv/wheels/c6/6e/7d/ef751ae03b7d549816c6658c7f8065cb889a8de3f0c2b3ca6c
# Successfully built thoth-lab
# selinon 0.1.0rc9 requires celery>=4, which is not installed.
# thoth-analyzer 0.1.0 requires distro, which is not installed.
# thoth-storages 0.9.5 requires aiogremlin==3.2.6rc1, which is not installed.
# tensorflow-tensorboard 1.5.1 has requirement bleach==1.5.0, but you'll have bleach 2.1.4 which is incompatible.
# tensorflow-tensorboard 1.5.1 has requirement html5lib==0.9999999, but you'll have html5lib 1.0.1 which is incompatible.
# tensorboard 1.6.0 has requirement bleach==1.5.0, but you'll have bleach 2.1.4 which is incompatible.
# tensorboard 1.6.0 has requirement html5lib==0.9999999, but you'll have html5lib 1.0.1 which is incompatible.
# notebook 5.7.0 has requirement jupyter-client>=5.2.0, but you'll have jupyter-client 5.1.0 which is incompatible.
# notebook 5.7.0 has requirement pyzmq>=17, but you'll have pyzmq 16.0.3 which is incompatible.
# kaggle 1.4.7.1 has requirement urllib3<1.23.0,>=1.15, but you'll have urllib3 1.24.1 which is incompatible.
# botocore 1.11.3 has requirement urllib3<1.24,>=1.20, but you'll have urllib3 1.24.1 which is incompatible.
# awscli 1.14.25 has requirement botocore==1.8.29, but you'll have botocore 1.11.3 which is incompatible.
# awscli 1.14.25 has requirement colorama<=0.3.7,>=0.2.5, but you'll have colorama 0.3.9 which is incompatible.
# awscli 1.14.25 has requirement PyYAML<=3.12,>=3.10, but you'll have pyyaml 3.13 which is incompatible.
# thoth-storages 0.9.5 has requirement yarl<1.2, but you'll have yarl 1.3.0 which is incompatible.
# spyder-kernels 0.2.6 has requirement jupyter-client>=5.2.3, but you'll have jupyter-client 5.1.0 which is incompatible.
# spyder-kernels 0.2.6 has requirement pyzmq>=17, but you'll have pyzmq 16.0.3 which is incompatible.
# rstcheck 2.2 has requirement sphinx<1.5,>=1.3, but you'll have sphinx 1.8.1 which is incompatible.
# gremlinpython 3.2.6 has requirement six==1.10.0, but you'll have six 1.12.0 which is incompatible.
# gremlinpython 3.2.6 has requirement tornado==4.4.1, but you'll have tornado 4.5.2 which is incompatible.
# Installing collected packages: decorator, networkx, idna, urllib3, certifi, chardet, requests, six, python-dateutil, pytz, numpy, pandas, retrying, ipython-genutils, traitlets, jupyter-core, jsonschema, nbformat, plotly, thoth-lab
#   Found existing installation: decorator 4.3.2
#     Uninstalling decorator-4.3.2:
#       Successfully uninstalled decorator-4.3.2
#   Found existing installation: networkx 2.2
#     Uninstalling networkx-2.2:
#       Successfully uninstalled networkx-2.2
#   Found existing installation: idna 2.8
#     Uninstalling idna-2.8:
#       Successfully uninstalled idna-2.8
#   Found existing installation: urllib3 1.24.1
#     Uninstalling urllib3-1.24.1:
#       Successfully uninstalled urllib3-1.24.1
#   Found existing installation: certifi 2018.11.29
# Cannot uninstall 'certifi'. It is a distutils installed project and thus we cannot accurately determine which files belong to it which would lead to only a partial uninstall.
# You are using pip version 18.1, however version 19.0.2 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.
#   </pre>
# </details>
#
# In the log file, there is a line 76 which contains the information about the package which broke the installation: `certifi`. We want to extract this information. In the most common case, we want to get a **report** containing the observations about this particular build log.
#
# ```python
# from thoth.build_analysers.analysis import build_breaker_report
#
# log: str = ...
# report: dict = build_breaker_report(log)
# ```
#
# The result is a dictionary which can further be formatted by the convenient `build_breaker_format_report` function.
#
# ```python
# from thoth.build_analysers.analysis import build_breaker_format_report
#
# print(build_breaker_format_report(report))
# ```
#
# And you should see something like this:
# ```
# Build breaker:
#
#     {
#         "already_satisfied": null,
#         "source": "thoth-lab",
#         "target": "certifi",
#         "version_installed": null,
#         "version_specified": ">=2017.4.17"
#     }
#
# Probable reason:
#
#     76: Cannot uninstall 'certifi'. It is a distutils installed project and thus we cannot accurately determine which files belong to it which would lead to only a partial uninstall.
#
# Candidates:
#
#     [
#         "76: Cannot uninstall 'certifi'. It is a distutils installed project and thus we cannot accurately determine which files belong to it which would lead to only a partial uninstall."
#     ]
#
# ```
#
# <br>
#
# ### How it works
#
# The logic is quite simple (and also a bit naive). Really, no rocket science, just a lot of string matching.
#
# #### The intuition
#
# The approach currently handles logs produced by pip and pipenv package installers. For both of them, there is a set of patterns which, if found in a log, potentially indicate an error. These patterns are strings formatted according to the [PEP3101](https://www.python.org/dev/peps/pep-3101/) string formatting syntax and are stored in the [`resources`](/thoth/build_analysers/resources) folder as [pandas DataFrames](https://pandas.pydata.org/pandas-docs/version/0.23.4/generated/pandas.DataFrame.html).
#
# We evaluate the 'goodness' of a match for each line of the log file with respect to the relevant set of patterns and label them based on the given *thresholds*. Currently, the `ERROR` threshold is set to the score of *>=0.6* on the scale from *0* through *1.0*. Finally, we try to search for package names in the log file to construct a dependency table. We filter the `ERROR`s containing a package name and we've got ourselves a list of *build breakers*.
#
# <br>

# %% [markdown]
# ## Installation
#
# The package is available on [PyPI](https://pypi.org/project/thoth-build-analysers/):
#
# ```bash
# pip install thoth-build-analysers
# ```
#
# And you're good to go :thumbsup:

# %% [markdown]
# ## Local setup

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from thoth.build_analysers import __version__

__version__
# Out:
# '0.1.0rc0'

# %%
from pathlib import Path

from thoth.build_analysers.analysis import build_breaker_analyze
from thoth.build_analysers.analysis import build_breaker_report

from thoth.build_analysers.analysis import build_breaker_format_report

# %% [markdown]
# ## Download fixtures

# %% [markdown]
# Download the source distribution which contains the fixtures (or use your own log file to analyse)

# %%
# !pip download --no-deps -i https://test.pypi.org/simple/ -d /tmp thoth-build-analysers
# !tar -xzf /tmp/thoth-build-analysers-0.1.0rc0.tar.gz -C /tmp/
# Out:
# Looking in indexes: https://test.pypi.org/simple/
# Collecting thoth-build-analysers
#   File was already downloaded /tmp/thoth_build_analysers-0.1.0rc0-py3-none-any.whl
# Successfully downloaded thoth-build-analysers

# %%
fixtures_dir = Path(f"/tmp/thoth-build-analysers-{__version__}/fixtures/")

# %%
from random import choice

log_fpath = choice(list(fixtures_dir.iterdir()))
log_fpath
# Out:
# PosixPath('/tmp/thoth-build-analysers-0.1.0rc0/fixtures/pipenv.failed.log')

# %% [markdown]
# Read the raw log file

# %%
log = log_fpath.read_text()
log[:1000] + "..."
# Out:
# '[pipenv.exceptions.ResolutionFailure]:       req_dir=requirements_dir\n[pipenv.exceptions.ResolutionFailure]:   File "/home/macermak/.local/lib/python3.6/site-packages/pipenv/utils.py", line 726, in resolve_deps\n[pipenv.exceptions.ResolutionFailure]:       req_dir=req_dir,\n[pipenv.exceptions.ResolutionFailure]:   File "/home/macermak/.local/lib/python3.6/site-packages/pipenv/utils.py", line 480, in actually_resolve_deps\n[pipenv.exceptions.ResolutionFailure]:       resolved_tree = resolver.resolve()\n[pipenv.exceptions.ResolutionFailure]:   File "/home/macermak/.local/lib/python3.6/site-packages/pipenv/utils.py", line 395, in resolve\n[pipenv.exceptions.ResolutionFailure]:       raise ResolutionFailure(message=str(e))\n[pipenv.exceptions.ResolutionFailure]:       pipenv.exceptions.ResolutionFailure: ERROR: ERROR: Could not find a version that matches six==1.10.0,>=1.11.0,>=1.5,>=1.9.0\n[pipenv.exceptions.ResolutionFailure]:       Tried: 0.9.0, 0.9.1, 0.9.2, 1.0.0, 1.1.0, 1.2.0, 1.3.0, 1.4.0,...'

# %% [markdown]
# ## Report

# %% [markdown]
# ---

# %%
handler, analysis = build_breaker_analyze(log)

print(f"\nThe log comes from: {handler}")
analysis
# Out:
# Length of the log file: 35
#
# The log comes from: pipenv
#                                                   msg     score  \
# 0   [pipenv.exceptions.ResolutionFailure]:       r...  1.000000
# 1   [pipenv.exceptions.ResolutionFailure]:   File ...  1.000000
# 2   [pipenv.exceptions.ResolutionFailure]:       r...  1.000000
# 3   [pipenv.exceptions.ResolutionFailure]:   File ...  1.000000
# 4   [pipenv.exceptions.ResolutionFailure]:       r...  1.000000
# 5   [pipenv.exceptions.ResolutionFailure]:   File ...  1.000000
# 6   [pipenv.exceptions.ResolutionFailure]:       r...  1.000000
# 7   [pipenv.exceptions.ResolutionFailure]:       p...  1.000000
# 8   [pipenv.exceptions.ResolutionFailure]:       T...  1.000000
# 9   [pipenv.exceptions.ResolutionFailure]:       S...  1.000000
# 10  [pipenv.exceptions.ResolutionFailure]: Warning...  1.000000
# 11  First try clearing your dependency cache with ...  1.000000
# 12  Alternatively, you can use $ pipenv install --...  1.000000
# 13  Hint: try $ pipenv lock --pre if it is a pre-r...  1.000000
# 14  ERROR: ERROR: Could not find a version that ma...  0.672544
# 15  Tried: 0.9.0, 0.9.1, 0.9.2, 1.0.0, 1.1.0, 1.2....  1.000000
# 16                        Skipped pre-versions: 1.0b1  0.384311
# 17  There are incompatible versions in the resolve...  1.000000
# 18  [pipenv.exceptions.ResolutionFailure]:   File ...  1.000000
# 19  [pipenv.exceptions.ResolutionFailure]:       r...  1.000000
# 20  [pipenv.exceptions.ResolutionFailure]:   File ...  1.000000
# 21  [pipenv.exceptions.ResolutionFailure]:       r...  1.000000
# 22  [pipenv.exceptions.ResolutionFailure]:   File ...  1.000000
# 23  [pipenv.exceptions.ResolutionFailure]:       r...  1.000000
# 24  [pipenv.exceptions.ResolutionFailure]:       p...  1.000000
# 25  [pipenv.exceptions.ResolutionFailure]:       T...  1.000000
# 26  [pipenv.exceptions.ResolutionFailure]:       S...  1.000000
# 27  [pipenv.exceptions.ResolutionFailure]: Warning...  1.000000
# 28  First try clearing your dependency cache with ...  1.000000
# 29  Alternatively, you can use $ pipenv install --...  1.000000
# 30  Hint: try $ pipenv lock --pre if it is a pre-r...  1.000000
# 31  ERROR: ERROR: Could not find a version that ma...  0.672544
# 32  Tried: 0.9.0, 0.9.1, 0.9.2, 1.0.0, 1.1.0, 1.2....  1.000000
# 33                        Skipped pre-versions: 1.0b1  0.384311
# 34  There are incompatible versions in the resolve...  1.000000
#
#                                               pattern    label   colour
# 0                          [pipenv.exceptions.{}]: {}    ERROR  #17934e
# 1                          [pipenv.exceptions.{}]: {}    ERROR  #17934e
# 2                          [pipenv.exceptions.{}]: {}    ERROR  #17934e
# 3                          [pipenv.exceptions.{}]: {}    ERROR  #17934e
# 4                          [pipenv.exceptions.{}]: {}    ERROR  #17934e
# 5                          [pipenv.exceptions.{}]: {}    ERROR  #17934e
# 6                          [pipenv.exceptions.{}]: {}    ERROR  #17934e
# 7                          [pipenv.exceptions.{}]: {}    ERROR  #17934e
# 8                          [pipenv.exceptions.{}]: {}    ERROR  #17934e
# 9                          [pipenv.exceptions.{}]: {}    ERROR  #17934e
# 10                         [pipenv.exceptions.{}]: {}    ERROR  #17934e
# 11  First try clearing your dependency cache with ...    ERROR  #17934e
# 12  Alternatively, you can use {} to bypass this m...    ERROR  #17934e
# 13    Hint: try {} if it is a pre-release dependency.    ERROR  #17934e
# 14           Could not find a version that matches {}    ERROR  #c7e77f
# 15                                          Tried: {}    ERROR  #17934e
# 16                                   pre-versions: {}  WARNING  #fece7c
# 17  There are incompatible versions in the resolve...    ERROR  #17934e
# 18                         [pipenv.exceptions.{}]: {}    ERROR  #17934e
# 19                         [pipenv.exceptions.{}]: {}    ERROR  #17934e
# 20                         [pipenv.exceptions.{}]: {}    ERROR  #17934e
# 21                         [pipenv.exceptions.{}]: {}    ERROR  #17934e
# 22                         [pipenv.exceptions.{}]: {}    ERROR  #17934e
# 23                         [pipenv.exceptions.{}]: {}    ERROR  #17934e
# 24                         [pipenv.exceptions.{}]: {}    ERROR  #17934e
# 25                         [pipenv.exceptions.{}]: {}    ERROR  #17934e
# 26                         [pipenv.exceptions.{}]: {}    ERROR  #17934e
# 27                         [pipenv.exceptions.{}]: {}    ERROR  #17934e
# 28  First try clearing your dependency cache with ...    ERROR  #17934e
# 29  Alternatively, you can use {} to bypass this m...    ERROR  #17934e
# 30    Hint: try {} if it is a pre-release dependency.    ERROR  #17934e
# 31           Could not find a version that matches {}    ERROR  #c7e77f
# 32                                          Tried: {}    ERROR  #17934e
# 33                                   pre-versions: {}  WARNING  #fece7c
# 34  There are incompatible versions in the resolve...    ERROR  #17934e

# %%
report: dict = build_breaker_report(analysis, handler=handler)
report
# Out:
# {'build_breaker': {'already_satisfied': None,
#   'source': None,
#   'target': 'six',
#   'version_installed': None,
#   'version_specified': '==1.10.0,>=1.11.0,>=1.5,>=1.9.0'},
#  'reason': {'ln': 31,
#   'msg': 'ERROR: ERROR: Could not find a version that matches six==1.10.0,>=1.11.0,>=1.5,>=1.9.0'},
#  'candidates': [{'ln': 34,
#    'msg': 'There are incompatible versions in the resolved dependencies.'},
#   {'ln': 32,
#    'msg': 'Tried: 0.9.0, 0.9.1, 0.9.2, 1.0.0, 1.1.0, 1.2.0, 1.3.0, 1.4.0, 1.4.1, 1.5.0, 1.5.0, 1.5.1, 1.5.1, 1.5.2, 1.5.2, 1.6.0, 1.6.0, 1.6.1, 1.6.1, 1.7.0, 1.7.0, 1.7.1, 1.7.1, 1.7.2, 1.7.2, 1.7.3, 1.7.3, 1.8.0, 1.8.0, 1.9.0, 1.9.0, 1.10.0, 1.10.0, 1.11.0, 1.11.0, 1.12.0, 1.12.0'},
#   {'ln': 1,
#    'msg': '[pipenv.exceptions.ResolutionFailure]:   File "/home/macermak/.local/lib/python3.6/site-packages/pipenv/utils.py", line 726, in resolve_deps'},
#   {'ln': 2,
#    'msg': '[pipenv.exceptions.ResolutionFailure]:       req_dir=req_dir,'},
#   {'ln': 3,
#    'msg': '[pipenv.exceptions.ResolutionFailure]:   File "/home/macermak/.local/lib/python3.6/site-packages/pipenv/utils.py", line 480, in actually_resolve_deps'},
#   {'ln': 4,
#    'msg': '[pipenv.exceptions.ResolutionFailure]:       resolved_tree = resolver.resolve()'},
#   {'ln': 5,
#    'msg': '[pipenv.exceptions.ResolutionFailure]:   File "/home/macermak/.local/lib/python3.6/site-packages/pipenv/utils.py", line 395, in resolve'},
#   {'ln': 6,
#    'msg': '[pipenv.exceptions.ResolutionFailure]:       raise ResolutionFailure(message=str(e))'},
#   {'ln': 7,
#    'msg': '[pipenv.exceptions.ResolutionFailure]:       pipenv.exceptions.ResolutionFailure: ERROR: ERROR: Could not find a version that matches six==1.10.0,>=1.11.0,>=1.5,>=1.9.0'},
#   {'ln': 8,
#    'msg': '[pipenv.exceptions.ResolutionFailure]:       Tried: 0.9.0, 0.9.1, 0.9.2, 1.0.0, 1.1.0, 1.2.0, 1.3.0, 1.4.0, 1.4.1, 1.5.0, 1.5.0, 1.5.1, 1.5.1, 1.5.2, 1.5.2, 1.6.0, 1.6.0, 1.6.1, 1.6.1, 1.7.0, 1.7.0, 1.7.1, 1.7.1, 1.7.2, 1.7.2, 1.7.3, 1.7.3, 1.8.0, 1.8.0, 1.9.0, 1.9.0, 1.10.0, 1.10.0, 1.11.0, 1.11.0, 1.12.0, 1.12.0'},
#   {'ln': 9,
#    'msg': '[pipenv.exceptions.ResolutionFailure]:       Skipped pre-versions: 1.0b1'},
#   {'ln': 10,
#    'msg': '[pipenv.exceptions.ResolutionFailure]: Warning: Your dependencies could not be resolved. You likely have a mismatch in your sub-dependencies.'},
#   {'ln': 11,
#    'msg': 'First try clearing your dependency cache with $ pipenv lock --clear, then try the original command again.'},
#   {'ln': 12,
#    'msg': 'Alternatively, you can use $ pipenv install --skip-lock to bypass this mechanism, then run $ pipenv graph to inspect the situation.'},
#   {'ln': 13,
#    'msg': 'Hint: try $ pipenv lock --pre if it is a pre-release dependency.'},
#   {'ln': 15,
#    'msg': 'Tried: 0.9.0, 0.9.1, 0.9.2, 1.0.0, 1.1.0, 1.2.0, 1.3.0, 1.4.0, 1.4.1, 1.5.0, 1.5.0, 1.5.1, 1.5.1, 1.5.2, 1.5.2, 1.6.0, 1.6.0, 1.6.1, 1.6.1, 1.7.0, 1.7.0, 1.7.1, 1.7.1, 1.7.2, 1.7.2, 1.7.3, 1.7.3, 1.8.0, 1.8.0, 1.9.0, 1.9.0, 1.10.0, 1.10.0, 1.11.0, 1.11.0, 1.12.0, 1.12.0'},
#   {'ln': 17,
#    'msg': 'There are incompatible versions in the resolved dependencies.'},
#   {'ln': 18,
#    'msg': '[pipenv.exceptions.ResolutionFailure]:   File "/home/macermak/.local/lib/python3.6/site-packages/pipenv/utils.py", line 726, in resolve_deps'},
#   {'ln': 19,
#    'msg': '[pipenv.exceptions.ResolutionFailure]:       req_dir=req_dir,'},
#   {'ln': 20,
#    'msg': '[pipenv.exceptions.ResolutionFailure]:   File "/home/macermak/.local/lib/python3.6/site-packages/pipenv/utils.py", line 480, in actually_resolve_deps'},
#   {'ln': 21,
#    'msg': '[pipenv.exceptions.ResolutionFailure]:       resolved_tree = resolver.resolve()'},
#   {'ln': 22,
#    'msg': '[pipenv.exceptions.ResolutionFailure]:   File "/home/macermak/.local/lib/python3.6/site-packages/pipenv/utils.py", line 395, in resolve'},
#   {'ln': 23,
#    'msg': '[pipenv.exceptions.ResolutionFailure]:       raise ResolutionFailure(message=str(e))'},
#   {'ln': 24,
#    'msg': '[pipenv.exceptions.ResolutionFailure]:       pipenv.exceptions.ResolutionFailure: ERROR: ERROR: Could not find a version that matches six==1.10.0,>=1.11.0,>=1.5,>=1.9.0'},
#   {'ln': 25,
#    'msg': '[pipenv.exceptions.ResolutionFailure]:       Tried: 0.9.0, 0.9.1, 0.9.2, 1.0.0, 1.1.0, 1.2.0, 1.3.0, 1.4.0, 1.4.1, 1.5.0, 1.5.0, 1.5.1, 1.5.1, 1.5.2, 1.5.2, 1.6.0, 1.6.0, 1.6.1, 1.6.1, 1.7.0, 1.7.0, 1.7.1, 1.7.1, 1.7.2, 1.7.2, 1.7.3, 1.7.3, 1.8.0, 1.8.0, 1.9.0, 1.9.0, 1.10.0, 1.10.0, 1.11.0, 1.11.0, 1.12.0, 1.12.0'},
#   {'ln': 26,
#    'msg': '[pipenv.exceptions.ResolutionFailure]:       Skipped pre-versions: 1.0b1'},
#   {'ln': 27,
#    'msg': '[pipenv.exceptions.ResolutionFailure]: Warning: Your dependencies could not be resolved. You likely have a mismatch in your sub-dependencies.'},
#   {'ln': 28,
#    'msg': 'First try clearing your dependency cache with $ pipenv lock --clear, then try the original command again.'},
#   {'ln': 29,
#    'msg': 'Alternatively, you can use $ pipenv install --skip-lock to bypass this mechanism, then run $ pipenv graph to inspect the situation.'},
#   {'ln': 30,
#    'msg': 'Hint: try $ pipenv lock --pre if it is a pre-release dependency.'},
#   {'ln': 0,
#    'msg': '[pipenv.exceptions.ResolutionFailure]:       req_dir=requirements_dir'},
#   {'ln': 14,
#    'msg': 'ERROR: ERROR: Could not find a version that matches six==1.10.0,>=1.11.0,>=1.5,>=1.9.0'},
#   {'ln': 31,
#    'msg': 'ERROR: ERROR: Could not find a version that matches six==1.10.0,>=1.11.0,>=1.5,>=1.9.0'}]}

# %%
print(build_breaker_format_report(report))
# Out:
# Build breaker:
#
#     {
#         "already_satisfied": null,
#         "source": null,
#         "target": "six",
#         "version_installed": null,
#         "version_specified": "==1.10.0,>=1.11.0,>=1.5,>=1.9.0"
#     }
#
# Probable reason:
#
#     31: ERROR: ERROR: Could not find a version that matches six==1.10.0,>=1.11.0,>=1.5,>=1.9.0
#
# Candidates:
#
#     [
#         "34: There are incompatible versions in the resolved dependencies.",
#         "32: Tried: 0.9.0, 0.9.1, 0.9.2, 1.0.0, 1.1.0, 1.2.0, 1.3.0, 1.4.0, 1.4.1, 1.5.0, 1.5.0, 1.5.1, 1.5.1, 1.5.2, 1.5.2, 1.6.0, 1.6.0, 1.6.1, 1.6.1, 1.7.0, 1.7.0, 1.7.1, 1.7.1, 1.7.2, 1.7.2, 1.7.3, 1.7.3, 1.8.0, 1.8.0, 1.9.0, 1.9.0, 1.10.0, 1.10.0, 1.11.0, 1.11.0, 1.12.0, 1.12.0",
#         "1: [pipenv.exceptions.ResolutionFailure]:   File \"/home/macermak/.local/lib/python3.6/site-packages/pipenv/utils.py\", line 726, in resolve_deps",
#         "2: [pipenv.exceptions.ResolutionFailure]:       req_dir=req_dir,",
#         "3: [pipenv.exceptions.ResolutionFailure]:   File \"/home/macermak/.local/lib/python3.6/site-packages/pipenv/utils.py\", line 480, in actually_resolve_deps",
#         "4: [pipenv.exceptions.ResolutionFailure]:       resolved_tree = resolver.resolve()",
#         "5: [pipenv.exceptions.ResolutionFailure]:   File \"/home/macermak/.local/lib/python3.6/site-packages/pipenv/utils.py\", line 395, in resolve",
#         "6: [pipenv.exceptions.ResolutionFailure]:       raise ResolutionFailure(message=str(e))",
#         "7: [pipenv.exceptions.ResolutionFailure]:       pipenv.exceptions.ResolutionFailure: ERROR: ERROR: Could not find a version that matches six==1.10.0,>=1.11.0,>=1.5,>=1.9.0",
#         "8: [pipenv.exceptions.ResolutionFailure]:       Tried: 0.9.0, 0.9.1, 0.9.2, 1.0.0, 1.1.0, 1.2.0, 1.3.0, 1.4.0, 1.4.1, 1.5.0, 1.5.0, 1.5.1, 1.5.1, 1.5.2, 1.5.2, 1.6.0, 1.6.0, 1.6.1, 1.6.1, 1.7.0, 1.7.0, 1.7.1, 1.7.1, 1.7.2, 1.7.2, 1.7.3, 1.7.3, 1.8.0, 1.8.0, 1.9.0, 1.9.0, 1.10.0, 1.10.0, 1.11.0, 1.11.0, 1.12.0, 1.12.0",
#         "9: [pipenv.exceptions.ResolutionFailure]:       Skipped pre-versions: 1.0b1",
#         "10: [pipenv.exceptions.ResolutionFailure]: Warning: Your dependencies could not be resolved. You likely have a mismatch in your sub-dependencies.",
#         "11: First try clearing your dependency cache with $ pipenv lock --clear, then try the original command again.",
#         "12: Alternatively, you can use $ pipenv install --skip-lock to bypass this mechanism, then run $ pipenv graph to inspect the situation.",
#         "13: Hint: try $ pipenv lock --pre if it is a pre-release dependency.",
#         "15: Tried: 0.9.0, 0.9.1, 0.9.2, 1.0.0, 1.1.0, 1.2.0, 1.3.0, 1.4.0, 1.4.1, 1.5.0, 1.5.0, 1.5.1, 1.5.1, 1.5.2, 1.5.2, 1.6.0, 1.6.0, 1.6.1, 1.6.1, 1.7.0, 1.7.0, 1.7.1, 1.7.1, 1.7.2, 1.7.2, 1.7.3, 1.7.3, 1.8.0, 1.8.0, 1.9.0, 1.9.0, 1.10.0, 1.10.0, 1.11.0, 1.11.0, 1.12.0, 1.12.0",
#         "17: There are incompatible versions in the resolved dependencies.",
#         "18: [pipenv.exceptions.ResolutionFailure]:   File \"/home/macermak/.local/lib/python3.6/site-packages/pipenv/utils.py\", line 726, in resolve_deps",
#         "19: [pipenv.exceptions.ResolutionFailure]:       req_dir=req_dir,",
#         "20: [pipenv.exceptions.ResolutionFailure]:   File \"/home/macermak/.local/lib/python3.6/site-packages/pipenv/utils.py\", line 480, in actually_resolve_deps",
#         "21: [pipenv.exceptions.ResolutionFailure]:       resolved_tree = resolver.resolve()",
#         "22: [pipenv.exceptions.ResolutionFailure]:   File \"/home/macermak/.local/lib/python3.6/site-packages/pipenv/utils.py\", line 395, in resolve",
#         "23: [pipenv.exceptions.ResolutionFailure]:       raise ResolutionFailure(message=str(e))",
#         "24: [pipenv.exceptions.ResolutionFailure]:       pipenv.exceptions.ResolutionFailure: ERROR: ERROR: Could not find a version that matches six==1.10.0,>=1.11.0,>=1.5,>=1.9.0",
#         "25: [pipenv.exceptions.ResolutionFailure]:       Tried: 0.9.0, 0.9.1, 0.9.2, 1.0.0, 1.1.0, 1.2.0, 1.3.0, 1.4.0, 1.4.1, 1.5.0, 1.5.0, 1.5.1, 1.5.1, 1.5.2, 1.5.2, 1.6.0, 1.6.0, 1.6.1, 1.6.1, 1.7.0, 1.7.0, 1.7.1, 1.7.1, 1.7.2, 1.7.2, 1.7.3, 1.7.3, 1.8.0, 1.8.0, 1.9.0, 1.9.0, 1.10.0, 1.10.0, 1.11.0, 1.11.0, 1.12.0, 1.12.0",
#         "26: [pipenv.exceptions.ResolutionFailure]:       Skipped pre-versions: 1.0b1",
#         "27: [pipenv.exceptions.ResolutionFailure]: Warning: Your dependencies could not be resolved. You likely have a mismatch in your sub-dependencies.",
#         "28: First try clearing your dependency cache with $ pipenv lock --clear, then try the original command again.",
#         "29: Alternatively, you can use $ pipenv install --skip-lock to bypass this mechanism, then run $ pipenv graph to inspect the situation.",
#         "30: Hint: try $ pipenv lock --pre if it is a pre-release dependency.",
#         "0: [pipenv.exceptions.ResolutionFailure]:       req_dir=requirements_dir",
#         "14: ERROR: ERROR: Could not find a version that matches six==1.10.0,>=1.11.0,>=1.5,>=1.9.0",
#         "31: ERROR: ERROR: Could not find a version that matches six==1.10.0,>=1.11.0,>=1.5,>=1.9.0"
#     ]
